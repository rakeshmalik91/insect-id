# %%
# !pip install torch torchvision
# !pip install matplotlib pandas scikit-learn
# !pip install pillow
# !pip install opencv-python

# %%
import sys
directory = ".."
sys.path.append(directory)

# %% [markdown]
# # Scrape https://www.indiancicadas.org for butterfly dataset

# %%
dataset_dir = "../insect-dataset/src/indiancicadas.org"
class_details_json_path = "insect-dataset/src/class_details.indiancicadas.org.json"

website_url = "https://www.indiancicadas.org"
initial_path = "/cicadoidea"
first_page = 0
last_page = 15

batch_size = 3
max_workers = 50
page_timeout = 120
image_timeout = 30

ignore_image_regex = r"^(imgs10|.*(iucn-red-list|mobileapp|butterfliesofurbangreeneries|webheader|headerlogo|WPA-[IVX]+).*)\.(png|jpg|jpeg)$"
skip_downloaded_species = False

early_stage_suffix = '-early'

# %%
import os
import re
import requests
from bs4 import BeautifulSoup
from urllib.parse import urljoin
import threading
from concurrent.futures import ThreadPoolExecutor

def log_header():
    return f"[ {threading.current_thread().name:24} ]  "

def download_image(img_url, output_dir):
    try:
        img_data = requests.get(img_url, timeout=image_timeout).content
        img_name = img_url.split("/")[-1]
        img_path = os.path.join(output_dir, img_name)
        with open(img_path, 'wb') as file:
            file.write(img_data)
        return True
    except Exception as e:
        # print(f"{log_header()}{e}")
        return False

def has_parent_with_prop(tag, prop, value, max_parents):
    parent = tag
    for i in range(0, max_parents):
        parent = parent.parent
        if parent.get(prop) == value:
            return True
    return False
    
def scrape_images(url, output_dir):
    try:
        print(f"{log_header()}    Scraping URL: {url}")
        response = requests.get(url, timeout=page_timeout)
        soup = BeautifulSoup(response.text, 'html.parser')
        img_tags = soup.find_all('img')
        success_cnt = 0
        failure_cnt = 0
        already_downloaded_cnt = 0
        for img in img_tags:
            img_url = img.get('src')
            if has_parent_with_prop(img, 'id', 'laraval', 5):
                # larval host plants photo
                # print (f"Ignoring larval host plants image {img_url}")
                continue
            class_suffix = ''
            if has_parent_with_prop(img, 'id', 'early', 6):
                # early stages
                # print (f"Found early stages image {img_url}")
                class_suffix = early_stage_suffix
            if img_url:
                img_url = urljoin(url, img_url)
                img_name = img_url.split("/")[-1]
                if re.search(ignore_image_regex, img_name):
                    continue
                if os.path.exists(f"{output_dir}{class_suffix}/{img_name}"):
                    already_downloaded_cnt = already_downloaded_cnt + 1
                    continue
                if not os.path.exists(output_dir+class_suffix):
                    os.makedirs(output_dir+class_suffix)
                if download_image(img_url, output_dir+class_suffix):
                    success_cnt = success_cnt + 1
                else:
                    failure_cnt = failure_cnt + 1
        if success_cnt > 0:
            print(f"{log_header()}      Downloaded {success_cnt}(+{already_downloaded_cnt}) / {success_cnt+already_downloaded_cnt+failure_cnt} image(s) in {output_dir}")
        return True
    except Exception as e:
        print(f"{log_header()}{e}")
        return False

def crawl(base_url, root, output_dir):
    try:
        url = urljoin(base_url, root)
        print(f"{log_header()}Crawling URL: {url}")
        if not os.path.exists(output_dir):
            os.makedirs(output_dir)
        response = requests.get(url, timeout=page_timeout)
        soup = BeautifulSoup(response.text, 'html.parser')
        img_tags = soup.find_all('img')
        for img in img_tags:
            img_url = img.get('src')
            if img_url:
                img_url = urljoin(url, img_url)
                # print (f"Found image {img_url}")
                img_name = img_url.split("/")[-1]
                if re.search(ignore_image_regex, img_name):
                    continue
                species_path = img.parent.parent.get('href')
                species_dir = output_dir+species_path.lower()
                if not (skip_downloaded_species and os.path.exists(species_dir) and os.path.isdir(species_dir) and os.listdir(species_dir)):
                    scrape_images(urljoin(base_url, species_path), species_dir)
        return True
    except Exception as e:
        print(f"{log_header()}{e}")
        return False

def crawl_in_batch(batch_start):
    print(f"Starting batch from page {batch_start} on thread {threading.current_thread().name}")
    for page in range(batch_start, min(batch_start+batch_size, last_page+1), 1):
        crawl(website_url, f"{initial_path}?page={page}", f"{dataset_dir}")

# %%
with ThreadPoolExecutor(max_workers=max_workers) as executor:
    futures = [executor.submit(crawl_in_batch, batch_start) for batch_start in range(first_page, last_page+1, batch_size)]
    for future in futures:
        print(f"Thread completed with result {future.result()}")

print("Scraping completed!")
# Out:
# Starting batch from page 0 on thread ThreadPoolExecutor-3_0
# [ ThreadPoolExecutor-3_0   ]  Crawling URL: https://www.indiancicadas.org/cicadoidea?page=0
# Starting batch from page 3 on thread ThreadPoolExecutor-3_1
# [ ThreadPoolExecutor-3_1   ]  Crawling URL: https://www.indiancicadas.org/cicadoidea?page=3
# Starting batch from page 6 on thread ThreadPoolExecutor-3_2
# [ ThreadPoolExecutor-3_2   ]  Crawling URL: https://www.indiancicadas.org/cicadoidea?page=6
# Starting batch from page 9 on thread ThreadPoolExecutor-3_3
# [ ThreadPoolExecutor-3_3   ]  Crawling URL: https://www.indiancicadas.org/cicadoidea?page=9
# Starting batch from page 12 on thread ThreadPoolExecutor-3_4
# [ ThreadPoolExecutor-3_4   ]  Crawling URL: https://www.indiancicadas.org/cicadoidea?page=12
# Starting batch from page 15 on thread ThreadPoolExecutor-3_5
# [ ThreadPoolExecutor-3_5   ]  Crawling URL: https://www.indiancicadas.org/cicadoidea?page=15
# [ ThreadPoolExecutor-3_0   ]      Scraping URL: https://www.indiancicadas.org/linguacicada-continuata
# [ ThreadPoolExecutor-3_1   ]      Scraping URL: https://www.indiancicadas.org/pomponia-cyanea
# [ ThreadPoolExecutor-3_2   ]      Scraping URL: https://www.indiancicadas.org/platylomia-ficulnea
# [ ThreadPoolExecutor-3_4   ]      Scraping URL: https://www.indiancicadas.org/platypleura-takasagona
# [ ThreadPoolExecutor-3_3   ]      Scraping URL: https://www.indiancicadas.org/talainga-japrona
# [ ThreadPoolExecutor-3_3   ]      Scraping URL: https://www.indiancicadas.org/talainga-naga
# [ ThreadPoolExecutor-3_0   ]      Scraping URL: https://www.indiancicadas.org/melampsalta-literata
# [ ThreadPoolExecutor-3_2   ]      Scraping URL: https://www.indiancicadas.org/platylomia-juno
# [ ThreadPoolExecutor-3_1   ]      Scraping URL: https://www.indiancicadas.org/pomponia-linearis
# [ ThreadPoolExecutor-3_4   ]      Scraping URL: https://www.indiancicadas.org/platypleura-testacea
# [ ThreadPoolExecutor-3_2   ]      Scraping URL: https://www.indiancicadas.org/platylomia-larus
# [ ThreadPoolExecutor-3_3   ]      Scraping URL: https://www.indiancicadas.org/tosena-albata
# [ ThreadPoolExecutor-3_0   ]      Scraping URL: https://www.indiancicadas.org/pauropsalta-exaequata
# [ ThreadPoolExecutor-3_1   ]      Scraping URL: https://www.indiancicadas.org/pomponia-picta
# [ ThreadPoolExecutor-3_4   ]      Scraping URL: https://www.indiancicadas.org/platypleura-westwoodi
# [ ThreadPoolExecutor-3_2   ]      Scraping URL: https://www.indiancicadas.org/platylomia-operculata
# [ ThreadPoolExecutor-3_3   ]      Scraping URL: https://www.indiancicadas.org/tosena-dives
# [ ThreadPoolExecutor-3_0   ]      Scraping URL: https://www.indiancicadas.org/graptotettix-guttatus
# [ ThreadPoolExecutor-3_1   ]      Scraping URL: https://www.indiancicadas.org/pomponia-ramifera
# [ ThreadPoolExecutor-3_4   ]      Scraping URL: https://www.indiancicadas.org/polyneura-laevigata
# [ ThreadPoolExecutor-3_2   ]      Scraping URL: https://www.indiancicadas.org/platylomia-radha
# [ ThreadPoolExecutor-3_3   ]      Scraping URL: https://www.indiancicadas.org/tosena-mearesiana
# [ ThreadPoolExecutor-3_0   ]      Scraping URL: https://www.indiancicadas.org/huechys-beata
# [ ThreadPoolExecutor-3_4   ]      Scraping URL: https://www.indiancicadas.org/pomponia-adusta
# [ ThreadPoolExecutor-3_1   ]      Scraping URL: https://www.indiancicadas.org/pomponia-solitaria
# [ ThreadPoolExecutor-3_2   ]      Scraping URL: https://www.indiancicadas.org/platylomia-vibrans
# [ ThreadPoolExecutor-3_3   ]      Scraping URL: https://www.indiancicadas.org/tosena-melanoptera
# [ ThreadPoolExecutor-3_0   ]      Scraping URL: https://www.indiancicadas.org/huechys-incarnata
# [ ThreadPoolExecutor-3_4   ]      Scraping URL: https://www.indiancicadas.org/pomponia-secreta
# [ ThreadPoolExecutor-3_1   ]      Scraping URL: https://www.indiancicadas.org/pomponia-surya
# [ ThreadPoolExecutor-3_2   ]      Scraping URL: https://www.indiancicadas.org/macrosemia-assamensis
# [ ThreadPoolExecutor-3_3   ]      Scraping URL: https://www.indiancicadas.org/subtibicina-tigris
# [ ThreadPoolExecutor-3_0   ]      Scraping URL: https://www.indiancicadas.org/huechys-phaenicura
# [ ThreadPoolExecutor-3_2   ]      Scraping URL: https://www.indiancicadas.org/macrosemia-saturata
# [ ThreadPoolExecutor-3_4   ]      Scraping URL: https://www.indiancicadas.org/proarna-hilaris
# [ ThreadPoolExecutor-3_1   ]      Scraping URL: https://www.indiancicadas.org/pomponia-urania
# [ ThreadPoolExecutor-3_3   ]      Scraping URL: https://www.indiancicadas.org/paharia-lacteipennis
# [ ThreadPoolExecutor-3_0   ]      Scraping URL: https://www.indiancicadas.org/huechys-sanguinea
# [ ThreadPoolExecutor-3_1   ]      Scraping URL: https://www.indiancicadas.org/pomponia-zebra
# [ ThreadPoolExecutor-3_2   ]      Scraping URL: https://www.indiancicadas.org/macrosemia-tonkiniana
# [ ThreadPoolExecutor-3_4   ]      Scraping URL: https://www.indiancicadas.org/psalmocharias-chitralensis
# [ ThreadPoolExecutor-3_0   ]      Scraping URL: https://www.indiancicadas.org/huechys-thoracica
# [ ThreadPoolExecutor-3_3   ]      Scraping URL: https://www.indiancicadas.org/tibicina-casyapae
# [ ThreadPoolExecutor-3_1   ]      Scraping URL: https://www.indiancicadas.org/terpnosia-abdullah
# [ ThreadPoolExecutor-3_2   ]      Scraping URL: https://www.indiancicadas.org/macrosemia-umbrata
# [ ThreadPoolExecutor-3_4   ]      Scraping URL: https://www.indiancicadas.org/psalmocharias-gizarensis
# [ ThreadPoolExecutor-3_3   ]      Scraping URL: https://www.indiancicadas.org/tibicina-reticulata
# [ ThreadPoolExecutor-3_0   ]      Scraping URL: https://www.indiancicadas.org/scieroptera-crocea
# [ ThreadPoolExecutor-3_1   ]      Scraping URL: https://www.indiancicadas.org/terpnosia-andersoni
# [ ThreadPoolExecutor-3_2   ]      Scraping URL: https://www.indiancicadas.org/megapomponia-imperatoria
# [ ThreadPoolExecutor-3_4   ]      Scraping URL: https://www.indiancicadas.org/psalmocharias-japokensis
# [ ThreadPoolExecutor-3_3   ]      Scraping URL: https://www.indiancicadas.org/abricta-brunnea
# [ ThreadPoolExecutor-3_0   ]      Scraping URL: https://www.indiancicadas.org/scieroptera-formosana
# [ ThreadPoolExecutor-3_4   ]      Scraping URL: https://www.indiancicadas.org/psalmocharias-paliur
# [ ThreadPoolExecutor-3_1   ]      Scraping URL: https://www.indiancicadas.org/terpnosia-clio
# [ ThreadPoolExecutor-3_2   ]      Scraping URL: https://www.indiancicadas.org/megapomponia-intermedia
# [ ThreadPoolExecutor-3_3   ]      Scraping URL: https://www.indiancicadas.org/abricta-pusilla[ ThreadPoolExecutor-3_0   ]      Scraping URL: https://www.indiancicadas.org/scieroptera-fumigata
#
# [ ThreadPoolExecutor-3_1   ]      Scraping URL: https://www.indiancicadas.org/terpnosia-collina
# [ ThreadPoolExecutor-3_4   ]      Scraping URL: https://www.indiancicadas.org/purana-campanula
# [ ThreadPoolExecutor-3_2   ]      Scraping URL: https://www.indiancicadas.org/khimbya-diminuta
# [ ThreadPoolExecutor-3_3   ]      Scraping URL: https://www.indiancicadas.org/abroma-bengalensis
# [ ThreadPoolExecutor-3_0   ]      Scraping URL: https://www.indiancicadas.org/scieroptera-montana
# [ ThreadPoolExecutor-3_1   ]      Scraping URL: https://www.indiancicadas.org/terpnosia-confusa
# [ ThreadPoolExecutor-3_4   ]      Scraping URL: https://www.indiancicadas.org/eopycna-himalayana
# [ ThreadPoolExecutor-3_2   ]      Scraping URL: https://www.indiancicadas.org/khimbya-evanescens
# [ ThreadPoolExecutor-3_0   ]      Scraping URL: https://www.indiancicadas.org/scieroptera-splendidula
# [ ThreadPoolExecutor-3_3   ]      Scraping URL: https://www.indiancicadas.org/abroma-nubifurca
# [ ThreadPoolExecutor-3_4   ]      Scraping URL: https://www.indiancicadas.org/eopycna-montana
# [ ThreadPoolExecutor-3_1   ]      Scraping URL: https://www.indiancicadas.org/terpnosia-ganesa
# [ ThreadPoolExecutor-3_2   ]      Scraping URL: https://www.indiancicadas.org/khimbya-immsi
# [ ThreadPoolExecutor-3_3   ]      Scraping URL: https://www.indiancicadas.org/huechys-haematica
# [ ThreadPoolExecutor-3_0   ]      Scraping URL: https://www.indiancicadas.org/bijaurana-sita
# [ ThreadPoolExecutor-3_4   ]      Scraping URL: https://www.indiancicadas.org/shaoshia-zhangi
# [ ThreadPoolExecutor-3_1   ]      Scraping URL: https://www.indiancicadas.org/terpnosia-jenkinsi
# [ ThreadPoolExecutor-3_2   ]      Scraping URL: https://www.indiancicadas.org/changa-sita
# [ ThreadPoolExecutor-3_3   ]      Scraping URL: https://www.indiancicadas.org/karenia-ravida
# [ ThreadPoolExecutor-3_0   ]      Scraping URL: https://www.indiancicadas.org/lycurgus-subvittus
# [ ThreadPoolExecutor-3_2   ]      Scraping URL: https://www.indiancicadas.org/lethama-locusta
# [ ThreadPoolExecutor-3_4   ]      Scraping URL: https://www.indiancicadas.org/tanna-bhutanensis
# [ ThreadPoolExecutor-3_1   ]      Scraping URL: https://www.indiancicadas.org/terpnosia-lactea
# [ ThreadPoolExecutor-3_3   ]      Scraping URL: https://www.indiancicadas.org/kumanga-sandaracata
# [ ThreadPoolExecutor-3_0   ]      Scraping URL: https://www.indiancicadas.org/quintilia-pomponia
# [ ThreadPoolExecutor-3_2   ]      Scraping URL: https://www.indiancicadas.org/mata-kama
# [ ThreadPoolExecutor-3_4   ]      Scraping URL: https://www.indiancicadas.org/tanna-chekiangensis
# [ ThreadPoolExecutor-3_1   ]      Scraping URL: https://www.indiancicadas.org/terpnosia-maculipes
# [ ThreadPoolExecutor-3_3   ]      Scraping URL: https://www.indiancicadas.org/melampsalta-mogannia
# [ ThreadPoolExecutor-3_0   ]      Scraping URL: https://www.indiancicadas.org/abroma-apicalis
# [ ThreadPoolExecutor-3_2   ]      Scraping URL: https://www.indiancicadas.org/ambragaeana-stellata
# [ ThreadPoolExecutor-3_4   ]      Scraping URL: https://www.indiancicadas.org/tanna-japonensis
# [ ThreadPoolExecutor-3_3   ]      Scraping URL: https://www.indiancicadas.org/panka-simulata
# [ ThreadPoolExecutor-3_1   ]      Scraping URL: https://www.indiancicadas.org/terpnosia-ransonneti
# [ ThreadPoolExecutor-3_0   ]      Scraping URL: https://www.indiancicadas.org/abroma-maculicollis
# [ ThreadPoolExecutor-3_4   ]      Scraping URL: https://www.indiancicadas.org/tanna-minor
# [ ThreadPoolExecutor-3_2   ]      Scraping URL: https://www.indiancicadas.org/balinta-delinenda
# [ ThreadPoolExecutor-3_3   ]      Scraping URL: https://www.indiancicadas.org/scieroptera-sumatrana
# [ ThreadPoolExecutor-3_1   ]      Scraping URL: https://www.indiancicadas.org/neotanna-thalia
# [ ThreadPoolExecutor-3_0   ]      Scraping URL: https://www.indiancicadas.org/lemuriana-apicalis
# [ ThreadPoolExecutor-3_4   ]      Scraping URL: https://www.indiancicadas.org/terpnosia-elegans
# [ ThreadPoolExecutor-3_2   ]      Scraping URL: https://www.indiancicadas.org/balinta-octonotata
# [ ThreadPoolExecutor-3_1   ]      Scraping URL: https://www.indiancicadas.org/paratanna-parata
# [ ThreadPoolExecutor-3_3   ]      Scraping URL: https://www.indiancicadas.org/tettigetta-musiva
# [ ThreadPoolExecutor-3_4   ]      Scraping URL: https://www.indiancicadas.org/terpnosia-oberthuri
# [ ThreadPoolExecutor-3_2   ]  Crawling URL: https://www.indiancicadas.org/cicadoidea?page=7
# [ ThreadPoolExecutor-3_0   ]      Scraping URL: https://www.indiancicadas.org/cicadatra-acberi
# [ ThreadPoolExecutor-3_1   ]      Scraping URL: https://www.indiancicadas.org/rustia-dentivitta
# [ ThreadPoolExecutor-3_3   ]  Crawling URL: https://www.indiancicadas.org/cicadoidea?page=10
# [ ThreadPoolExecutor-3_2   ]      Scraping URL: https://www.indiancicadas.org/balinta-sanguiniventris
# [ ThreadPoolExecutor-3_4   ]  Crawling URL: https://www.indiancicadas.org/cicadoidea?page=13
# [ ThreadPoolExecutor-3_0   ]  Crawling URL: https://www.indiancicadas.org/cicadoidea?page=1
# [ ThreadPoolExecutor-3_3   ]      Scraping URL: https://www.indiancicadas.org/tibeta-zenobia
# [ ThreadPoolExecutor-3_1   ]  Crawling URL: https://www.indiancicadas.org/cicadoidea?page=4
# [ ThreadPoolExecutor-3_2   ]      Scraping URL: https://www.indiancicadas.org/callogaeana-annamensis
# [ ThreadPoolExecutor-3_0   ]      Scraping URL: https://www.indiancicadas.org/cicadatra-anoea
# [ ThreadPoolExecutor-3_4   ]      Scraping URL: https://www.indiancicadas.org/terpnosia-polei
# [ ThreadPoolExecutor-3_1   ]      Scraping URL: https://www.indiancicadas.org/rustia-tigrina
# [ ThreadPoolExecutor-3_3   ]      Scraping URL: https://www.indiancicadas.org/unduncus-connexa
# [ ThreadPoolExecutor-3_0   ]      Scraping URL: https://www.indiancicadas.org/cicadatra-gingat
# [ ThreadPoolExecutor-3_2   ]      Scraping URL: https://www.indiancicadas.org/callogaeana-festiva
# [ ThreadPoolExecutor-3_4   ]      Scraping URL: https://www.indiancicadas.org/terpnosia-psecas
# [ ThreadPoolExecutor-3_1   ]      Scraping URL: https://www.indiancicadas.org/taungia-abnormis
# [ ThreadPoolExecutor-3_3   ]      Scraping URL: https://www.indiancicadas.org/zouga-fornicata
# [ ThreadPoolExecutor-3_0   ]      Scraping URL: https://www.indiancicadas.org/cicadatra-inconspicua
# [ ThreadPoolExecutor-3_4   ]      Scraping URL: https://www.indiancicadas.org/terpnosia-ridens
# [ ThreadPoolExecutor-3_2   ]      Scraping URL: https://www.indiancicadas.org/gaeana-atkinsoni
# [ ThreadPoolExecutor-3_1   ]      Scraping URL: https://www.indiancicadas.org/chremistica-ochracea
# [ ThreadPoolExecutor-3_3   ]      Scraping URL: https://www.indiancicadas.org/balinta-pulchella
# [ ThreadPoolExecutor-3_0   ]      Scraping URL: https://www.indiancicadas.org/cicadatra-raja
# [ ThreadPoolExecutor-3_2   ]      Scraping URL: https://www.indiancicadas.org/gaeana-consors
# [ ThreadPoolExecutor-3_4   ]      Scraping URL: https://www.indiancicadas.org/terpnosia-stipata
# [ ThreadPoolExecutor-3_1   ]      Scraping URL: https://www.indiancicadas.org/chremistica-ribhoi
# [ ThreadPoolExecutor-3_3   ]      Scraping URL: https://www.indiancicadas.org/balinta-tenebricosa
# [ ThreadPoolExecutor-3_0   ]      Scraping URL: https://www.indiancicadas.org/cicadatra-sankara
# [ ThreadPoolExecutor-3_2   ]      Scraping URL: https://www.indiancicadas.org/gaeana-maculata
# [ ThreadPoolExecutor-3_4   ]      Scraping URL: https://www.indiancicadas.org/terpnosia-versicolor
# [ ThreadPoolExecutor-3_1   ]      Scraping URL: https://www.indiancicadas.org/chremistica-seminiger
# [ ThreadPoolExecutor-3_2   ]      Scraping URL: https://www.indiancicadas.org/sulphogaeana-sulphurea
# [ ThreadPoolExecutor-3_0   ]      Scraping URL: https://www.indiancicadas.org/cicadatra-walkeri
# [ ThreadPoolExecutor-3_3   ]      Scraping URL: https://www.indiancicadas.org/champaka-abdulla
# [ ThreadPoolExecutor-3_4   ]      Scraping URL: https://www.indiancicadas.org/bijaurana-typica
# [ ThreadPoolExecutor-3_1   ]      Scraping URL: https://www.indiancicadas.org/chremistica-tridentigera
# [ ThreadPoolExecutor-3_2   ]      Scraping URL: https://www.indiancicadas.org/hamza-ciliaris
# [ ThreadPoolExecutor-3_3   ]      Scraping URL: https://www.indiancicadas.org/chremistica-bimaculata
# [ ThreadPoolExecutor-3_4   ]      Scraping URL: https://www.indiancicadas.org/birrima-varians
# [ ThreadPoolExecutor-3_0   ]      Scraping URL: https://www.indiancicadas.org/cicadatra-xantes
# [ ThreadPoolExecutor-3_1   ]      Scraping URL: https://www.indiancicadas.org/cryptotympana-acuta
# [ ThreadPoolExecutor-3_2   ]      Scraping URL: https://www.indiancicadas.org/lahugada-dohertyi
# [ ThreadPoolExecutor-3_4   ]      Scraping URL: https://www.indiancicadas.org/graptotettix-thoracicus
# [ ThreadPoolExecutor-3_3   ]      Scraping URL: https://www.indiancicadas.org/chremistica-germana
# [ ThreadPoolExecutor-3_0   ]      Scraping URL: https://www.indiancicadas.org/mogannia-aurea
# [ ThreadPoolExecutor-3_1   ]      Scraping URL: https://www.indiancicadas.org/cryptotympana-aquila
# [ ThreadPoolExecutor-3_2   ]      Scraping URL: https://www.indiancicadas.org/oxypleura-atkinsoni
# [ ThreadPoolExecutor-3_4   ]      Scraping URL: https://www.indiancicadas.org/proarna-shaoshia
# [ ThreadPoolExecutor-3_3   ]      Scraping URL: https://www.indiancicadas.org/chremistica-mixta
# [ ThreadPoolExecutor-3_0   ]      Scraping URL: https://www.indiancicadas.org/mogannia-conica
# [ ThreadPoolExecutor-3_1   ]      Scraping URL: https://www.indiancicadas.org/cryptotympana-corvus
# [ ThreadPoolExecutor-3_2   ]      Scraping URL: https://www.indiancicadas.org/platypleura-affinis
# [ ThreadPoolExecutor-3_4   ]      Scraping URL: https://www.indiancicadas.org/pomponia-sp
# [ ThreadPoolExecutor-3_3   ]      Scraping URL: https://www.indiancicadas.org/chremistica-nigra
# [ ThreadPoolExecutor-3_0   ]      Scraping URL: https://www.indiancicadas.org/mogannia-cyanea
# [ ThreadPoolExecutor-3_1   ]      Scraping URL: https://www.indiancicadas.org/cryptotympana-edwardsi
# [ ThreadPoolExecutor-3_2   ]      Scraping URL: https://www.indiancicadas.org/platypleura-andamana
# [ ThreadPoolExecutor-3_4   ]      Scraping URL: https://www.indiancicadas.org/eopycna-spp
# [ ThreadPoolExecutor-3_3   ]      Scraping URL: https://www.indiancicadas.org/chremistica-viridis
# [ ThreadPoolExecutor-3_0   ]      Scraping URL: https://www.indiancicadas.org/mogannia-effecta
# [ ThreadPoolExecutor-3_1   ]      Scraping URL: https://www.indiancicadas.org/cryptotympana-exalbida
# [ ThreadPoolExecutor-3_2   ]      Scraping URL: https://www.indiancicadas.org/platypleura-assamensis
# [ ThreadPoolExecutor-3_4   ]      Scraping URL: https://www.indiancicadas.org/mosaica-irregularis
# [ ThreadPoolExecutor-3_3   ]      Scraping URL: https://www.indiancicadas.org/cicada-complex
# [ ThreadPoolExecutor-3_0   ]      Scraping URL: https://www.indiancicadas.org/mogannia-funebris
# [ ThreadPoolExecutor-3_1   ]      Scraping URL: https://www.indiancicadas.org/cryptotympana-holsti
# [ ThreadPoolExecutor-3_2   ]      Scraping URL: https://www.indiancicadas.org/platypleura-badia
# [ ThreadPoolExecutor-3_4   ]      Scraping URL: https://www.indiancicadas.org/rustia-apicata
# [ ThreadPoolExecutor-3_3   ]      Scraping URL: https://www.indiancicadas.org/cicada-orni
# [ ThreadPoolExecutor-3_0   ]      Scraping URL: https://www.indiancicadas.org/mogannia-hebes
# [ ThreadPoolExecutor-3_1   ]      Scraping URL: https://www.indiancicadas.org/cryptotympana-insularis
# [ ThreadPoolExecutor-3_2   ]      Scraping URL: https://www.indiancicadas.org/platypleura-basialba
# [ ThreadPoolExecutor-3_4   ]      Scraping URL: https://www.indiancicadas.org/platypleura-poorvachala
# [ ThreadPoolExecutor-3_3   ]      Scraping URL: https://www.indiancicadas.org/cicadetta-inglisi
# [ ThreadPoolExecutor-3_0   ]      Scraping URL: https://www.indiancicadas.org/mogannia-nasalis
# [ ThreadPoolExecutor-3_1   ]      Scraping URL: https://www.indiancicadas.org/cryptotympana-intermedia
# [ ThreadPoolExecutor-3_2   ]      Scraping URL: https://www.indiancicadas.org/platypleura-basiviridis
# [ ThreadPoolExecutor-3_4   ]      Scraping URL: https://www.indiancicadas.org/rustia-minuta
# [ ThreadPoolExecutor-3_3   ]      Scraping URL: https://www.indiancicadas.org/cicadatra-intermedia
# [ ThreadPoolExecutor-3_0   ]      Scraping URL: https://www.indiancicadas.org/mogannia-obliqua
# [ ThreadPoolExecutor-3_2   ]      Scraping URL: https://www.indiancicadas.org/platypleura-bufo
# [ ThreadPoolExecutor-3_1   ]      Scraping URL: https://www.indiancicadas.org/cryptotympana-limborgi
# [ ThreadPoolExecutor-3_4   ]      Scraping URL: https://www.indiancicadas.org/rustia-kodagura
# [ ThreadPoolExecutor-3_3   ]      Scraping URL: https://www.indiancicadas.org/cicadatra-karachiensis
# [ ThreadPoolExecutor-3_0   ]      Scraping URL: https://www.indiancicadas.org/mogannia-spurcata
# [ ThreadPoolExecutor-3_2   ]      Scraping URL: https://www.indiancicadas.org/platypleura-capitata
# [ ThreadPoolExecutor-3_1   ]      Scraping URL: https://www.indiancicadas.org/cryptotympana-mandarina
# [ ThreadPoolExecutor-3_3   ]      Scraping URL: https://www.indiancicadas.org/cicadatra-minuta[ ThreadPoolExecutor-3_4   ]      Scraping URL: https://www.indiancicadas.org/orientopsaltria-fangrayae
#
# [ ThreadPoolExecutor-3_0   ]      Scraping URL: https://www.indiancicadas.org/mogannia-venutissima
# [ ThreadPoolExecutor-3_1   ]      Scraping URL: https://www.indiancicadas.org/cryptotympana-recta
# [ ThreadPoolExecutor-3_2   ]      Scraping URL: https://www.indiancicadas.org/platypleura-cervina
# [ ThreadPoolExecutor-3_4   ]      Scraping URL: https://www.indiancicadas.org/meimuna-duffelsi
# [ ThreadPoolExecutor-3_3   ]      Scraping URL: https://www.indiancicadas.org/cryptotympana-atrata
# [ ThreadPoolExecutor-3_0   ]      Scraping URL: https://www.indiancicadas.org/mogannia-viridis
# [ ThreadPoolExecutor-3_2   ]      Scraping URL: https://www.indiancicadas.org/platypleura-coelebs
# [ ThreadPoolExecutor-3_1   ]      Scraping URL: https://www.indiancicadas.org/cryptotympana-vesta
# [ ThreadPoolExecutor-3_4   ]      Scraping URL: https://www.indiancicadas.org/dundubia-annandalei
# [ ThreadPoolExecutor-3_0   ]      Scraping URL: https://www.indiancicadas.org/psalmocharias-balochii
# [ ThreadPoolExecutor-3_3   ]      Scraping URL: https://www.indiancicadas.org/cryptotympana-auropilosa
# [ ThreadPoolExecutor-3_2   ]      Scraping URL: https://www.indiancicadas.org/platypleura-hampsoni
# [ ThreadPoolExecutor-3_1   ]      Scraping URL: https://www.indiancicadas.org/haphsa-bindusara
# [ ThreadPoolExecutor-3_4   ]      Scraping URL: https://www.indiancicadas.org/hyalessa-expansa-0
# [ ThreadPoolExecutor-3_0   ]      Scraping URL: https://www.indiancicadas.org/psalmocharias-querula
# [ ThreadPoolExecutor-3_3   ]      Scraping URL: https://www.indiancicadas.org/cryptotympana-facialis
# [ ThreadPoolExecutor-3_2   ]  Crawling URL: https://www.indiancicadas.org/cicadoidea?page=8
# [ ThreadPoolExecutor-3_1   ]      Scraping URL: https://www.indiancicadas.org/haphsa-durga
# [ ThreadPoolExecutor-3_2   ]      Scraping URL: https://www.indiancicadas.org/platypleura-inglisi
# [ ThreadPoolExecutor-3_4   ]      Scraping URL: https://www.indiancicadas.org/hyalessa-mahoni-0
# [ ThreadPoolExecutor-3_0   ]      Scraping URL: https://www.indiancicadas.org/psalmocharias-rugipennis
# [ ThreadPoolExecutor-3_3   ]      Scraping URL: https://www.indiancicadas.org/cryptotympana-takasagona
# [ ThreadPoolExecutor-3_1   ]      Scraping URL: https://www.indiancicadas.org/haphsa-karenensis
# [ ThreadPoolExecutor-3_2   ]      Scraping URL: https://www.indiancicadas.org/platypleura-insignis
# [ ThreadPoolExecutor-3_4   ]  Crawling URL: https://www.indiancicadas.org/cicadoidea?page=14
# [ ThreadPoolExecutor-3_0   ]  Crawling URL: https://www.indiancicadas.org/cicadoidea?page=2
# [ ThreadPoolExecutor-3_3   ]  Crawling URL: https://www.indiancicadas.org/cicadoidea?page=11
# [ ThreadPoolExecutor-3_1   ]  Crawling URL: https://www.indiancicadas.org/cicadoidea?page=5
# [ ThreadPoolExecutor-3_4   ]      Scraping URL: https://www.indiancicadas.org/hyalessa-melanoptera-0
# [ ThreadPoolExecutor-3_3   ]      Scraping URL: https://www.indiancicadas.org/cryptotympana-timorica
# [ ThreadPoolExecutor-3_0   ]      Scraping URL: https://www.indiancicadas.org/cicadetta-intermedia
# [ ThreadPoolExecutor-3_2   ]      Scraping URL: https://www.indiancicadas.org/platypleura-mackinnoni
# [ ThreadPoolExecutor-3_1   ]      Scraping URL: https://www.indiancicadas.org/haphsa-nicomache
# [ ThreadPoolExecutor-3_3   ]      Scraping URL: https://www.indiancicadas.org/cryptotympana-varicolor
# [ ThreadPoolExecutor-3_4   ]      Scraping URL: https://www.indiancicadas.org/hyalessa-obnubila-0
# [ ThreadPoolExecutor-3_0   ]      Scraping URL: https://www.indiancicadas.org/cicadetta-minuta
# [ ThreadPoolExecutor-3_1   ]      Scraping URL: https://www.indiancicadas.org/haphsa-scitula
# [ ThreadPoolExecutor-3_2   ]      Scraping URL: https://www.indiancicadas.org/platypleura-nobilis
# [ ThreadPoolExecutor-3_3   ]      Scraping URL: https://www.indiancicadas.org/diceroprocta-semicincta
# [ ThreadPoolExecutor-3_4   ]      Scraping URL: https://www.indiancicadas.org/hyalessa-stratoria-0
# [ ThreadPoolExecutor-3_0   ]      Scraping URL: https://www.indiancicadas.org/emathia-aegrota
# [ ThreadPoolExecutor-3_2   ]      Scraping URL: https://www.indiancicadas.org/platypleura-octoguttata
# [ ThreadPoolExecutor-3_1   ]      Scraping URL: https://www.indiancicadas.org/haphsa-stellata
# [ ThreadPoolExecutor-3_4   ]      Scraping URL: https://www.indiancicadas.org/mata-lenonia
# [ ThreadPoolExecutor-3_3   ]      Scraping URL: https://www.indiancicadas.org/dundubia-ensifera
# [ ThreadPoolExecutor-3_0   ]      Scraping URL: https://www.indiancicadas.org/cicada-conspurcata
# [ ThreadPoolExecutor-3_1   ]      Scraping URL: https://www.indiancicadas.org/meimuna-cassandra
# [ ThreadPoolExecutor-3_2   ]      Scraping URL: https://www.indiancicadas.org/platypleura-polita
# [ ThreadPoolExecutor-3_4   ]      Scraping URL: https://www.indiancicadas.org/mata-ruffordii
# [ ThreadPoolExecutor-3_3   ]      Scraping URL: https://www.indiancicadas.org/dundubia-myitkyinensis
# [ ThreadPoolExecutor-3_0   ]      Scraping URL: https://www.indiancicadas.org/cicada-olivierana
# [ ThreadPoolExecutor-3_1   ]      Scraping URL: https://www.indiancicadas.org/meimuna-microdon
# [ ThreadPoolExecutor-3_2   ]      Scraping URL: https://www.indiancicadas.org/platypleura-sphinx
# [ ThreadPoolExecutor-3_4   ]      Scraping URL: https://www.indiancicadas.org/mata-meghalayana
# [ ThreadPoolExecutor-3_3   ]      Scraping URL: https://www.indiancicadas.org/emathia-dup-aegrota
# [ ThreadPoolExecutor-3_0   ]      Scraping URL: https://www.indiancicadas.org/rustia-maculata
# [ ThreadPoolExecutor-3_1   ]      Scraping URL: https://www.indiancicadas.org/meimuna-pallida
# [ ThreadPoolExecutor-3_2   ]      Scraping URL: https://www.indiancicadas.org/platypleura-watsoni
# [ ThreadPoolExecutor-3_4   ]      Scraping URL: https://www.indiancicadas.org/becquartina-goera
# [ ThreadPoolExecutor-3_3   ]      Scraping URL: https://www.indiancicadas.org/rustia-marginatus
# [ ThreadPoolExecutor-3_0   ]      Scraping URL: https://www.indiancicadas.org/calcagninus-divaricatus
# [ ThreadPoolExecutor-3_1   ]      Scraping URL: https://www.indiancicadas.org/meimuna-silhetana
# [ ThreadPoolExecutor-3_2   ]      Scraping URL: https://www.indiancicadas.org/eopycna-minor
# [ ThreadPoolExecutor-3_3   ]      Scraping URL: https://www.indiancicadas.org/hyalessa-stratoria
# [ ThreadPoolExecutor-3_0   ]      Scraping URL: https://www.indiancicadas.org/calcagninus-nilgirensis[ ThreadPoolExecutor-3_2   ]      Scraping URL: https://www.indiancicadas.org/eopycna-repanda
#
# [ ThreadPoolExecutor-3_1   ]      Scraping URL: https://www.indiancicadas.org/meimuna-tripurasura
# [ ThreadPoolExecutor-3_3   ]      Scraping URL: https://www.indiancicadas.org/hyalessa-virescens
# [ ThreadPoolExecutor-3_2   ]      Scraping URL: https://www.indiancicadas.org/eopycna-verna
# [ ThreadPoolExecutor-3_0   ]      Scraping URL: https://www.indiancicadas.org/calcagninus-picturatus
# [ ThreadPoolExecutor-3_1   ]      Scraping URL: https://www.indiancicadas.org/meimuna-velitaris
# [ ThreadPoolExecutor-3_3   ]      Scraping URL: https://www.indiancicadas.org/khimbya-cuneata
# [ ThreadPoolExecutor-3_2   ]      Scraping URL: https://www.indiancicadas.org/formotosena-montivaga
# [ ThreadPoolExecutor-3_0   ]      Scraping URL: https://www.indiancicadas.org/euterpnosia-crowfooti
# [ ThreadPoolExecutor-3_1   ]      Scraping URL: https://www.indiancicadas.org/champaka-spinosa
# [ ThreadPoolExecutor-3_3   ]      Scraping URL: https://www.indiancicadas.org/mata-rama
# [ ThreadPoolExecutor-3_2   ]      Scraping URL: https://www.indiancicadas.org/angamiana-aetherea
# [ ThreadPoolExecutor-3_0   ]      Scraping URL: https://www.indiancicadas.org/euterpnosia-madhava
# [ ThreadPoolExecutor-3_1   ]      Scraping URL: https://www.indiancicadas.org/dundubia-emanatura
# [ ThreadPoolExecutor-3_3   ]      Scraping URL: https://www.indiancicadas.org/meimuna-gamameda
# [ ThreadPoolExecutor-3_2   ]      Scraping URL: https://www.indiancicadas.org/polyneura-ducalis
# [ ThreadPoolExecutor-3_0   ]      Scraping URL: https://www.indiancicadas.org/leptopsaltria-andamanensis
# [ ThreadPoolExecutor-3_1   ]      Scraping URL: https://www.indiancicadas.org/dundubia-feae
# [ ThreadPoolExecutor-3_3   ]      Scraping URL: https://www.indiancicadas.org/meimuna-tavoyana
# [ ThreadPoolExecutor-3_2   ]      Scraping URL: https://www.indiancicadas.org/distantalna-splendida
# [ ThreadPoolExecutor-3_0   ]      Scraping URL: https://www.indiancicadas.org/leptopsaltria-samia
# [ ThreadPoolExecutor-3_1   ]      Scraping URL: https://www.indiancicadas.org/dundubia-hastata
# [ ThreadPoolExecutor-3_3   ]      Scraping URL: https://www.indiancicadas.org/nabalua-mascula
# [ ThreadPoolExecutor-3_2   ]      Scraping URL: https://www.indiancicadas.org/hyalessa-expansa
# [ ThreadPoolExecutor-3_0   ]      Scraping URL: https://www.indiancicadas.org/leptopsaltria-tuberosa
# [ ThreadPoolExecutor-3_1   ]      Scraping URL: https://www.indiancicadas.org/dundubia-laterocurvata
# [ ThreadPoolExecutor-3_3   ]      Scraping URL: https://www.indiancicadas.org/orientopsaltria-beaudouini
# [ ThreadPoolExecutor-3_2   ]      Scraping URL: https://www.indiancicadas.org/hyalessa-mahoni
# [ ThreadPoolExecutor-3_1   ]      Scraping URL: https://www.indiancicadas.org/dundubia-nagarasingna
# [ ThreadPoolExecutor-3_0   ]      Scraping URL: https://www.indiancicadas.org/maua-quadrituberculata
# [ ThreadPoolExecutor-3_3   ]      Scraping URL: https://www.indiancicadas.org/platylomia-insignis
# [ ThreadPoolExecutor-3_2   ]      Scraping URL: https://www.indiancicadas.org/hyalessa-melanoptera
# [ ThreadPoolExecutor-3_1   ]      Scraping URL: https://www.indiancicadas.org/dundubia-oopaga
# [ ThreadPoolExecutor-3_0   ]      Scraping URL: https://www.indiancicadas.org/purana-guttularis
# [ ThreadPoolExecutor-3_3   ]      Scraping URL: https://www.indiancicadas.org/platylomia-lemoultii
# [ ThreadPoolExecutor-3_2   ]      Scraping URL: https://www.indiancicadas.org/hyalessa-obnubila
# [ ThreadPoolExecutor-3_0   ]      Scraping URL: https://www.indiancicadas.org/purana-morrisi
# [ ThreadPoolExecutor-3_1   ]      Scraping URL: https://www.indiancicadas.org/dundubia-rufivena
# [ ThreadPoolExecutor-3_3   ]      Scraping URL: https://www.indiancicadas.org/platylomia-malickyi
# [ ThreadPoolExecutor-3_2   ]      Scraping URL: https://www.indiancicadas.org/tacua-speciosa
# [ ThreadPoolExecutor-3_1   ]      Scraping URL: https://www.indiancicadas.org/dundubia-terpsichore
# [ ThreadPoolExecutor-3_0   ]      Scraping URL: https://www.indiancicadas.org/purana-tigrina
# [ ThreadPoolExecutor-3_3   ]      Scraping URL: https://www.indiancicadas.org/platypleura-intermedia
# [ ThreadPoolExecutor-3_1   ]      Scraping URL: https://www.indiancicadas.org/dundubia-vaginata
# [ ThreadPoolExecutor-3_2   ]      Scraping URL: https://www.indiancicadas.org/talainga-binghami
# [ ThreadPoolExecutor-3_0   ]      Scraping URL: https://www.indiancicadas.org/tanna-tigroides
# [ ThreadPoolExecutor-3_3   ]      Scraping URL: https://www.indiancicadas.org/platypleura-nigrosignata
# [ ThreadPoolExecutor-3_1   ]      Scraping URL: https://www.indiancicadas.org/platylomia-amicta
# [ ThreadPoolExecutor-3_0   ]      Scraping URL: https://www.indiancicadas.org/basa-singularis
# [ ThreadPoolExecutor-3_3   ]      Scraping URL: https://www.indiancicadas.org/platypleura-stridula
# [ ThreadPoolExecutor-3_1   ]      Scraping URL: https://www.indiancicadas.org/platylomia-brevis
# [ ThreadPoolExecutor-3_0   ]      Scraping URL: https://www.indiancicadas.org/pomponia-cinctimanus
# Thread completed with result None
# Thread completed with result None
# Thread completed with result None
# Thread completed with result None
# Thread completed with result None
# Thread completed with result None
# Scraping completed!

# %% [markdown]
# # Remove corrupted images & empty folders

# %%
import os
from PIL import Image
from pathlib import Path

def check_image(file_path):
    try:
        with Image.open(file_path) as img:
            img.verify()
        return True
    except (IOError, SyntaxError):
        return False

for species_dir in Path(f"{dataset_dir}").iterdir():
    if species_dir.is_dir() and os.listdir(species_dir):
        for file in Path(f"{species_dir}").iterdir():
            if file.is_file() and not check_image(file):
                os.remove(file)
                print(f"Corrupted file {file} removed")
            elif re.search(ignore_image_regex, file.name):
                os.remove(file)
                print(f"Unwanted file {file} removed")
    # if species_dir.is_dir() and not os.listdir(species_dir):
    #     os.rmdir(species_dir)
    #     print(f"Empty folder {species_dir} removed")

# %% [markdown]
# # Fetch species names

# %%
classes = { class_dir: len([ img for img in os.listdir(f"{dataset_dir}/{class_dir}") ]) for class_dir in os.listdir(f"{dataset_dir}") }

# %%
class_details = {}

# %%
import json

# read json
with open(class_details_json_path, "r", encoding="utf-8") as file:
    class_details = json.load(file)

# %%
for class_name in [ c for c in classes.keys() if not c.endswith("-early") ]:
    try:
        if class_name in class_details and "name" in class_details[class_name]:
            continue
        print()
        print(f"class_name: {class_name}")
        url = f"{website_url}/{class_name}"
        response = requests.get(url, timeout=page_timeout)
        soup = BeautifulSoup(response.text, 'html.parser')
        title = soup.find(lambda tag: tag.find("span", class_="spices-title") is not None, class_="field field--name-title field--type-string field--label-hidden").get_text(strip=True)
        print(f"title: {title}")
        species_name = re.split(r"\s+-\s+", title)
        if len(species_name) > 1:
            species_name = species_name[-1]
        else:
            print(f"species_name: NOT FOUND")
            continue
        print(f"species_name: {species_name}")
        class_details[class_name] = {"name": species_name}
    except Exception:
        print("ERROR")
# Out:
# class_name: abricta-brunnea
# title: Abricta brunneaFabricius, 1798  -
# species_name: NOT FOUND
#
# class_name: abricta-pusilla
# title: Abricta pusillaFabricius, 1803  -
# species_name: NOT FOUND
#
# class_name: abroma-apicalis
# title: Abroma apicalisOllenbach, 1929  -
# species_name: NOT FOUND
#
# class_name: abroma-bengalensis
# title: Abroma bengalensisDistant, 1906  -
# species_name: NOT FOUND
#
# class_name: abroma-maculicollis
# title: Abroma maculicollisGuérin-Méneville, 1838  -
# species_name: NOT FOUND
#
# class_name: abroma-nubifurca
# title: Abroma nubifurcaWalker, 1858  -
# species_name: NOT FOUND
#
# class_name: ambragaeana-stellata
# title: Ambragaeana stellataWalker, 1858  -
# species_name: NOT FOUND
#
# class_name: angamiana-aetherea
# title: Angamiana aethereaDistant, 1890  -
# species_name: NOT FOUND
#
# class_name: balinta-delinenda
# title: Balinta delinendaDistant, 1888  -
# species_name: NOT FOUND
#
# class_name: balinta-octonotata
# title: Balinta octonotataWestwood, 1842  -
# species_name: NOT FOUND
#
# class_name: balinta-pulchella
# title: Balinta pulchellaDistant, 1913  -
# species_name: NOT FOUND
#
# class_name: balinta-sanguiniventris
# title: Balinta sanguiniventrisOllenbach, 1929  -
# species_name: NOT FOUND
#
# class_name: balinta-tenebricosa
# title: Balinta tenebricosaDistant, 1888  -
# species_name: NOT FOUND
#
# class_name: basa-singularis
# title: Basa singularisWalker, 1858  -
# species_name: NOT FOUND
#
# class_name: becquartina-goera
# title: Becquartina goeraSarkar, Mahapatra, Mohapatra & Nair, 2021  - Balpakram Butterfly Cicada
# species_name: Balpakram Butterfly Cicada
#
# class_name: bijaurana-sita
# title: Bijaurana sitaDistant, 1912  -
# species_name: NOT FOUND
#
# class_name: bijaurana-typica
# title: Bijaurana typicaDistant, 1912  -
# species_name: NOT FOUND
#
# class_name: birrima-varians
# title: Birrima variansGermar, 1834  -
# species_name: NOT FOUND
#
# class_name: calcagninus-divaricatus
# title: Calcagninus divaricatusBliven, 1964  -
# species_name: NOT FOUND
#
# class_name: calcagninus-nilgirensis
# title: Calcagninus nilgirensisDistant, 1887  -
# species_name: NOT FOUND
#
# class_name: calcagninus-picturatus
# title: Calcagninus picturatusDistant, 1888  -
# species_name: NOT FOUND
#
# class_name: callogaeana-annamensis
# title: Callogaeana annamensisDistant, 1892  -
# species_name: NOT FOUND
#
# class_name: callogaeana-festiva
# title: Callogaeana festivaFabricius, 1803  -
# species_name: NOT FOUND
#
# class_name: champaka-abdulla
# title: Champaka abdullaDistant, 1881  -
# species_name: NOT FOUND
#
# class_name: champaka-spinosa
# title: Champaka spinosaFabricius, 1787  -
# species_name: NOT FOUND
#
# class_name: changa-sita
# title: Changa sitaDistant, 1881  -
# species_name: NOT FOUND
#
# class_name: chremistica-bimaculata
# title: Chremistica bimaculataOlivier, 1791  -
# species_name: NOT FOUND
#
# class_name: chremistica-germana
# title: Chremistica germanaDistant, 1888  -
# species_name: NOT FOUND
#
# class_name: chremistica-mixta
# title: Chremistica mixtaKirby, 1891  -
# species_name: NOT FOUND
#
# class_name: chremistica-nigra
# title: Chremistica nigraChen, 1940  -
# species_name: NOT FOUND
#
# class_name: chremistica-ochracea
# title: Chremistica ochraceaWalker, 1850  -
# species_name: NOT FOUND
#
# class_name: chremistica-ribhoi
# title: Chremistica ribhoiHajong & Yaakop, 2013  -
# species_name: NOT FOUND
#
# class_name: chremistica-seminiger
# title: Chremistica seminigerDistant, 1909  -
# species_name: NOT FOUND
#
# class_name: chremistica-tridentigera
# title: Chremistica tridentigeraBreddin, 1905  -
# species_name: NOT FOUND
#
# class_name: chremistica-viridis
# title: Chremistica viridisFabricius, 1803  -
# species_name: NOT FOUND
#
# class_name: cicada-complex
# title: Cicada complexWalker, 1850  -
# species_name: NOT FOUND
#
# class_name: cicada-conspurcata
# title: Cicada conspurcataFabricius, 1777  -
# species_name: NOT FOUND
#
# class_name: cicada-olivierana
# title: Cicada olivieranaMetcalf, 1963  -
# species_name: NOT FOUND
#
# class_name: cicada-orni
# title: Cicada orniLinnaeus, 1758  -
# species_name: NOT FOUND
#
# class_name: cicadatra-acberi
# title: Cicadatra acberiDistant, 1888  -
# species_name: NOT FOUND
#
# class_name: cicadatra-anoea
# title: Cicadatra anoeaWalker, 1850  -
# species_name: NOT FOUND
#
# class_name: cicadatra-gingat
# title: Cicadatra gingatChina, 1926  -
# species_name: NOT FOUND
#
# class_name: cicadatra-inconspicua
# title: Cicadatra inconspicuaDistant, 1912  -
# species_name: NOT FOUND
#
# class_name: cicadatra-intermedia
# title: Cicadatra intermediaOllenbach, 1929  -
# species_name: NOT FOUND
#
# class_name: cicadatra-karachiensis
# title: Cicadatra karachiensisAhmed, Sanborn & Hill, 2010  -
# species_name: NOT FOUND
#
# class_name: cicadatra-minuta
# title: Cicadatra minutaOllenbach, 1929  -
# species_name: NOT FOUND
#
# class_name: cicadatra-raja
# title: Cicadatra rajaDistant, 1906  -
# species_name: NOT FOUND
#
# class_name: cicadatra-sankara
# title: Cicadatra sankaraDistant, 1904  -
# species_name: NOT FOUND
#
# class_name: cicadatra-walkeri
# title: Cicadatra walkeriMetcalf, 1963  -
# species_name: NOT FOUND
#
# class_name: cicadatra-xantes
# title: Cicadatra xantesWalker, 1850  -
# species_name: NOT FOUND
#
# class_name: cicadetta-inglisi
# title: Cicadetta inglisiOllenbach, 1929  -
# species_name: NOT FOUND
#
# class_name: cicadetta-intermedia
# title: Cicadetta intermediaOllenbach, 1929  -
# species_name: NOT FOUND
#
# class_name: cicadetta-minuta
# title: Cicadetta minutaOllenbach, 1929  -
# species_name: NOT FOUND
#
# class_name: cryptotympana-acuta
# title: Cryptotympana acutaSignoret, 1849  -
# species_name: NOT FOUND
#
# class_name: cryptotympana-aquila
# title: Cryptotympana aquilaWalker, 1850  -
# species_name: NOT FOUND
#
# class_name: cryptotympana-atrata
# title: Cryptotympana atrataFabricius, 1775  -
# species_name: NOT FOUND
#
# class_name: cryptotympana-auropilosa
# title: Cryptotympana auropilosaHayashi, 1987  -
# species_name: NOT FOUND
#
# class_name: cryptotympana-corvus
# title: Cryptotympana corvusWalker, 1850  -
# species_name: NOT FOUND
#
# class_name: cryptotympana-edwardsi
# title: Cryptotympana edwardsiKirkaldy, 1902  -
# species_name: NOT FOUND
#
# class_name: cryptotympana-exalbida
# title: Cryptotympana exalbidaDistant, 1891  -
# species_name: NOT FOUND
#
# class_name: cryptotympana-facialis
# title: Cryptotympana facialisWalker, 1858  -
# species_name: NOT FOUND
#
# class_name: cryptotympana-holsti
# title: Cryptotympana holstiDistant, 1904  -
# species_name: NOT FOUND
#
# class_name: cryptotympana-insularis
# title: Cryptotympana insularisDistant, 1887  -
# species_name: NOT FOUND
#
# class_name: cryptotympana-intermedia
# title: Cryptotympana intermediaSignoret, 1849  -
# species_name: NOT FOUND
#
# class_name: cryptotympana-limborgi
# title: Cryptotympana limborgiDistant, 1888  -
# species_name: NOT FOUND
#
# class_name: cryptotympana-mandarina
# title: Cryptotympana mandarinaDistant, 1891  -
# species_name: NOT FOUND
#
# class_name: cryptotympana-recta
# title: Cryptotympana rectaWalker, 1850  -
# species_name: NOT FOUND
#
# class_name: cryptotympana-takasagona
# title: Cryptotympana takasagonaKato, 1925  -
# species_name: NOT FOUND
#
# class_name: cryptotympana-timorica
# title: Cryptotympana timoricaWalker, 1870  -
# species_name: NOT FOUND
#
# class_name: cryptotympana-varicolor
# title: Cryptotympana varicolorDistant, 1904  -
# species_name: NOT FOUND
#
# class_name: cryptotympana-vesta
# title: Cryptotympana vestaDistant, 1904  -
# species_name: NOT FOUND
#
# class_name: diceroprocta-semicincta
# title: Diceroprocta semicinctaDavis, 1925  -
# species_name: NOT FOUND
#
# class_name: distantalna-splendida
# title: Distantalna splendidaDistant, 1878  -
# species_name: NOT FOUND
#
# class_name: dundubia-emanatura
# title: Dundubia emanaturaDistant, 1889  -
# species_name: NOT FOUND
#
# class_name: dundubia-ensifera
# title: Dundubia ensiferaBloen & Duffels, 1976  -
# species_name: NOT FOUND
#
# class_name: dundubia-feae
# title: Dundubia feaeDistant, 1892  -
# species_name: NOT FOUND
#
# class_name: dundubia-laterocurvata
# title: Dundubia laterocurvataBeuk, 1996  -
# species_name: NOT FOUND
#
# class_name: dundubia-myitkyinensis
# title: Dundubia myitkyinensisBeuk, 1996  -
# species_name: NOT FOUND
#
# class_name: dundubia-nagarasingna
# title: Dundubia nagarasingnaDistant, 1881  -
# species_name: NOT FOUND
#
# class_name: dundubia-oopaga
# title: Dundubia oopagaDistant, 1881  -
# species_name: NOT FOUND
#
# class_name: dundubia-rufivena
# title: Dundubia rufivenaWalker, 1850  -
# species_name: NOT FOUND
#
# class_name: dundubia-terpsichore
# title: Dundubia terpsichoreWalker, 1850  -
# species_name: NOT FOUND
#
# class_name: dundubia-vaginata
# title: Dundubia vaginataFabricius, 1787  -
# species_name: NOT FOUND
#
# class_name: emathia-aegrota
# title: Emathia aegrotaStål, 1866  -
# species_name: NOT FOUND
#
# class_name: emathia-dup-aegrota
# title: Emathia dup aegrotaStål, 1866  -
# species_name: NOT FOUND
#
# class_name: eopycna-himalayana
# title: Eopycna himalayanaNaruse, 1977  -
# species_name: NOT FOUND
#
# class_name: eopycna-minor
# title: Eopycna minorLiu, 1940  -
# species_name: NOT FOUND
#
# class_name: eopycna-montana
# title: Eopycna montanaHayashi, 1978  -
# species_name: NOT FOUND
#
# class_name: eopycna-repanda
# title: Eopycna repandaLinnaeus, 1758  -
# species_name: NOT FOUND
#
# class_name: eopycna-spp
# title: Eopycna spp.-
# species_name: NOT FOUND
#
# class_name: eopycna-verna
# title: Eopycna vernaHayashi, 1982  -
# species_name: NOT FOUND
#
# class_name: euterpnosia-crowfooti
# title: Euterpnosia crowfootiDistant, 1912  -
# species_name: NOT FOUND
#
# class_name: euterpnosia-madhava
# title: Euterpnosia madhavaDistant, 1881  -
# species_name: NOT FOUND
#
# class_name: formotosena-montivaga
# title: Formotosena montivagaDistant, 1889  -
# species_name: NOT FOUND
#
# class_name: gaeana-atkinsoni
# title: Gaeana atkinsoniDistant, 1892  -
# species_name: NOT FOUND
#
# class_name: gaeana-consors
# title: Gaeana consorsAtkinson, 1884  -
# species_name: NOT FOUND
#
# class_name: gaeana-maculata
# title: Gaeana maculataDrury, 1773  -
# species_name: NOT FOUND
#
# class_name: graptotettix-guttatus
# title: Graptotettix guttatusStål, 1866  -
# species_name: NOT FOUND
#
# class_name: graptotettix-thoracicus
# title: Graptotettix thoracicusDistant, 1892  -
# species_name: NOT FOUND
#
# class_name: hamza-ciliaris
# title: Hamza ciliarisLinnaeus, 1758  -
# species_name: NOT FOUND
#
# class_name: haphsa-bindusara
# title: Haphsa bindusaraDistant, 1881  -
# species_name: NOT FOUND
#
# class_name: haphsa-durga
# title: Haphsa durgaDistant, 1881  -
# species_name: NOT FOUND
#
# class_name: haphsa-karenensis
# title: Haphsa karenensisOllenbach, 1928  -
# species_name: NOT FOUND
#
# class_name: haphsa-nicomache
# title: Haphsa nicomacheWalker, 1850  -
# species_name: NOT FOUND
#
# class_name: haphsa-scitula
# title: Haphsa scitulaDistant, 1888  -
# species_name: NOT FOUND
#
# class_name: haphsa-stellata
# title: Haphsa stellataLee, 2009  -
# species_name: NOT FOUND
#
# class_name: huechys-beata
# title: Huechys beataDistant, 1892  -
# species_name: NOT FOUND
#
# class_name: huechys-haematica
# title: Huechys haematicaDistant, 1888  -
# species_name: NOT FOUND
#
# class_name: huechys-incarnata
# title: Huechys incarnataHaupt, 1924  -
# species_name: NOT FOUND
#
# class_name: huechys-phaenicura
# title: Huechys phaenicuraGermar, 1834  -
# species_name: NOT FOUND
#
# class_name: huechys-sanguinea
# title: Huechys sanguineaDegeer, 1773  -
# species_name: NOT FOUND
#
# class_name: huechys-thoracica
# title: Huechys thoracicaDistant, 1879  -
# species_name: NOT FOUND
#
# class_name: hyalessa-expansa
# title: Hyalessa expansaWalker, 1858  -
# species_name: NOT FOUND
#
# class_name: hyalessa-expansa-0
# title: Hyalessa expansa(Walker, 1858)  -
# species_name: NOT FOUND
#
# class_name: hyalessa-mahoni
# title: Hyalessa mahoniDistant, 1906  -
# species_name: NOT FOUND
#
# class_name: hyalessa-mahoni-0
# title: Hyalessa mahoni(Distant, 1906)  -
# species_name: NOT FOUND
#
# class_name: hyalessa-melanoptera
# title: Hyalessa melanopteraDistant, 1904  -
# species_name: NOT FOUND
#
# class_name: hyalessa-melanoptera-0
# title: Hyalessa melanoptera(Distant, 1904)  -
# species_name: NOT FOUND
#
# class_name: hyalessa-obnubila
# title: Hyalessa obnubilaDistant, 1888  -
# species_name: NOT FOUND
#
# class_name: hyalessa-obnubila-0
# title: Hyalessa obnubila(Distant, 1888)  -
# species_name: NOT FOUND
#
# class_name: hyalessa-stratoria
# title: Hyalessa stratoriaDistant, 1905  -
# species_name: NOT FOUND
#
# class_name: hyalessa-stratoria-0
# title: Hyalessa stratoria(Distant, 1905)  -
# species_name: NOT FOUND
#
# class_name: hyalessa-virescens
# title: Hyalessa virescensDistant, 1905  -
# species_name: NOT FOUND
#
# class_name: karenia-ravida
# title: Karenia ravidaDistant, 1888  -
# species_name: NOT FOUND
#
# class_name: khimbya-cuneata
# title: Khimbya cuneataDistant, 1897  -
# species_name: NOT FOUND
#
# class_name: khimbya-diminuta
# title: Khimbya diminutaWalker, 1850  -
# species_name: NOT FOUND
#
# class_name: khimbya-evanescens
# title: Khimbya evanescensWalker, 1858  -
# species_name: NOT FOUND
#
# class_name: khimbya-immsi
# title: Khimbya immsiDistant, 1912  -
# species_name: NOT FOUND
#
# class_name: kumanga-sandaracata
# title: Kumanga sandaracataDistant, 1888  -
# species_name: NOT FOUND
#
# class_name: lahugada-dohertyi
# title: Lahugada dohertyiDistant, 1891  -
# species_name: NOT FOUND
#
# class_name: lemuriana-apicalis
# title: Lemuriana apicalisGermar, 1830  -
# species_name: NOT FOUND
#
# class_name: leptopsaltria-andamanensis
# title: Leptopsaltria andamanensisDistant, 1888  -
# species_name: NOT FOUND
#
# class_name: leptopsaltria-samia
# title: Leptopsaltria samiaWalker, 1850  -
# species_name: NOT FOUND
#
# class_name: leptopsaltria-tuberosa
# title: Leptopsaltria tuberosaSignoret, 1847  -
# species_name: NOT FOUND
#
# class_name: lethama-locusta
# title: Lethama locustaWalker, 1850  -
# species_name: NOT FOUND
#
# class_name: linguacicada-continuata
# title: Linguacicada continuataDistant, 1888  -
# species_name: NOT FOUND
#
# class_name: lycurgus-subvittus
# title: Lycurgus subvittusWalker, 1850  -
# species_name: NOT FOUND
#
# class_name: macrosemia-assamensis
# title: Macrosemia assamensisDistant, 1905  -
# species_name: NOT FOUND
#
# class_name: macrosemia-saturata
# title: Macrosemia saturataWalker, 1858  -
# species_name: NOT FOUND
#
# class_name: macrosemia-tonkiniana
# title: Macrosemia tonkinianaJacobi, 1905  -
# species_name: NOT FOUND
#
# class_name: macrosemia-umbrata
# title: Macrosemia umbrataDistant, 1888  -
# species_name: NOT FOUND
#
# class_name: mata-kama
# title: Mata kamaDistant, 1881  -
# species_name: NOT FOUND
#
# class_name: mata-rama
# title: Mata ramaDistant, 1912  -
# species_name: NOT FOUND
#
# class_name: maua-quadrituberculata
# title: Maua quadrituberculataSignoret, 1847  -
# species_name: NOT FOUND
#
# class_name: megapomponia-imperatoria
# title: Megapomponia imperatoriaWestwood, 1842  -
# species_name: NOT FOUND
#
# class_name: megapomponia-intermedia
# title: Megapomponia intermediaDistant, 1905  -
# species_name: NOT FOUND
#
# class_name: meimuna-cassandra
# title: Meimuna cassandraDistant, 1912  -
# species_name: NOT FOUND
#
# class_name: meimuna-gamameda
# title: Meimuna gamamedaDistant, 1902  -
# species_name: NOT FOUND
#
# class_name: meimuna-microdon
# title: Meimuna microdonWalker, 1850  -
# species_name: NOT FOUND
#
# class_name: meimuna-pallida
# title: Meimuna pallidaOllenbach, 1929  -
# species_name: NOT FOUND
#
# class_name: meimuna-silhetana
# title: Meimuna silhetanaDistant, 1888  -
# species_name: NOT FOUND
#
# class_name: meimuna-tavoyana
# title: Meimuna tavoyanaDistant, 1888  -
# species_name: NOT FOUND
#
# class_name: meimuna-tripurasura
# title: Meimuna tripurasuraDistant, 1881  -
# species_name: NOT FOUND
#
# class_name: meimuna-velitaris
# title: Meimuna velitarisDistant, 1897  -
# species_name: NOT FOUND
#
# class_name: melampsalta-literata
# title: Melampsalta literataDistant, 1888  -
# species_name: NOT FOUND
#
# class_name: melampsalta-mogannia
# title: Melampsalta moganniaDistant, 1905  -
# species_name: NOT FOUND
#
# class_name: mogannia-aurea
# title: Mogannia aureaFraser, 1942  -
# species_name: NOT FOUND
#
# class_name: mogannia-conica
# title: Mogannia conicaGermar, 1830  -
# species_name: NOT FOUND
#
# class_name: mogannia-cyanea
# title: Mogannia cyaneaWalker, 1858  -
# species_name: NOT FOUND
#
# class_name: mogannia-effecta
# title: Mogannia effectaDistant, 1892  -
# species_name: NOT FOUND
#
# class_name: mogannia-funebris
# title: Mogannia funebrisStål, 1865  -
# species_name: NOT FOUND
#
# class_name: mogannia-hebes
# title: Mogannia hebesWalker, 1858  -
# species_name: NOT FOUND
#
# class_name: mogannia-nasalis
# title: Mogannia nasalisWhite, 1844  -
# species_name: NOT FOUND
#
# class_name: mogannia-obliqua
# title: Mogannia obliquaWalker, 1858  -
# species_name: NOT FOUND
#
# class_name: mogannia-spurcata
# title: Mogannia spurcataWalker, 1858  -
# species_name: NOT FOUND
#
# class_name: mogannia-venutissima
# title: Mogannia venutissimaStål, 1865  -
# species_name: NOT FOUND
#
# class_name: mogannia-viridis
# title: Mogannia viridisSignoret, 1847  -
# species_name: NOT FOUND
#
# class_name: mosaica-irregularis
# title: Mosaica irregularisLee and Emery, 2013  -
# species_name: NOT FOUND
#
# class_name: nabalua-mascula
# title: Nabalua masculaDistant, 1889  -
# species_name: NOT FOUND
#
# class_name: neotanna-thalia
# title: Neotanna thaliaWalker, 1850  -
# species_name: NOT FOUND
#
# class_name: orientopsaltria-beaudouini
# title: Orientopsaltria beaudouiniBoulard, 2003  -
# species_name: NOT FOUND
#
# class_name: orientopsaltria-fangrayae
# title: Orientopsaltria fangrayaeBoulard, 2001  -
# species_name: NOT FOUND
#
# class_name: oxypleura-atkinsoni
# title: Oxypleura atkinsoniDistant, 1912  -
# species_name: NOT FOUND
#
# class_name: paharia-lacteipennis
# title: Paharia lacteipennisWalker, 1850  -
# species_name: NOT FOUND
#
# class_name: panka-simulata
# title: Panka simulataDistant, 1905  -
# species_name: NOT FOUND
#
# class_name: paratanna-parata
# title: Paratanna parataLee, 2012  -
# species_name: NOT FOUND
#
# class_name: pauropsalta-exaequata
# title: Pauropsalta exaequataDistant, 1892  -
# species_name: NOT FOUND
#
# class_name: platylomia-amicta
# title: Platylomia amictaDistant, 1889  -
# species_name: NOT FOUND
#
# class_name: platylomia-brevis
# title: Platylomia brevisDistant, 1912  -
# species_name: NOT FOUND
#
# class_name: platylomia-ficulnea
# title: Platylomia ficulneaDistant, 1892  -
# species_name: NOT FOUND
#
# class_name: platylomia-insignis
# title: Platylomia insignisDistant, 1912  -
# species_name: NOT FOUND
#
# class_name: platylomia-juno
# title: Platylomia junoDistant, 1905  -
# species_name: NOT FOUND
#
# class_name: platylomia-larus
# title: Platylomia larusWalker, 1858  -
# species_name: NOT FOUND
#
# class_name: platylomia-lemoultii
# title: Platylomia lemoultiiLallemand, 1924  -
# species_name: NOT FOUND
#
# class_name: platylomia-malickyi
# title: Platylomia malickyiBeuk, 1998  -
# species_name: NOT FOUND
#
# class_name: platylomia-operculata
# title: Platylomia operculataDistant, 1913  -
# species_name: NOT FOUND
#
# class_name: platylomia-radha
# title: Platylomia radhaDistant, 1881  -
# species_name: NOT FOUND
#
# class_name: platylomia-vibrans
# title: Platylomia vibransWalker, 1850  -
# species_name: NOT FOUND
#
# class_name: platypleura-affinis
# title: Platypleura affinisFabricius, 1803  -
# species_name: NOT FOUND
#
# class_name: platypleura-andamana
# title: Platypleura andamanaDistant, 1878  -
# species_name: NOT FOUND
#
# class_name: platypleura-assamensis
# title: Platypleura assamensisAtkinson, 1884  -
# species_name: NOT FOUND
#
# class_name: platypleura-badia
# title: Platypleura badiaDistant, 1888  -
# species_name: NOT FOUND
#
# class_name: platypleura-basialba
# title: Platypleura basialbaWalker, 1850  -
# species_name: NOT FOUND
#
# class_name: platypleura-basiviridis
# title: Platypleura basiviridisWalker, 1850  -
# species_name: NOT FOUND
#
# class_name: platypleura-bufo
# title: Platypleura bufoWalker, 1850  -
# species_name: NOT FOUND
#
# class_name: platypleura-capitata
# title: Platypleura capitataOlivier, 1790  -
# species_name: NOT FOUND
#
# class_name: platypleura-cervina
# title: Platypleura cervinaWalker, 1850  -
# species_name: NOT FOUND
#
# class_name: platypleura-coelebs
# title: Platypleura coelebsStål, 1863  -
# species_name: NOT FOUND
#
# class_name: platypleura-hampsoni
# title: Platypleura hampsoniDistant, 1887  -
# species_name: NOT FOUND
#
# class_name: platypleura-inglisi
# title: Platypleura inglisiOllenbach, 1929  -
# species_name: NOT FOUND
#
# class_name: platypleura-insignis
# title: Platypleura insignisDistant, 1879  -
# species_name: NOT FOUND
#
# class_name: platypleura-intermedia
# title: Platypleura intermediaLiu, 1940  -
# species_name: NOT FOUND
#
# class_name: platypleura-mackinnoni
# title: Platypleura mackinnoniDistant, 1904  -
# species_name: NOT FOUND
#
# class_name: platypleura-nigrosignata
# title: Platypleura nigrosignataDistant, 1913  -
# species_name: NOT FOUND
#
# class_name: platypleura-nobilis
# title: Platypleura nobilisGermar, 1830  -
# species_name: NOT FOUND
#
# class_name: platypleura-octoguttata
# title: Platypleura octoguttataFabricius, 1798  -
# species_name: NOT FOUND
#
# class_name: platypleura-polita
# title: Platypleura politaWalker, 1850  -
# species_name: NOT FOUND
#
# class_name: platypleura-poorvachala
# title: Platypleura poorvachalaMarathe, Yeshwanth, Basu, & Kunte, 2017  -
# species_name: NOT FOUND
#
# class_name: platypleura-sphinx
# title: Platypleura sphinxWalker, 1850  -
# species_name: NOT FOUND
#
# class_name: platypleura-stridula
# title: Platypleura stridulaLinnaeus, 1758  -
# species_name: NOT FOUND
#
# class_name: platypleura-takasagona
# title: Platypleura takasagonaMatsumura, 1917  -
# species_name: NOT FOUND
#
# class_name: platypleura-testacea
# title: Platypleura testaceaWalker, 1858  -
# species_name: NOT FOUND
#
# class_name: platypleura-watsoni
# title: Platypleura watsoniDistant, 1897  -
# species_name: NOT FOUND
#
# class_name: platypleura-westwoodi
# title: Platypleura westwoodiStål, 1863  -
# species_name: NOT FOUND
#
# class_name: polyneura-ducalis
# title: Polyneura ducalisWestwood, 1840  -
# species_name: NOT FOUND
#
# class_name: polyneura-laevigata
# title: Polyneura laevigataChou & Yao, 1986  -
# species_name: NOT FOUND
#
# class_name: pomponia-adusta
# title: Pomponia adustaWalker, 1850  -
# species_name: NOT FOUND
#
# class_name: pomponia-cinctimanus
# title: Pomponia cinctimanusWalker, 1850  -
# species_name: NOT FOUND
#
# class_name: pomponia-cyanea
# title: Pomponia cyaneaFraser, 1948  -
# species_name: NOT FOUND
#
# class_name: pomponia-linearis
# title: Pomponia linearisWalker, 1850  -
# species_name: NOT FOUND
#
# class_name: pomponia-picta
# title: Pomponia pictaWalker, 1868  -
# species_name: NOT FOUND
#
# class_name: pomponia-ramifera
# title: Pomponia ramiferaWalker, 1850  -
# species_name: NOT FOUND
#
# class_name: pomponia-secreta
# title: Pomponia secretaHayashi, 1978  -
# species_name: NOT FOUND
#
# class_name: pomponia-solitaria
# title: Pomponia solitariaDistant, 1888  -
# species_name: NOT FOUND
#
# class_name: pomponia-sp
# title: Pomponia sp.-
# species_name: NOT FOUND
#
# class_name: pomponia-surya
# title: Pomponia suryaDistant, 1904  -
# species_name: NOT FOUND
#
# class_name: pomponia-urania
# title: Pomponia uraniaWalker, 1850  -
# species_name: NOT FOUND
#
# class_name: pomponia-zebra
# title: Pomponia zebraBliven, 1964  -
# species_name: NOT FOUND
#
# class_name: proarna-hilaris
# title: Proarna hilarisGermar, 1834  -
# species_name: NOT FOUND
#
# class_name: proarna-shaoshia
# title: Proarna Shaoshia-
# species_name: NOT FOUND
#
# class_name: psalmocharias-balochii
# title: Psalmocharias balochiiAhmed & Sanborn, 2010  -
# species_name: NOT FOUND
#
# class_name: psalmocharias-chitralensis
# title: Psalmocharias chitralensisAhmed & Sanborn, 2010  -
# species_name: NOT FOUND
#
# class_name: psalmocharias-gizarensis
# title: Psalmocharias gizarensisAhmed & Sanborn, 2010  -
# species_name: NOT FOUND
#
# class_name: psalmocharias-japokensis
# title: Psalmocharias japokensisAhmed & Sanborn, 2010  -
# species_name: NOT FOUND
#
# class_name: psalmocharias-paliur
# title: Psalmocharias paliurKolenati, 1857  -
# species_name: NOT FOUND
#
# class_name: psalmocharias-querula
# title: Psalmocharias querulaPallas, 1773  -
# species_name: NOT FOUND
#
# class_name: psalmocharias-rugipennis
# title: Psalmocharias rugipennisWalker, 1858  -
# species_name: NOT FOUND
#
# class_name: purana-campanula
# title: Purana campanulaPringle, 1955  -
# species_name: NOT FOUND
#
# class_name: purana-guttularis
# title: Purana guttularisWalker, 1858  -
# species_name: NOT FOUND
#
# class_name: purana-morrisi
# title: Purana morrisiDistant, 1892  -
# species_name: NOT FOUND
#
# class_name: purana-tigrina
# title: Purana tigrinaWalker, 1850  -
# species_name: NOT FOUND
#
# class_name: quintilia-pomponia
# title: Quintilia pomponiaDistant, 1912  -
# species_name: NOT FOUND
#
# class_name: rustia-apicata
# title: Rustia apicataDistant, 1906  -
# species_name: NOT FOUND
#
# class_name: rustia-dentivitta
# title: Rustia dentivittaWalker, 1862  -
# species_name: NOT FOUND
#
# class_name: rustia-kodagura
# title: Rustia kodaguraMarathe, Sanborn & Kunte, 2018  -
# species_name: NOT FOUND
#
# class_name: rustia-maculata
# title: Rustia maculataDistant, 1912  -
# species_name: NOT FOUND
#
# class_name: rustia-marginatus
# title: Rustia marginatusDistant, 1897  -
# species_name: NOT FOUND
#
# class_name: rustia-minuta
# title: Rustia minutaMarathe, Sanborn & Kunte, 2018  -
# species_name: NOT FOUND
#
# class_name: rustia-tigrina
# title: Rustia tigrinaDistant, 1888  -
# species_name: NOT FOUND
#
# class_name: scieroptera-crocea
# title: Scieroptera croceaGuérin-Méneville, 1838  -
# species_name: NOT FOUND
#
# class_name: scieroptera-formosana
# title: Scieroptera formosanaSchmidt, 1918  -
# species_name: NOT FOUND
#
# class_name: scieroptera-fumigata
# title: Scieroptera fumigataStål, 1854  -
# species_name: NOT FOUND
#
# class_name: scieroptera-montana
# title: Scieroptera montanaSchmidt, 1918  -
# species_name: NOT FOUND
#
# class_name: scieroptera-splendidula
# title: Scieroptera splendidulaFabricius, 1775  -
# species_name: NOT FOUND
#
# class_name: scieroptera-sumatrana
# title: Scieroptera sumatranaSchmidt, 1918  -
# species_name: NOT FOUND
#
# class_name: shaoshia-zhangi
# title: Shaoshia zhangiWei, Ahmed & Rizvi, 2010  -
# species_name: NOT FOUND
#
# class_name: subtibicina-tigris
# title: Subtibicina tigrisLee, 2012  -
# species_name: NOT FOUND
#
# class_name: sulphogaeana-sulphurea
# title: Sulphogaeana sulphureaWestwood, 1839  -
# species_name: NOT FOUND
#
# class_name: tacua-speciosa
# title: Tacua speciosaIlliger, 1800  -
# species_name: NOT FOUND
#
# class_name: talainga-binghami
# title: Talainga binghamiDistant, 1890  -
# species_name: NOT FOUND
#
# class_name: talainga-japrona
# title: Talainga japronaOllenbach, 1929  -
# species_name: NOT FOUND
#
# class_name: talainga-naga
# title: Talainga nagaOllenbach, 1929  -
# species_name: NOT FOUND
#
# class_name: tanna-bhutanensis
# title: Tanna bhutanensisDistant, 1912  -
# species_name: NOT FOUND
#
# class_name: tanna-chekiangensis
# title: Tanna chekiangensisOuchi, 1938  -
# species_name: NOT FOUND
#
# class_name: tanna-japonensis
# title: Tanna japonensisDistant, 1892  -
# species_name: NOT FOUND
#
# class_name: tanna-minor
# title: Tanna minorHayashi, 1978  -
# species_name: NOT FOUND
#
# class_name: tanna-tigroides
# title: Tanna tigroidesWalker, 1858  -
# species_name: NOT FOUND
#
# class_name: taungia-abnormis
# title: Taungia abnormisOllenbach, 1929  -
# species_name: NOT FOUND
#
# class_name: terpnosia-abdullah
# title: Terpnosia abdullahDistant, 1904  -
# species_name: NOT FOUND
#
# class_name: terpnosia-andersoni
# title: Terpnosia andersoniDistant, 1892  -
# species_name: NOT FOUND
#
# class_name: terpnosia-clio
# title: Terpnosia clioWalker, 1850  -
# species_name: NOT FOUND
#
# class_name: terpnosia-collina
# title: Terpnosia collinaDistant, 1888  -
# species_name: NOT FOUND
#
# class_name: terpnosia-confusa
# title: Terpnosia confusaDistant, 1905  -
# species_name: NOT FOUND
#
# class_name: terpnosia-elegans
# title: Terpnosia elegansKirby, 1891  -
# species_name: NOT FOUND
#
# class_name: terpnosia-ganesa
# title: Terpnosia ganesaDistant, 1904  -
# species_name: NOT FOUND
#
# class_name: terpnosia-jenkinsi
# title: Terpnosia jenkinsiDistant, 1912  -
# species_name: NOT FOUND
#
# class_name: terpnosia-lactea
# title: Terpnosia lacteaDistant, 1887  -
# species_name: NOT FOUND
#
# class_name: terpnosia-maculipes
# title: Terpnosia maculipesWalker, 1850  -
# species_name: NOT FOUND
#
# class_name: terpnosia-oberthuri
# title: Terpnosia oberthuriDistant, 1912  -
# species_name: NOT FOUND
#
# class_name: terpnosia-polei
# title: Terpnosia poleiHenry, 1931  -
# species_name: NOT FOUND
#
# class_name: terpnosia-psecas
# title: Terpnosia psecasWalker, 1850  -
# species_name: NOT FOUND
#
# class_name: terpnosia-ransonneti
# title: Terpnosia ransonnetiDistant, 1888  -
# species_name: NOT FOUND
#
# class_name: terpnosia-ridens
# title: Terpnosia ridensPringle, 1955  -
# species_name: NOT FOUND
#
# class_name: terpnosia-stipata
# title: Terpnosia stipataWalker, 1950  -
# species_name: NOT FOUND
#
# class_name: terpnosia-versicolor
# title: Terpnosia versicolorDistant, 1912  -
# species_name: NOT FOUND
#
# class_name: tettigetta-musiva
# title: Tettigetta musivaGermar, 1830  -
# species_name: NOT FOUND
#
# class_name: tibeta-zenobia
# title: Tibeta zenobiaDistant, 1912  -
# species_name: NOT FOUND
#
# class_name: tibicina-casyapae
# title: Tibicina casyapaeDistant, 1888  -
# species_name: NOT FOUND
#
# class_name: tibicina-reticulata
# title: Tibicina reticulataDistant, 1888  -
# species_name: NOT FOUND
#
# class_name: tosena-albata
# title: Tosena albataDistant, 1878  -
# species_name: NOT FOUND
#
# class_name: tosena-dives
# title: Tosena divesWestwood, 1842  -
# species_name: NOT FOUND
#
# class_name: tosena-mearesiana
# title: Tosena mearesianaWestwood, 1842  -
# species_name: NOT FOUND
#
# class_name: tosena-melanoptera
# title: Tosena melanopteraWhite, 1846  -
# species_name: NOT FOUND
#
# class_name: unduncus-connexa
# title: Unduncus connexaDistant, 1910  -
# species_name: NOT FOUND
#
# class_name: zouga-fornicata
# title: Zouga fornicataLinnaeus, 1758  -
# species_name: NOT FOUND

# %%
# replace unicodes 

import json

for class_name, details in class_details.items():
    if 'name' in details:
        # details['name'] = re.sub("\\u2019", "'", details['name'])
        for unicode in range(0, 9999):
            details['name'] = re.sub(f"\\u{unicode:04}", f"\\u{unicode:04}".encode().decode("unicode_escape"), details['name'])

# %%
import json

with open(class_details_json_path, "w", encoding="utf-8") as file:
        json.dump(class_details, file, indent=4)

# %% [markdown]
# # Fetch image urls

# %%
import json

# read json
with open(class_details_json_path, "r", encoding="utf-8") as file:
    class_details = json.load(file)

# %%
for class_name, _ in classes.items():
    if class_name not in class_details and not class_name.endswith(early_stage_suffix):
        class_details[class_name] = {}

# %%
max_images = 10

for class_name, data in class_details.items():
    try:
        if 'images' in class_details[class_name]:
            continue
        print(f"processing {class_name}")
        early_class_name = class_name + early_stage_suffix
        url = f"{website_url}/{class_name}"
        response = requests.get(url, timeout=page_timeout)
        soup = BeautifulSoup(response.text, 'html.parser')
        img_tags = soup.find_all('img')
        for img in img_tags:
            if 'images' in class_details[class_name] and len(class_details[class_name]['images']) >= max_images:
                break
            if early_class_name in class_details:
                if 'images' in class_details[early_class_name] and len(class_details[early_class_name]['images']) >= max_images:
                    break
            img_url = img.get('src')
            if has_parent_with_prop(img, 'id', 'laraval', 5):
                continue
            if img_url:
                img_url = urljoin(url, img_url)
                img_name = img_url.split("/")[-1]
                if re.search(ignore_image_regex, img_name):
                    continue
                if has_parent_with_prop(img, 'id', 'early', 6):
                    if 'images' not in class_details[early_class_name]:
                        class_details[early_class_name]['images'] = []
                    if len(class_details[early_class_name]['images']) < max_images:
                        class_details[early_class_name]['images'] += [img_url]
                else:
                    if 'images' not in class_details[class_name]:
                        class_details[class_name]['images'] = []
                    if len(class_details[class_name]['images']) < max_images:
                        class_details[class_name]['images'] += [img_url]
        with open(class_details_json_path, "w", encoding="utf-8") as file:
            json.dump(class_details, file, indent=4)
    except Exception:
        print("ERROR")
# Out:
# processing becquartina-goera
# processing abricta-brunnea
# processing abricta-pusilla
# processing abroma-apicalis
# processing balinta-pulchella
# processing balinta-sanguiniventris
# processing birrima-varians
# processing calcagninus-divaricatus
# processing calcagninus-nilgirensis
# processing callogaeana-annamensis
# processing champaka-abdulla
# processing champaka-spinosa
# processing chremistica-bimaculata
# processing chremistica-germana
# processing chremistica-mixta
# processing chremistica-nigra
# processing chremistica-ochracea
# processing chremistica-tridentigera
# processing chremistica-viridis
# processing cicada-complex
# processing cicada-conspurcata
# processing cicada-olivierana
# processing cicada-orni
# processing cicadatra-anoea
# processing cicadatra-gingat
# processing cicadatra-intermedia
# processing cicadatra-karachiensis
# processing cicadatra-minuta
# processing cicadatra-raja
# processing cicadatra-walkeri
# processing cicadetta-inglisi
# processing cicadetta-intermedia
# processing cicadetta-minuta
# processing cryptotympana-aquila
# processing cryptotympana-atrata
# processing cryptotympana-auropilosa
# processing cryptotympana-edwardsi
# processing cryptotympana-facialis
# processing cryptotympana-holsti
# processing cryptotympana-mandarina
# processing cryptotympana-takasagona
# processing cryptotympana-timorica
# processing cryptotympana-varicolor
# processing diceroprocta-semicincta
# processing dundubia-ensifera
# processing dundubia-laterocurvata
# processing dundubia-myitkyinensis
# processing dundubia-vaginata
# processing emathia-aegrota
# processing emathia-dup-aegrota
# processing eopycna-himalayana
# processing eopycna-minor
# processing eopycna-montana
# processing eopycna-spp
# processing eopycna-verna
# processing gaeana-consors
# processing hamza-ciliaris
# processing haphsa-bindusara
# processing haphsa-karenensis
# processing haphsa-stellata
# processing huechys-beata
# processing huechys-haematica
# processing huechys-phaenicura
# processing huechys-thoracica
# processing hyalessa-expansa-0
# processing hyalessa-melanoptera
# processing hyalessa-melanoptera-0
# processing hyalessa-stratoria
# processing hyalessa-stratoria-0
# processing hyalessa-virescens
# processing karenia-ravida
# processing khimbya-cuneata
# processing kumanga-sandaracata
# processing linguacicada-continuata
# processing macrosemia-tonkiniana
# processing mata-rama
# processing maua-quadrituberculata
# processing megapomponia-imperatoria
# processing meimuna-gamameda
# processing meimuna-pallida
# processing meimuna-tavoyana
# processing meimuna-velitaris
# processing melampsalta-mogannia
# processing mogannia-aurea
# processing mogannia-conica
# processing mogannia-hebes
# processing mogannia-nasalis
# processing mogannia-spurcata
# processing mogannia-venutissima
# processing mogannia-viridis
# processing nabalua-mascula
# processing neotanna-thalia
# processing orientopsaltria-beaudouini
# processing panka-simulata
# processing paratanna-parata
# processing platylomia-juno
# processing platylomia-lemoultii
# processing platylomia-malickyi
# processing platypleura-inglisi
# processing platypleura-intermedia
# processing platypleura-nigrosignata
# processing platypleura-stridula
# processing platypleura-takasagona
# processing platypleura-testacea
# processing platypleura-westwoodi
# processing polyneura-laevigata
# processing pomponia-adusta
# processing pomponia-picta
# processing pomponia-secreta
# processing pomponia-zebra
# processing proarna-hilaris
# processing proarna-shaoshia
# processing psalmocharias-balochii
# processing psalmocharias-chitralensis
# processing psalmocharias-gizarensis
# processing psalmocharias-japokensis
# processing psalmocharias-paliur
# processing psalmocharias-querula
# processing scieroptera-crocea
# processing scieroptera-formosana
# processing scieroptera-montana
# processing scieroptera-sumatrana
# processing shaoshia-zhangi
# processing subtibicina-tigris
# processing tacua-speciosa
# processing talainga-japrona
# processing talainga-naga
# processing tanna-chekiangensis
# processing tanna-japonensis
# processing tanna-minor
# processing taungia-abnormis
# processing terpnosia-abdullah
# processing terpnosia-elegans
# processing terpnosia-lactea
# processing terpnosia-polei
# processing terpnosia-psecas
# processing tettigetta-musiva
# processing unduncus-connexa
# processing zouga-fornicata

# %%
import json

# read json
with open(class_details_json_path, "r", encoding="utf-8") as file:
    class_details = json.load(file)
# remove duplicates
for class_name, data in class_details.items():
    if 'images' in data:
        data['images'] = list(set(data['images']))
# dump json
with open(class_details_json_path, "w", encoding="utf-8") as file:
    json.dump(class_details, file, indent=4)

# %%
import json

# read json
with open(class_details_json_path, "r", encoding="utf-8") as file:
    class_details = json.load(file)
# remove bad images
bad_image_regex = r"(?i).*(butterfliy_5\.jpg).*"
for class_name, data in class_details.items():
    if 'images' in data:
        data['images'] = [ image for image in data['images'] if not re.match(bad_image_regex, image) ]
# dump json
with open(class_details_json_path, "w", encoding="utf-8") as file:
    json.dump(class_details, file, indent=4)

# %% [markdown]
# # Count

# %%
early_regex = r"^.*-(early)$"
unidentified_regex = r"^.*-(spp|genera|genera-spp)$"
early_or_unidentified_regex = r"^.*-(early|spp|genera|genera-spp)$"
classes = { class_dir: len([ img for img in os.listdir(f"{dataset_dir}/{class_dir}") ]) for class_dir in os.listdir(f"{dataset_dir}") }
early_classes = { class_name: count for class_name, count in classes.items() if re.match(early_regex, class_name) }
unidentified_classes = { class_name: count for class_name, count in classes.items() if re.match(unidentified_regex, class_name) }
print(f"Total Class count : {len(classes):6} ( Unidentified: {len(unidentified_classes):6} / Early-stage: {len(early_classes):6} / Identified-adult: {len(classes) - len(unidentified_classes) - len(early_classes):6} )")
print(f"Total  Data count : {sum(classes.values()):6} ( Unidentified: {sum(unidentified_classes.values()):6} / Early-stage: {sum(early_classes.values()):6} / Identified-adult: {sum(classes.values()) - sum(unidentified_classes.values()) - sum(early_classes.values()):6} )")
# Out:
# Total Class count :    308 ( Unidentified:      1 / Early-stage:      7 / Identified-adult:    300 )
# Total  Data count :   1019 ( Unidentified:      0 / Early-stage:     25 / Identified-adult:    994 )

# %%
empty_classes = [ class_dir for class_dir in os.listdir(f"{dataset_dir}") if not os.listdir(f"{dataset_dir}/{class_dir}") ]
print (f"Empty classes: {len(empty_classes)}")
# Out:
# Empty classes: 139
