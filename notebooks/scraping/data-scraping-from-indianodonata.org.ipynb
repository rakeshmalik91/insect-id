# %%
import os
import sys

# Standardize working directory to project root
try:
    if os.path.basename(os.getcwd()) in ['modeling', 'scraping', 'data-prep', 'analysis', 'setup', 'misc']:
        os.chdir('../..')
    elif os.path.basename(os.getcwd()) == 'notebooks':
        os.chdir('..')
        
    if os.getcwd() not in sys.path:
        sys.path.append(os.getcwd())
        
    print(f"Working Directory set to: {os.getcwd()}")
except Exception as e:
    print(f"Failed to set working directory: {e}")

# %%
# !pip install torch torchvision
# !pip install matplotlib pandas scikit-learn
# !pip install pillow
# !pip install opencv-python

# %%
import sys
directory = ".."
sys.path.append(directory)

# %% [markdown]
# # Scrape https://www.indianodonata.org for butterfly dataset

# %%
dataset_dir = "insect-dataset/src/indianodonata.org"
class_details_json_path = "insect-dataset/src/class_details.indianodonata.org.json"

website_url = "https://www.indianodonata.org"
initial_path = "/odonata"
first_page = 0
last_page = 26

batch_size = 3
max_workers = 50
page_timeout = 120
image_timeout = 30

ignore_image_regex = r"^(imgs10|.*(iucn-red-list|mobileapp|butterfliesofurbangreeneries|webheader|headerlogo|WPA-[IVX]+).*)\.(png|jpg|jpeg)$"
skip_downloaded_species = False

early_stage_suffix = '-early'

# %%
import os
import re
import requests
from bs4 import BeautifulSoup
from urllib.parse import urljoin
import threading
from concurrent.futures import ThreadPoolExecutor

def log_header():
    return f"[ {threading.current_thread().name:24} ]  "

def download_image(img_url, output_dir):
    try:
        img_data = requests.get(img_url, timeout=image_timeout).content
        img_name = img_url.split("/")[-1]
        img_path = os.path.join(output_dir, img_name)
        with open(img_path, 'wb') as file:
            file.write(img_data)
        return True
    except Exception as e:
        # print(f"{log_header()}{e}")
        return False

def has_parent_with_prop(tag, prop, value, max_parents):
    parent = tag
    for i in range(0, max_parents):
        parent = parent.parent
        if parent.get(prop) == value:
            return True
    return False
    
def scrape_images(url, output_dir):
    try:
        print(f"{log_header()}    Scraping URL: {url}")
        response = requests.get(url, timeout=page_timeout)
        soup = BeautifulSoup(response.text, 'html.parser')
        img_tags = soup.find_all('img')
        success_cnt = 0
        failure_cnt = 0
        already_downloaded_cnt = 0
        for img in img_tags:
            img_url = img.get('src')
            if has_parent_with_prop(img, 'id', 'laraval', 5):
                # larval host plants photo
                # print (f"Ignoring larval host plants image {img_url}")
                continue
            class_suffix = ''
            if has_parent_with_prop(img, 'id', 'early', 6):
                # early stages
                # print (f"Found early stages image {img_url}")
                class_suffix = early_stage_suffix
            if img_url:
                img_url = urljoin(url, img_url)
                img_name = img_url.split("/")[-1]
                if re.search(ignore_image_regex, img_name):
                    continue
                if os.path.exists(f"{output_dir}{class_suffix}/{img_name}"):
                    already_downloaded_cnt = already_downloaded_cnt + 1
                    continue
                if not os.path.exists(output_dir+class_suffix):
                    os.makedirs(output_dir+class_suffix)
                if download_image(img_url, output_dir+class_suffix):
                    success_cnt = success_cnt + 1
                else:
                    failure_cnt = failure_cnt + 1
        if success_cnt > 0:
            print(f"{log_header()}      Downloaded {success_cnt}(+{already_downloaded_cnt}) / {success_cnt+already_downloaded_cnt+failure_cnt} image(s) in {output_dir}")
        return True
    except Exception as e:
        print(f"{log_header()}{e}")
        return False

def crawl(base_url, root, output_dir):
    try:
        url = urljoin(base_url, root)
        print(f"{log_header()}Crawling URL: {url}")
        if not os.path.exists(output_dir):
            os.makedirs(output_dir)
        response = requests.get(url, timeout=page_timeout)
        soup = BeautifulSoup(response.text, 'html.parser')
        img_tags = soup.find_all('img')
        for img in img_tags:
            img_url = img.get('src')
            if img_url:
                img_url = urljoin(url, img_url)
                # print (f"Found image {img_url}")
                img_name = img_url.split("/")[-1]
                if re.search(ignore_image_regex, img_name):
                    continue
                species_path = img.parent.parent.get('href')
                species_dir = output_dir+species_path.lower()
                if not (skip_downloaded_species and os.path.exists(species_dir) and os.path.isdir(species_dir) and os.listdir(species_dir)):
                    scrape_images(urljoin(base_url, species_path), species_dir)
        return True
    except Exception as e:
        print(f"{log_header()}{e}")
        return False

def crawl_in_batch(batch_start):
    print(f"Starting batch from page {batch_start} on thread {threading.current_thread().name}")
    for page in range(batch_start, min(batch_start+batch_size, last_page+1), 1):
        crawl(website_url, f"{initial_path}?page={page}", f"{dataset_dir}")

# %%
with ThreadPoolExecutor(max_workers=max_workers) as executor:
    futures = [executor.submit(crawl_in_batch, batch_start) for batch_start in range(first_page, last_page+1, batch_size)]
    for future in futures:
        print(f"Thread completed with result {future.result()}")

print("Scraping completed!")
# Out:
# Starting batch from page 0 on thread ThreadPoolExecutor-0_0
# [ ThreadPoolExecutor-0_0   ]  Crawling URL: https://www.indianodonata.org/odonata?page=0
# Starting batch from page 3 on thread ThreadPoolExecutor-0_1
# [ ThreadPoolExecutor-0_1   ]  Crawling URL: https://www.indianodonata.org/odonata?page=3
# Starting batch from page 6 on thread ThreadPoolExecutor-0_2
# [ ThreadPoolExecutor-0_2   ]  Crawling URL: https://www.indianodonata.org/odonata?page=6
# Starting batch from page 9 on thread ThreadPoolExecutor-0_3
# [ ThreadPoolExecutor-0_3   ]  Crawling URL: https://www.indianodonata.org/odonata?page=9
# Starting batch from page 12 on thread ThreadPoolExecutor-0_4
# [ ThreadPoolExecutor-0_4   ]  Crawling URL: https://www.indianodonata.org/odonata?page=12
# Starting batch from page 15 on thread ThreadPoolExecutor-0_5
# [ ThreadPoolExecutor-0_5   ]  Crawling URL: https://www.indianodonata.org/odonata?page=15
# Starting batch from page 18 on thread ThreadPoolExecutor-0_6
# [ ThreadPoolExecutor-0_6   ]  Crawling URL: https://www.indianodonata.org/odonata?page=18
# Starting batch from page 21 on thread ThreadPoolExecutor-0_7
# [ ThreadPoolExecutor-0_7   ]  Crawling URL: https://www.indianodonata.org/odonata?page=21
# Starting batch from page 24 on thread ThreadPoolExecutor-0_8
# [ ThreadPoolExecutor-0_8   ]  Crawling URL: https://www.indianodonata.org/odonata?page=24
# [ ThreadPoolExecutor-0_7   ]      Scraping URL: https://www.indianodonata.org/idionyx-galeata
# [ ThreadPoolExecutor-0_8   ]      Scraping URL: https://www.indianodonata.org/calicnemia-spp
# [ ThreadPoolExecutor-0_4   ]      Scraping URL: https://www.indianodonata.org/burmagomphus-sivalikensis
# [ ThreadPoolExecutor-0_1   ]      Scraping URL: https://www.indianodonata.org/anisopleura-comes
# [ ThreadPoolExecutor-0_3   ]      Scraping URL: https://www.indianodonata.org/pseudagrion-rubriceps
# [ ThreadPoolExecutor-0_6   ]      Scraping URL: https://www.indianodonata.org/indothemis-limbata
# [ ThreadPoolExecutor-0_0   ]      Scraping URL: https://www.indianodonata.org/indolestes-cyaneus
# [ ThreadPoolExecutor-0_2   ]      Scraping URL: https://www.indianodonata.org/prodasineura-odoneli
# [ ThreadPoolExecutor-0_5   ]      Scraping URL: https://www.indianodonata.org/platygomphus-dolabratus
# [ ThreadPoolExecutor-0_8   ]      Scraping URL: https://www.indianodonata.org/gynacantha-spp
# [ ThreadPoolExecutor-0_5   ]      Scraping URL: https://www.indianodonata.org/stylogomphus-inglisi
# [ ThreadPoolExecutor-0_0   ]      Scraping URL: https://www.indianodonata.org/lestes-praemorsus
# [ ThreadPoolExecutor-0_7   ]      Scraping URL: https://www.indianodonata.org/idionyx-gomantakensis
# [ ThreadPoolExecutor-0_2   ]      Scraping URL: https://www.indianodonata.org/prodasineura-verticalis
# [ ThreadPoolExecutor-0_6   ]      Scraping URL: https://www.indianodonata.org/lathrecista-asiatica
# [ ThreadPoolExecutor-0_4   ]      Scraping URL: https://www.indianodonata.org/cyclogomphus-heterostylus
# [ ThreadPoolExecutor-0_8   ]      Scraping URL: https://www.indianodonata.org/lestes-spp
# [ ThreadPoolExecutor-0_1   ]      Scraping URL: https://www.indianodonata.org/anisopleura-lestoides
# [ ThreadPoolExecutor-0_2   ]      Scraping URL: https://www.indianodonata.org/onychargia-atrocyana
# [ ThreadPoolExecutor-0_3   ]      Scraping URL: https://www.indianodonata.org/pseudagrion-spencei
# [ ThreadPoolExecutor-0_7   ]      Scraping URL: https://www.indianodonata.org/idionyx-imbricata
# [ ThreadPoolExecutor-0_0   ]      Scraping URL: https://www.indianodonata.org/ceriagrion-coromandelianum
# [ ThreadPoolExecutor-0_6   ]      Scraping URL: https://www.indianodonata.org/libellula-quadrimaculata
# [ ThreadPoolExecutor-0_5   ]      Scraping URL: https://www.indianodonata.org/watanabeopetalia-atkinsoni
# [ ThreadPoolExecutor-0_4   ]      Scraping URL: https://www.indianodonata.org/cyclogomphus-vesiculosus
# [ ThreadPoolExecutor-0_0   ]      Scraping URL: https://www.indianodonata.org/megalestes-irma
# [ ThreadPoolExecutor-0_8   ]      Scraping URL: https://www.indianodonata.org/esme-spp
# [ ThreadPoolExecutor-0_6   ]      Scraping URL: https://www.indianodonata.org/lyriothemis-acigastra
# [ ThreadPoolExecutor-0_2   ]      Scraping URL: https://www.indianodonata.org/onychargia-indica
# [ ThreadPoolExecutor-0_1   ]      Scraping URL: https://www.indianodonata.org/anisopleura-subplatystyla
# [ ThreadPoolExecutor-0_7   ]      Scraping URL: https://www.indianodonata.org/idionyx-intricata
# [ ThreadPoolExecutor-0_3   ]      Scraping URL: https://www.indianodonata.org/epiophlebia-laidlawi
# [ ThreadPoolExecutor-0_4   ]      Scraping URL: https://www.indianodonata.org/cyclogomphus-wilkinsi
# [ ThreadPoolExecutor-0_5   ]      Scraping URL: https://www.indianodonata.org/chlorogomphus-brevistigma
# [ ThreadPoolExecutor-0_6   ]      Scraping URL: https://www.indianodonata.org/lyriothemis-bivittata
# [ ThreadPoolExecutor-0_2   ]      Scraping URL: https://www.indianodonata.org/pseudocopera-ciliata
# [ ThreadPoolExecutor-0_1   ]      Scraping URL: https://www.indianodonata.org/anisopleura-vallei
# [ ThreadPoolExecutor-0_0   ]      Scraping URL: https://www.indianodonata.org/megalestes-major
# [ ThreadPoolExecutor-0_8   ]      Scraping URL: https://www.indianodonata.org/lyriothemis-spp
# [ ThreadPoolExecutor-0_7   ]      Scraping URL: https://www.indianodonata.org/idionyx-minima
# [ ThreadPoolExecutor-0_3   ]      Scraping URL: https://www.indianodonata.org/aeshna-juncea
# [ ThreadPoolExecutor-0_4   ]      Scraping URL: https://www.indianodonata.org/cyclogomphus-ypsilon
# [ ThreadPoolExecutor-0_5   ]      Scraping URL: https://www.indianodonata.org/chlorogomphus-campioni
# [ ThreadPoolExecutor-0_6   ]      Scraping URL: https://www.indianodonata.org/lyriothemis-cleis
# [ ThreadPoolExecutor-0_0   ]      Scraping URL: https://www.indianodonata.org/indolestes-gracilis
# [ ThreadPoolExecutor-0_1   ]      Scraping URL: https://www.indianodonata.org/bayadera-hyalina
# [ ThreadPoolExecutor-0_2   ]      Scraping URL: https://www.indianodonata.org/copera-marginipes
# [ ThreadPoolExecutor-0_3   ]      Scraping URL: https://www.indianodonata.org/aeshna-mixta
# [ ThreadPoolExecutor-0_8   ]      Scraping URL: https://www.indianodonata.org/pseudagrion-spp
# [ ThreadPoolExecutor-0_7   ]      Scraping URL: https://www.indianodonata.org/idionyx-nadganiensis
# [ ThreadPoolExecutor-0_4   ]      Scraping URL: https://www.indianodonata.org/davidioides-martini
# [ ThreadPoolExecutor-0_0   ]      Scraping URL: https://www.indianodonata.org/indolestes-indicus
# [ ThreadPoolExecutor-0_6   ]      Scraping URL: https://www.indianodonata.org/lyriothemis-tricolor
# [ ThreadPoolExecutor-0_5   ]      Scraping URL: https://www.indianodonata.org/chlorogomphus-fraseri
# [ ThreadPoolExecutor-0_2   ]      Scraping URL: https://www.indianodonata.org/pseudocopera-superplatypes
# [ ThreadPoolExecutor-0_3   ]      Scraping URL: https://www.indianodonata.org/aeshna-petalura
# [ ThreadPoolExecutor-0_1   ]      Scraping URL: https://www.indianodonata.org/bayadera-indica
# [ ThreadPoolExecutor-0_8   ]      Scraping URL: https://www.indianodonata.org/copera-spp
# [ ThreadPoolExecutor-0_7   ]      Scraping URL: https://www.indianodonata.org/idionyx-nilgiriensis
# [ ThreadPoolExecutor-0_4   ]      Scraping URL: https://www.indianodonata.org/davidius-aberrans
# [ ThreadPoolExecutor-0_6   ]      Scraping URL: https://www.indianodonata.org/macrodiplax-cora
# [ ThreadPoolExecutor-0_5   ]      Scraping URL: https://www.indianodonata.org/chlorogomphus-mortoni
# [ ThreadPoolExecutor-0_1   ]      Scraping URL: https://www.indianodonata.org/bayadera-kali
# [ ThreadPoolExecutor-0_0   ]      Scraping URL: https://www.indianodonata.org/lestes-barbarus
# [ ThreadPoolExecutor-0_3   ]      Scraping URL: https://www.indianodonata.org/aeshna-donaldi
# [ ThreadPoolExecutor-0_2   ]      Scraping URL: https://www.indianodonata.org/copera-vittata
# [ ThreadPoolExecutor-0_8   ]      Scraping URL: https://www.indianodonata.org/sympetrum-spp
# [ ThreadPoolExecutor-0_7   ]      Scraping URL: https://www.indianodonata.org/idionyx-optata
# [ ThreadPoolExecutor-0_4   ]      Scraping URL: https://www.indianodonata.org/davidius-davidii
# [ ThreadPoolExecutor-0_5   ]      Scraping URL: https://www.indianodonata.org/chloropetalia-olympicus
# [ ThreadPoolExecutor-0_6   ]      Scraping URL: https://www.indianodonata.org/nannophya-pygmaea
# [ ThreadPoolExecutor-0_1   ]      Scraping URL: https://www.indianodonata.org/bayadera-longicauda
# [ ThreadPoolExecutor-0_0   ]      Scraping URL: https://www.indianodonata.org/lestes-concinnus
# [ ThreadPoolExecutor-0_8   ]      Scraping URL: https://www.indianodonata.org/caconeura-spp
# [ ThreadPoolExecutor-0_2   ]      Scraping URL: https://www.indianodonata.org/aciagrion-approximans
# [ ThreadPoolExecutor-0_3   ]      Scraping URL: https://www.indianodonata.org/anaciaeschna-jaspidea
# [ ThreadPoolExecutor-0_7   ]      Scraping URL: https://www.indianodonata.org/idionyx-periyashola
# [ ThreadPoolExecutor-0_4   ]      Scraping URL: https://www.indianodonata.org/davidius-kumaonensis[ ThreadPoolExecutor-0_6   ]      Scraping URL: https://www.indianodonata.org/nesoxenia-lineata
#
# [ ThreadPoolExecutor-0_5   ]      Scraping URL: https://www.indianodonata.org/chlorogomphus-preciosus
# [ ThreadPoolExecutor-0_0   ]      Scraping URL: https://www.indianodonata.org/lestes-dorothea
# [ ThreadPoolExecutor-0_1   ]      Scraping URL: https://www.indianodonata.org/dysphaea-ethela
# [ ThreadPoolExecutor-0_2   ]      Scraping URL: https://www.indianodonata.org/aciagrion-azureum
# [ ThreadPoolExecutor-0_7   ]      Scraping URL: https://www.indianodonata.org/idionyx-rhinoceroides
# [ ThreadPoolExecutor-0_8   ]      Scraping URL: https://www.indianodonata.org/paragomphus-capricornis
# [ ThreadPoolExecutor-0_3   ]      Scraping URL: https://www.indianodonata.org/anax-guttatus
# [ ThreadPoolExecutor-0_5   ]      Scraping URL: https://www.indianodonata.org/chlorogomphus-schmidti
# [ ThreadPoolExecutor-0_6   ]      Scraping URL: https://www.indianodonata.org/neurothemis-fluctuans
# [ ThreadPoolExecutor-0_4   ]      Scraping URL: https://www.indianodonata.org/davidius-malloryi
# [ ThreadPoolExecutor-0_1   ]      Scraping URL: https://www.indianodonata.org/dysphaea-walli
# [ ThreadPoolExecutor-0_0   ]      Scraping URL: https://www.indianodonata.org/lestes-elatus
# [ ThreadPoolExecutor-0_8   ]      Scraping URL: https://www.indianodonata.org/burmagomphus-chaukulensis
# [ ThreadPoolExecutor-0_2   ]      Scraping URL: https://www.indianodonata.org/aciagrion-hisopa
# [ ThreadPoolExecutor-0_3   ]      Scraping URL: https://www.indianodonata.org/anax-immaculifrons
# [ ThreadPoolExecutor-0_7   ]      Scraping URL: https://www.indianodonata.org/idionyx-saffronata
# [ ThreadPoolExecutor-0_5   ]      Scraping URL: https://www.indianodonata.org/chloropetalia-selysi
# [ ThreadPoolExecutor-0_6   ]      Scraping URL: https://www.indianodonata.org/neurothemis-fulvia
# [ ThreadPoolExecutor-0_4   ]      Scraping URL: https://www.indianodonata.org/davidius-zallorensis
# [ ThreadPoolExecutor-0_1   ]      Scraping URL: https://www.indianodonata.org/epallage-fatime
# [ ThreadPoolExecutor-0_8   ]      Scraping URL: https://www.indianodonata.org/ischnura-spp
# [ ThreadPoolExecutor-0_2   ]      Scraping URL: https://www.indianodonata.org/aciagrion-occidentale
# [ ThreadPoolExecutor-0_7   ]      Scraping URL: https://www.indianodonata.org/idionyx-stevensi
# [ ThreadPoolExecutor-0_0   ]      Scraping URL: https://www.indianodonata.org/lestes-garoensis
# [ ThreadPoolExecutor-0_3   ]      Scraping URL: https://www.indianodonata.org/anax-imperator
# [ ThreadPoolExecutor-0_6   ]      Scraping URL: https://www.indianodonata.org/neurothemis-intermedia
# [ ThreadPoolExecutor-0_5   ]      Scraping URL: https://www.indianodonata.org/chlorogomphus-xanthoptera
# [ ThreadPoolExecutor-0_4   ]      Scraping URL: https://www.indianodonata.org/dubitogomphus-bidentatus[ ThreadPoolExecutor-0_1   ]      Scraping URL: https://www.indianodonata.org/euphaea-cardinalis
#
# [ ThreadPoolExecutor-0_8   ]      Scraping URL: https://www.indianodonata.org/aristocypha-spp
# [ ThreadPoolExecutor-0_3   ]      Scraping URL: https://www.indianodonata.org/anax-indicus
# [ ThreadPoolExecutor-0_0   ]      Scraping URL: https://www.indianodonata.org/lestes-malabaricus
# [ ThreadPoolExecutor-0_7   ]      Scraping URL: https://www.indianodonata.org/idionyx-travancorensis
# [ ThreadPoolExecutor-0_2   ]      Scraping URL: https://www.indianodonata.org/aciagrion-olympicum
# [ ThreadPoolExecutor-0_5   ]      Scraping URL: https://www.indianodonata.org/anotogaster-basalis
# [ ThreadPoolExecutor-0_6   ]      Scraping URL: https://www.indianodonata.org/onychothemis-testacea
# [ ThreadPoolExecutor-0_4   ]      Scraping URL: https://www.indianodonata.org/gomphidia-kodaguensis
# [ ThreadPoolExecutor-0_1   ]      Scraping URL: https://www.indianodonata.org/euphaea-dispar
# [ ThreadPoolExecutor-0_3   ]      Scraping URL: https://www.indianodonata.org/anax-nigrolineatus
# [ ThreadPoolExecutor-0_8   ]      Scraping URL: https://www.indianodonata.org/aeshna-spp
# [ ThreadPoolExecutor-0_7   ]      Scraping URL: https://www.indianodonata.org/macromidia-donaldi
# [ ThreadPoolExecutor-0_0   ]      Scraping URL: https://www.indianodonata.org/lestes-nigriceps
# [ ThreadPoolExecutor-0_2   ]      Scraping URL: https://www.indianodonata.org/aciagrion-pallidum
# [ ThreadPoolExecutor-0_5   ]      Scraping URL: https://www.indianodonata.org/anotogaster-nipalensis
# [ ThreadPoolExecutor-0_6   ]      Scraping URL: https://www.indianodonata.org/orthetrum-anceps
# [ ThreadPoolExecutor-0_4   ]      Scraping URL: https://www.indianodonata.org/gomphidia-t-nigrum
# [ ThreadPoolExecutor-0_3   ]      Scraping URL: https://www.indianodonata.org/anax-parthenope
# [ ThreadPoolExecutor-0_1   ]      Scraping URL: https://www.indianodonata.org/euphaea-fraseri
# [ ThreadPoolExecutor-0_7   ]      Scraping URL: https://www.indianodonata.org/merogomphus-tamaracherriensis
# [ ThreadPoolExecutor-0_0   ]      Scraping URL: https://www.indianodonata.org/lestes-nodalis
# [ ThreadPoolExecutor-0_8   ]      Scraping URL: https://www.indianodonata.org/crocothemis-spp
# [ ThreadPoolExecutor-0_2   ]      Scraping URL: https://www.indianodonata.org/aciagrion-tillyardi
# [ ThreadPoolExecutor-0_6   ]      Scraping URL: https://www.indianodonata.org/orthetrum-brunneum
# [ ThreadPoolExecutor-0_5   ]      Scraping URL: https://www.indianodonata.org/cordulegaster-brevistigma
# [ ThreadPoolExecutor-0_4   ]      Scraping URL: https://www.indianodonata.org/heliogomphus-kalarensis
# [ ThreadPoolExecutor-0_3   ]      Scraping URL: https://www.indianodonata.org/anax-panybeus
# [ ThreadPoolExecutor-0_7   ]      Scraping URL: https://www.indianodonata.org/platycnemis-dealbata
# [ ThreadPoolExecutor-0_1   ]      Scraping URL: https://www.indianodonata.org/euphaea-masoni
# [ ThreadPoolExecutor-0_0   ]      Scraping URL: https://www.indianodonata.org/lestes-patricia
# [ ThreadPoolExecutor-0_2   ]      Scraping URL: https://www.indianodonata.org/agriocnemis-clauseni
# [ ThreadPoolExecutor-0_8   ]      Scraping URL: https://www.indianodonata.org/idionyx-spp
# [ ThreadPoolExecutor-0_6   ]      Scraping URL: https://www.indianodonata.org/orthetrum-cancellatum
# [ ThreadPoolExecutor-0_5   ]      Scraping URL: https://www.indianodonata.org/cordulegaster-parvistigma
# [ ThreadPoolExecutor-0_1   ]      Scraping URL: https://www.indianodonata.org/euphaea-ochracea
# [ ThreadPoolExecutor-0_3   ]      Scraping URL: https://www.indianodonata.org/cephalaeschna-acutifrons
# [ ThreadPoolExecutor-0_7   ]      Scraping URL: https://www.indianodonata.org/heliocypha-bisignata
# [ ThreadPoolExecutor-0_4   ]      Scraping URL: https://www.indianodonata.org/heliogomphus-promelas
# [ ThreadPoolExecutor-0_8   ]      Scraping URL: https://www.indianodonata.org/aciagrion-spp
# [ ThreadPoolExecutor-0_2   ]      Scraping URL: https://www.indianodonata.org/agriocnemis-corbeti
# [ ThreadPoolExecutor-0_6   ]      Scraping URL: https://www.indianodonata.org/orthetrum-chrysis
# [ ThreadPoolExecutor-0_5   ]      Scraping URL: https://www.indianodonata.org/neallogaster-annandalei
# [ ThreadPoolExecutor-0_3   ]      Scraping URL: https://www.indianodonata.org/cephalaeschna-klapperichi
# [ ThreadPoolExecutor-0_1   ]      Scraping URL: https://www.indianodonata.org/schmidtiphaea-chittaranjani
# [ ThreadPoolExecutor-0_7   ]      Scraping URL: https://www.indianodonata.org/neurothemis-ramburi
# [ ThreadPoolExecutor-0_4   ]      Scraping URL: https://www.indianodonata.org/heliogomphus-selysi
# [ ThreadPoolExecutor-0_2   ]      Scraping URL: https://www.indianodonata.org/agriocnemis-dabreui
# [ ThreadPoolExecutor-0_8   ]      Scraping URL: https://www.indianodonata.org/agriocnemis-spp
# [ ThreadPoolExecutor-0_0   ]      Scraping URL: https://www.indianodonata.org/platylestes-platystylus
# [ ThreadPoolExecutor-0_6   ]      Scraping URL: https://www.indianodonata.org/orthetrum-glaucum
# [ ThreadPoolExecutor-0_5   ]      Scraping URL: https://www.indianodonata.org/neallogaster-hermionae
# [ ThreadPoolExecutor-0_3   ]      Scraping URL: https://www.indianodonata.org/cephalaeschna-masoni
# [ ThreadPoolExecutor-0_1   ]      Scraping URL: https://www.indianodonata.org/schmidtiphaea-schmidi
# [ ThreadPoolExecutor-0_7   ]      Scraping URL: https://www.indianodonata.org/neurothemis-tullia
# [ ThreadPoolExecutor-0_4   ]      Scraping URL: https://www.indianodonata.org/heliogomphus-spirillus
# [ ThreadPoolExecutor-0_8   ]      Scraping URL: https://www.indianodonata.org/ictinogomphus-spp
# [ ThreadPoolExecutor-0_2   ]      Scraping URL: https://www.indianodonata.org/agriocnemis-femina
# [ ThreadPoolExecutor-0_0   ]      Scraping URL: https://www.indianodonata.org/lestes-thoracicus
# [ ThreadPoolExecutor-0_5   ]      Scraping URL: https://www.indianodonata.org/neallogaster-latifrons
# [ ThreadPoolExecutor-0_6   ]      Scraping URL: https://www.indianodonata.org/orthetrum-internum
# [ ThreadPoolExecutor-0_1   ]      Scraping URL: https://www.indianodonata.org/burmargiolestes-laidlawi
# [ ThreadPoolExecutor-0_4   ]      Scraping URL: https://www.indianodonata.org/ictinogomphus-angulosus[ ThreadPoolExecutor-0_3   ]      Scraping URL: https://www.indianodonata.org/cephalaeschna-orbifrons
#
# [ ThreadPoolExecutor-0_8   ]      Scraping URL: https://www.indianodonata.org/planaeschna-spp
# [ ThreadPoolExecutor-0_0   ]      Scraping URL: https://www.indianodonata.org/lestes-viridulus
# [ ThreadPoolExecutor-0_2   ]      Scraping URL: https://www.indianodonata.org/agriocnemis-keralensis
# [ ThreadPoolExecutor-0_7   ]      Scraping URL: https://www.indianodonata.org/protosticta-ponmudiensis
# [ ThreadPoolExecutor-0_5   ]      Scraping URL: https://www.indianodonata.org/neallogaster-ornata
# [ ThreadPoolExecutor-0_6   ]      Scraping URL: https://www.indianodonata.org/orthetrum-luzonicum
# [ ThreadPoolExecutor-0_4   ]      Scraping URL: https://www.indianodonata.org/ictinogomphus-atrox
# [ ThreadPoolExecutor-0_1   ]      Scraping URL: https://www.indianodonata.org/philoganga-montana
# [ ThreadPoolExecutor-0_0   ]      Scraping URL: https://www.indianodonata.org/sympecma-paedisca
# [ ThreadPoolExecutor-0_7   ]      Scraping URL: https://www.indianodonata.org/agriocnemis-kalinga
# [ ThreadPoolExecutor-0_8   ]      Scraping URL: https://www.indianodonata.org/bayadera-spp
# [ ThreadPoolExecutor-0_3   ]      Scraping URL: https://www.indianodonata.org/cephalaeschna-viridifrons
# [ ThreadPoolExecutor-0_2   ]      Scraping URL: https://www.indianodonata.org/agriocnemis-lacteola
# [ ThreadPoolExecutor-0_5   ]      Scraping URL: https://www.indianodonata.org/neallogaster-schmidti
# [ ThreadPoolExecutor-0_6   ]  Crawling URL: https://www.indianodonata.org/odonata?page=19
# [ ThreadPoolExecutor-0_1   ]      Scraping URL: https://www.indianodonata.org/calicnemia-doonensis
# [ ThreadPoolExecutor-0_4   ]      Scraping URL: https://www.indianodonata.org/ictinogomphus-distinctus
# [ ThreadPoolExecutor-0_0   ]      Scraping URL: https://www.indianodonata.org/indosticta-deccanensis
# [ ThreadPoolExecutor-0_3   ]      Scraping URL: https://www.indianodonata.org/gynacantha-albistyla
# [ ThreadPoolExecutor-0_8   ]  Crawling URL: https://www.indianodonata.org/odonata?page=25
# [ ThreadPoolExecutor-0_7   ]  Crawling URL: https://www.indianodonata.org/odonata?page=22
# [ ThreadPoolExecutor-0_2   ]  Crawling URL: https://www.indianodonata.org/odonata?page=7
# [ ThreadPoolExecutor-0_6   ]      Scraping URL: https://www.indianodonata.org/orthetrum-martensi
# [ ThreadPoolExecutor-0_5   ]  Crawling URL: https://www.indianodonata.org/odonata?page=16
# [ ThreadPoolExecutor-0_2   ]      Scraping URL: https://www.indianodonata.org/agriocnemis-nana
# [ ThreadPoolExecutor-0_8   ]      Scraping URL: https://www.indianodonata.org/protosticta-spp
# [ ThreadPoolExecutor-0_7   ]      Scraping URL: https://www.indianodonata.org/lyriothemis-mortoni
# [ ThreadPoolExecutor-0_1   ]  Crawling URL: https://www.indianodonata.org/odonata?page=4
# [ ThreadPoolExecutor-0_0   ]  Crawling URL: https://www.indianodonata.org/odonata?page=1
# [ ThreadPoolExecutor-0_4   ]  Crawling URL: https://www.indianodonata.org/odonata?page=13
# [ ThreadPoolExecutor-0_3   ]  Crawling URL: https://www.indianodonata.org/odonata?page=10
# [ ThreadPoolExecutor-0_5   ]      Scraping URL: https://www.indianodonata.org/epophthalmia-frontalis
# [ ThreadPoolExecutor-0_6   ]      Scraping URL: https://www.indianodonata.org/orthetrum-pruinosum
# [ ThreadPoolExecutor-0_1   ]      Scraping URL: https://www.indianodonata.org/calicnemia-erythromelas
# [ ThreadPoolExecutor-0_0   ]      Scraping URL: https://www.indianodonata.org/drepanosticta-annandalei
# [ ThreadPoolExecutor-0_4   ]      Scraping URL: https://www.indianodonata.org/ictinogomphus-kishori
# [ ThreadPoolExecutor-0_3   ]      Scraping URL: https://www.indianodonata.org/gynacantha-andamanae
# [ ThreadPoolExecutor-0_2   ]      Scraping URL: https://www.indianodonata.org/agriocnemis-pieris
# [ ThreadPoolExecutor-0_7   ]      Scraping URL: https://www.indianodonata.org/calicnemia-nipalica
# [ ThreadPoolExecutor-0_8   ]      Scraping URL: https://www.indianodonata.org/macrogomphus-spp
# [ ThreadPoolExecutor-0_6   ]      Scraping URL: https://www.indianodonata.org/orthetrum-sabina
# [ ThreadPoolExecutor-0_5   ]      Scraping URL: https://www.indianodonata.org/epophthalmia-vittata
# [ ThreadPoolExecutor-0_1   ]      Scraping URL: https://www.indianodonata.org/calicnemia-eximia
# [ ThreadPoolExecutor-0_0   ]      Scraping URL: https://www.indianodonata.org/drepanosticta-carmichaeli
# [ ThreadPoolExecutor-0_7   ]      Scraping URL: https://www.indianodonata.org/dysphaea-gloriosa
# [ ThreadPoolExecutor-0_3   ]      Scraping URL: https://www.indianodonata.org/gynacantha-apicalis
# [ ThreadPoolExecutor-0_8   ]      Scraping URL: https://www.indianodonata.org/macromidia-spp
# [ ThreadPoolExecutor-0_4   ]      Scraping URL: https://www.indianodonata.org/ictinogomphus-pertinax
# [ ThreadPoolExecutor-0_2   ]      Scraping URL: https://www.indianodonata.org/agriocnemis-pygmaea
# [ ThreadPoolExecutor-0_5   ]      Scraping URL: https://www.indianodonata.org/epophthalmia-vittigera
# [ ThreadPoolExecutor-0_6   ]      Scraping URL: https://www.indianodonata.org/orthetrum-taeniolatum
# [ ThreadPoolExecutor-0_1   ]      Scraping URL: https://www.indianodonata.org/calicnemia-imitans
# [ ThreadPoolExecutor-0_7   ]      Scraping URL: https://www.indianodonata.org/burmagomphus-divaricatus
# [ ThreadPoolExecutor-0_0   ]      Scraping URL: https://www.indianodonata.org/drepanosticta-polychromatica
# [ ThreadPoolExecutor-0_2   ]      Scraping URL: https://www.indianodonata.org/agriocnemis-splendidissima
# [ ThreadPoolExecutor-0_8   ]      Scraping URL: https://www.indianodonata.org/gynacantha-chaplini
# [ ThreadPoolExecutor-0_4   ]      Scraping URL: https://www.indianodonata.org/ictinogomphus-rapax
# [ ThreadPoolExecutor-0_3   ]      Scraping URL: https://www.indianodonata.org/gynacantha-arnaudi
# [ ThreadPoolExecutor-0_6   ]      Scraping URL: https://www.indianodonata.org/orthetrum-testaceaum
# [ ThreadPoolExecutor-0_5   ]      Scraping URL: https://www.indianodonata.org/macromia-annaimalaiensis
# [ ThreadPoolExecutor-0_1   ]      Scraping URL: https://www.indianodonata.org/calicnemia-miles
# [ ThreadPoolExecutor-0_7   ]      Scraping URL: https://www.indianodonata.org/pseudothemis-zonata
# [ ThreadPoolExecutor-0_2   ]      Scraping URL: https://www.indianodonata.org/archibasis-oscillans
# [ ThreadPoolExecutor-0_4   ]      Scraping URL: https://www.indianodonata.org/macrogomphus-annulatus
# [ ThreadPoolExecutor-0_8   ]      Scraping URL: https://www.indianodonata.org/cyclogomphus-spp
# [ ThreadPoolExecutor-0_3   ]      Scraping URL: https://www.indianodonata.org/gynacantha-bainbriggei
# [ ThreadPoolExecutor-0_0   ]      Scraping URL: https://www.indianodonata.org/protosticta-davenporti
# [ ThreadPoolExecutor-0_6   ]      Scraping URL: https://www.indianodonata.org/orthetrum-triangulare
# [ ThreadPoolExecutor-0_5   ]      Scraping URL: https://www.indianodonata.org/macromia-bellicosa
# [ ThreadPoolExecutor-0_1   ]      Scraping URL: https://www.indianodonata.org/calicnemia-miniata
# [ ThreadPoolExecutor-0_7   ]      Scraping URL: https://www.indianodonata.org/cephalaeschna-acanthifrons
# [ ThreadPoolExecutor-0_4   ]      Scraping URL: https://www.indianodonata.org/macrogomphus-montanus
# [ ThreadPoolExecutor-0_2   ]      Scraping URL: https://www.indianodonata.org/argiocnemis-rubescens
# [ ThreadPoolExecutor-0_0   ]      Scraping URL: https://www.indianodonata.org/protosticta-fraseri
# [ ThreadPoolExecutor-0_8   ]      Scraping URL: https://www.indianodonata.org/davidius-davidi
# [ ThreadPoolExecutor-0_3   ]      Scraping URL: https://www.indianodonata.org/gynacantha-bayadera
# [ ThreadPoolExecutor-0_6   ]      Scraping URL: https://www.indianodonata.org/palpopleura-sexmaculata
# [ ThreadPoolExecutor-0_1   ]      Scraping URL: https://www.indianodonata.org/calicnemia-mortoni
# [ ThreadPoolExecutor-0_5   ]      Scraping URL: https://www.indianodonata.org/macromia-cingulata
# [ ThreadPoolExecutor-0_7   ]      Scraping URL: https://www.indianodonata.org/planaeschna-poumai
# [ ThreadPoolExecutor-0_4   ]      Scraping URL: https://www.indianodonata.org/macrogomphus-seductus
# [ ThreadPoolExecutor-0_2   ]      Scraping URL: https://www.indianodonata.org/ceriagrion-auranticum
# [ ThreadPoolExecutor-0_0   ]      Scraping URL: https://www.indianodonata.org/protosticta-gravelyi
# [ ThreadPoolExecutor-0_8   ]      Scraping URL: https://www.indianodonata.org/gynacantha-anandmati
# [ ThreadPoolExecutor-0_3   ]      Scraping URL: https://www.indianodonata.org/gynacantha-biharica
# [ ThreadPoolExecutor-0_1   ]      Scraping URL: https://www.indianodonata.org/calicnemia-mukherjeei
# [ ThreadPoolExecutor-0_5   ]      Scraping URL: https://www.indianodonata.org/macromia-cupricincta
# [ ThreadPoolExecutor-0_6   ]      Scraping URL: https://www.indianodonata.org/pantala-flavescens
# [ ThreadPoolExecutor-0_4   ]      Scraping URL: https://www.indianodonata.org/macrogomphus-wynaadicus
# [ ThreadPoolExecutor-0_2   ]      Scraping URL: https://www.indianodonata.org/ceriagrion-azureum
# [ ThreadPoolExecutor-0_7   ]      Scraping URL: https://www.indianodonata.org/camacinia-harterti
# [ ThreadPoolExecutor-0_0   ]      Scraping URL: https://www.indianodonata.org/protosticta-hearseyi
# [ ThreadPoolExecutor-0_3   ]      Scraping URL: https://www.indianodonata.org/gynacantha-dravida[ ThreadPoolExecutor-0_1   ]      Scraping URL: https://www.indianodonata.org/calicnemia-pulverulans
#
# [ ThreadPoolExecutor-0_8   ]      Scraping URL: https://www.indianodonata.org/devadatta-adii
# [ ThreadPoolExecutor-0_5   ]      Scraping URL: https://www.indianodonata.org/macromia-ellisoni
# [ ThreadPoolExecutor-0_6   ]      Scraping URL: https://www.indianodonata.org/potamarcha-congener
# [ ThreadPoolExecutor-0_2   ]      Scraping URL: https://www.indianodonata.org/ceriagrion-cerinorubellum
# [ ThreadPoolExecutor-0_7   ]      Scraping URL: https://www.indianodonata.org/ceriagrion-chromothorax
# [ ThreadPoolExecutor-0_4   ]      Scraping URL: https://www.indianodonata.org/megalogomphus-bicornutus
# [ ThreadPoolExecutor-0_0   ]      Scraping URL: https://www.indianodonata.org/protosticta-himalaica
# [ ThreadPoolExecutor-0_1   ]      Scraping URL: https://www.indianodonata.org/calicnemia-pyrrhosoma
# [ ThreadPoolExecutor-0_8   ]      Scraping URL: https://www.indianodonata.org/macromia-kannharaiensis
# [ ThreadPoolExecutor-0_5   ]      Scraping URL: https://www.indianodonata.org/macromia-flavicincta
# [ ThreadPoolExecutor-0_3   ]      Scraping URL: https://www.indianodonata.org/gynacantha-khasiaca
# [ ThreadPoolExecutor-0_6   ]      Scraping URL: https://www.indianodonata.org/pseudotramea-prateri
# [ ThreadPoolExecutor-0_2   ]      Scraping URL: https://www.indianodonata.org/ceriagrion-coeruleum
# [ ThreadPoolExecutor-0_7   ]      Scraping URL: https://www.indianodonata.org/gynacantha-subinterrupta
# [ ThreadPoolExecutor-0_4   ]      Scraping URL: https://www.indianodonata.org/megalogomphus-flavicolor
# [ ThreadPoolExecutor-0_0   ]      Scraping URL: https://www.indianodonata.org/protosticta-mortoni
# [ ThreadPoolExecutor-0_3   ]      Scraping URL: https://www.indianodonata.org/gynacantha-pallampurica
# [ ThreadPoolExecutor-0_8   ]      Scraping URL: https://www.indianodonata.org/yunnanosticta-siangi
# [ ThreadPoolExecutor-0_1   ]      Scraping URL: https://www.indianodonata.org/calicnemia-sudhaae
# [ ThreadPoolExecutor-0_5   ]      Scraping URL: https://www.indianodonata.org/macromia-flavocolorata
# [ ThreadPoolExecutor-0_6   ]      Scraping URL: https://www.indianodonata.org/rhodothemis-rufa
# [ ThreadPoolExecutor-0_7   ]      Scraping URL: https://www.indianodonata.org/gomphidia-podhigai
# [ ThreadPoolExecutor-0_4   ]      Scraping URL: https://www.indianodonata.org/megalogomphus-hannyngtoni
# [ ThreadPoolExecutor-0_2   ]      Scraping URL: https://www.indianodonata.org/ceriagrion-fallax
# [ ThreadPoolExecutor-0_1   ]      Scraping URL: https://www.indianodonata.org/coeliccia-bimaculata
# [ ThreadPoolExecutor-0_3   ]      Scraping URL: https://www.indianodonata.org/gynacantha-odoneli
# [ ThreadPoolExecutor-0_5   ]      Scraping URL: https://www.indianodonata.org/macromia-flavovittata
# [ ThreadPoolExecutor-0_8   ]      Scraping URL: https://www.indianodonata.org/merogomphus-aryanadensis
# [ ThreadPoolExecutor-0_7   ]      Scraping URL: https://www.indianodonata.org/cyclogomphus-flavoannulatus
# [ ThreadPoolExecutor-0_4   ]      Scraping URL: https://www.indianodonata.org/megalogomphus-smithii
# [ ThreadPoolExecutor-0_6   ]      Scraping URL: https://www.indianodonata.org/rhyothemis-obsolescens
# [ ThreadPoolExecutor-0_2   ]      Scraping URL: https://www.indianodonata.org/ceriagrion-olivaceum
# [ ThreadPoolExecutor-0_0   ]        Downloaded 2(+18) / 21 image(s) in insect-dataset/src/indianodonata.org/protosticta-mortoni
# [ ThreadPoolExecutor-0_0   ]      Scraping URL: https://www.indianodonata.org/protosticta-rufostigma
# [ ThreadPoolExecutor-0_8   ]      Scraping URL: https://www.indianodonata.org/merogomphus-flavoreductus
# [ ThreadPoolExecutor-0_1   ]      Scraping URL: https://www.indianodonata.org/coeliccia-didyma
# [ ThreadPoolExecutor-0_5   ]      Scraping URL: https://www.indianodonata.org/macromia-ida
# [ ThreadPoolExecutor-0_3   ]      Scraping URL: https://www.indianodonata.org/gynacantha-rammohani
# [ ThreadPoolExecutor-0_2   ]      Scraping URL: https://www.indianodonata.org/ceriagrion-rubiae
# [ ThreadPoolExecutor-0_7   ]      Scraping URL: https://www.indianodonata.org/calicnemia-carminea
# [ ThreadPoolExecutor-0_4   ]      Scraping URL: https://www.indianodonata.org/megalogomphus-superbus
# [ ThreadPoolExecutor-0_0   ]      Scraping URL: https://www.indianodonata.org/protosticta-sanguinostigma
# [ ThreadPoolExecutor-0_6   ]      Scraping URL: https://www.indianodonata.org/rhyothemis-plutonia
# [ ThreadPoolExecutor-0_1   ]      Scraping URL: https://www.indianodonata.org/coeliccia-dorothea
# [ ThreadPoolExecutor-0_8   ]  Crawling URL: https://www.indianodonata.org/odonata?page=26
# [ ThreadPoolExecutor-0_5   ]      Scraping URL: https://www.indianodonata.org/macromia-indica
# [ ThreadPoolExecutor-0_3   ]      Scraping URL: https://www.indianodonata.org/gynacantha-rotundata
# [ ThreadPoolExecutor-0_2   ]      Scraping URL: https://www.indianodonata.org/enallagma-cyathigerum
# [ ThreadPoolExecutor-0_7   ]      Scraping URL: https://www.indianodonata.org/nososticta-nicobarica
# [ ThreadPoolExecutor-0_6   ]      Scraping URL: https://www.indianodonata.org/rhyothemis-triangularis
# [ ThreadPoolExecutor-0_0   ]      Scraping URL: https://www.indianodonata.org/caliphaea-confusa
# [ ThreadPoolExecutor-0_1   ]      Scraping URL: https://www.indianodonata.org/coeliccia-fraseri
# [ ThreadPoolExecutor-0_4   ]      Scraping URL: https://www.indianodonata.org/merogomphus-longistigma
# [ ThreadPoolExecutor-0_5   ]      Scraping URL: https://www.indianodonata.org/macromia-irata
# [ ThreadPoolExecutor-0_3   ]      Scraping URL: https://www.indianodonata.org/anax-ephippiger
# [ ThreadPoolExecutor-0_7   ]      Scraping URL: https://www.indianodonata.org/nososticta-nancowra
# [ ThreadPoolExecutor-0_2   ]      Scraping URL: https://www.indianodonata.org/enallagma-immsi
# [ ThreadPoolExecutor-0_6   ]      Scraping URL: https://www.indianodonata.org/rhyothemis-variegata
# [ ThreadPoolExecutor-0_1   ]      Scraping URL: https://www.indianodonata.org/coeliccia-prakritiae
# [ ThreadPoolExecutor-0_4   ]      Scraping URL: https://www.indianodonata.org/euthygomphus-martini
# [ ThreadPoolExecutor-0_0   ]      Scraping URL: https://www.indianodonata.org/matrona-basilaris
# [ ThreadPoolExecutor-0_5   ]      Scraping URL: https://www.indianodonata.org/macromia-moorei
# [ ThreadPoolExecutor-0_3   ]      Scraping URL: https://www.indianodonata.org/oligoaeschna-andamani
# [ ThreadPoolExecutor-0_7   ]      Scraping URL: https://www.indianodonata.org/ictinogomphus-decoratus
# [ ThreadPoolExecutor-0_2   ]      Scraping URL: https://www.indianodonata.org/enallagma-insula
# [ ThreadPoolExecutor-0_4   ]      Scraping URL: https://www.indianodonata.org/microgomphus-chelifer
# [ ThreadPoolExecutor-0_0   ]      Scraping URL: https://www.indianodonata.org/matrona-nigripectus
# [ ThreadPoolExecutor-0_6   ]      Scraping URL: https://www.indianodonata.org/selysiothemis-nigra
# [ ThreadPoolExecutor-0_1   ]      Scraping URL: https://www.indianodonata.org/coeliccia-renifera
# [ ThreadPoolExecutor-0_5   ]      Scraping URL: https://www.indianodonata.org/macromia-pallida
# [ ThreadPoolExecutor-0_3   ]      Scraping URL: https://www.indianodonata.org/sarasaeschna-khasiana
# [ ThreadPoolExecutor-0_7   ]      Scraping URL: https://www.indianodonata.org/bradinopyga-konkanensis
# [ ThreadPoolExecutor-0_4   ]      Scraping URL: https://www.indianodonata.org/microgomphus-souteri
# [ ThreadPoolExecutor-0_2   ]      Scraping URL: https://www.indianodonata.org/amphiallagma-parvum
# [ ThreadPoolExecutor-0_0   ]      Scraping URL: https://www.indianodonata.org/neurobasis-chinensis
# [ ThreadPoolExecutor-0_6   ]      Scraping URL: https://www.indianodonata.org/sympetrum-commixtum
# [ ThreadPoolExecutor-0_1   ]      Scraping URL: https://www.indianodonata.org/coeliccia-rossi
# [ ThreadPoolExecutor-0_5   ]      Scraping URL: https://www.indianodonata.org/macromia-whitei
# [ ThreadPoolExecutor-0_3   ]      Scraping URL: https://www.indianodonata.org/sarasaeschna-martini
# [ ThreadPoolExecutor-0_4   ]      Scraping URL: https://www.indianodonata.org/microgomphus-torquatus
# [ ThreadPoolExecutor-0_2   ]      Scraping URL: https://www.indianodonata.org/enallagma-risi
# [ ThreadPoolExecutor-0_7   ]      Scraping URL: https://www.indianodonata.org/orthetrum-andamanicum
# [ ThreadPoolExecutor-0_6   ]      Scraping URL: https://www.indianodonata.org/sympetrum-durum
# [ ThreadPoolExecutor-0_0   ]      Scraping URL: https://www.indianodonata.org/echo-margarita
# [ ThreadPoolExecutor-0_5   ]      Scraping URL: https://www.indianodonata.org/hemicordulia-asiatica
# [ ThreadPoolExecutor-0_1   ]      Scraping URL: https://www.indianodonata.org/coeliccia-sarbottama
# [ ThreadPoolExecutor-0_3   ]      Scraping URL: https://www.indianodonata.org/sarasaeschna-speciosa
# [ ThreadPoolExecutor-0_2   ]      Scraping URL: https://www.indianodonata.org/himalagrion-exclamatione
# [ ThreadPoolExecutor-0_4   ]      Scraping URL: https://www.indianodonata.org/microgomphus-verticalis
# [ ThreadPoolExecutor-0_7   ]      Scraping URL: https://www.indianodonata.org/gynacanthaeschna-sikkima
# [ ThreadPoolExecutor-0_6   ]      Scraping URL: https://www.indianodonata.org/sympetrum-fonscolombii
# [ ThreadPoolExecutor-0_0   ]      Scraping URL: https://www.indianodonata.org/vestalaria-smaragdina
# [ ThreadPoolExecutor-0_5   ]      Scraping URL: https://www.indianodonata.org/somatochlora-daviesi
# [ ThreadPoolExecutor-0_1   ]      Scraping URL: https://www.indianodonata.org/coeliccia-schmidti
# [ ThreadPoolExecutor-0_3   ]      Scraping URL: https://www.indianodonata.org/periaeschna-flinti
# [ ThreadPoolExecutor-0_2   ]      Scraping URL: https://www.indianodonata.org/ischnura-rubilio
# [ ThreadPoolExecutor-0_4   ]      Scraping URL: https://www.indianodonata.org/nepogomphus-modestus
# [ ThreadPoolExecutor-0_7   ]      Scraping URL: https://www.indianodonata.org/megalestes-micans
# [ ThreadPoolExecutor-0_6   ]      Scraping URL: https://www.indianodonata.org/sympetrum-speciosum
# [ ThreadPoolExecutor-0_0   ]      Scraping URL: https://www.indianodonata.org/vestalis-apicalis
# [ ThreadPoolExecutor-0_1   ]      Scraping URL: https://www.indianodonata.org/coeliccia-svihleri
# [ ThreadPoolExecutor-0_5   ]      Scraping URL: https://www.indianodonata.org/acisoma-panorpoides
# [ ThreadPoolExecutor-0_3   ]      Scraping URL: https://www.indianodonata.org/periaeschna-lebasi
# [ ThreadPoolExecutor-0_4   ]      Scraping URL: https://www.indianodonata.org/nepogomphus-walli
# [ ThreadPoolExecutor-0_7   ]      Scraping URL: https://www.indianodonata.org/megalestes-gyalsey
# [ ThreadPoolExecutor-0_2   ]      Scraping URL: https://www.indianodonata.org/ischnura-elegans
# [ ThreadPoolExecutor-0_6   ]      Scraping URL: https://www.indianodonata.org/sympetrum-himalayanum
# [ ThreadPoolExecutor-0_1   ]      Scraping URL: https://www.indianodonata.org/coeliccia-vacca
# [ ThreadPoolExecutor-0_0   ]      Scraping URL: https://www.indianodonata.org/vestalis-gracilis
# [ ThreadPoolExecutor-0_5   ]      Scraping URL: https://www.indianodonata.org/aethriamanta-brevipennis
# [ ThreadPoolExecutor-0_3   ]      Scraping URL: https://www.indianodonata.org/periaeschna-magdalena
# [ ThreadPoolExecutor-0_4   ]      Scraping URL: https://www.indianodonata.org/orientogomphus-indicus
# [ ThreadPoolExecutor-0_2   ]  Crawling URL: https://www.indianodonata.org/odonata?page=8
# [ ThreadPoolExecutor-0_7   ]  Crawling URL: https://www.indianodonata.org/odonata?page=23
# [ ThreadPoolExecutor-0_5   ]  Crawling URL: https://www.indianodonata.org/odonata?page=17
# [ ThreadPoolExecutor-0_6   ]  Crawling URL: https://www.indianodonata.org/odonata?page=20
# [ ThreadPoolExecutor-0_1   ]  Crawling URL: https://www.indianodonata.org/odonata?page=5
# [ ThreadPoolExecutor-0_0   ]      Scraping URL: https://www.indianodonata.org/vestalis-submontana
# [ ThreadPoolExecutor-0_2   ]      Scraping URL: https://www.indianodonata.org/ischnura-forcipata
# [ ThreadPoolExecutor-0_7   ]      Scraping URL: https://www.indianodonata.org/platylestes-kirani
# [ ThreadPoolExecutor-0_3   ]      Scraping URL: https://www.indianodonata.org/periaeschna-nocturnalis
# [ ThreadPoolExecutor-0_1   ]      Scraping URL: https://www.indianodonata.org/indocnemis-orang
# [ ThreadPoolExecutor-0_6   ]      Scraping URL: https://www.indianodonata.org/sympetrum-hypomelas
# [ ThreadPoolExecutor-0_5   ]      Scraping URL: https://www.indianodonata.org/agrionoptera-dorothea
# [ ThreadPoolExecutor-0_4   ]  Crawling URL: https://www.indianodonata.org/odonata?page=14
# [ ThreadPoolExecutor-0_4   ]      Scraping URL: https://www.indianodonata.org/melligomphus-acinaces
# [ ThreadPoolExecutor-0_0   ]      Scraping URL: https://www.indianodonata.org/aristocypha-cuneata
# [ ThreadPoolExecutor-0_2   ]      Scraping URL: https://www.indianodonata.org/ischnura-inarmata
# [ ThreadPoolExecutor-0_7   ]      Scraping URL: https://www.indianodonata.org/protosticta-cyanofemora
# [ ThreadPoolExecutor-0_3   ]  Crawling URL: https://www.indianodonata.org/odonata?page=11
# [ ThreadPoolExecutor-0_1   ]      Scraping URL: https://www.indianodonata.org/caconeura-gomphoides
# [ ThreadPoolExecutor-0_5   ]      Scraping URL: https://www.indianodonata.org/agrionoptera-insignis
# [ ThreadPoolExecutor-0_6   ]      Scraping URL: https://www.indianodonata.org/sympetrum-meridionale
# [ ThreadPoolExecutor-0_3   ]      Scraping URL: https://www.indianodonata.org/periaeschna-unifasciata
# [ ThreadPoolExecutor-0_4   ]      Scraping URL: https://www.indianodonata.org/lamelligomphus-biforceps
# [ ThreadPoolExecutor-0_2   ]      Scraping URL: https://www.indianodonata.org/ischnura-mildredae
# [ ThreadPoolExecutor-0_0   ]  Crawling URL: https://www.indianodonata.org/odonata?page=2
# [ ThreadPoolExecutor-0_7   ]      Scraping URL: https://www.indianodonata.org/protosticta-sholai
# [ ThreadPoolExecutor-0_5   ]      Scraping URL: https://www.indianodonata.org/amphithemis-curvistyla
# [ ThreadPoolExecutor-0_6   ]      Scraping URL: https://www.indianodonata.org/sympetrum-orientale
# [ ThreadPoolExecutor-0_1   ]      Scraping URL: https://www.indianodonata.org/caconeura-obscura
# [ ThreadPoolExecutor-0_0   ]      Scraping URL: https://www.indianodonata.org/aristocypha-fenestrella
# [ ThreadPoolExecutor-0_4   ]      Scraping URL: https://www.indianodonata.org/scalmogomphus-bistrigatus
# [ ThreadPoolExecutor-0_2   ]      Scraping URL: https://www.indianodonata.org/ischnura-nursei
# [ ThreadPoolExecutor-0_3   ]      Scraping URL: https://www.indianodonata.org/petaliaeschna-fletcheri
# [ ThreadPoolExecutor-0_7   ]      Scraping URL: https://www.indianodonata.org/protosticta-myristicaensis
# [ ThreadPoolExecutor-0_6   ]      Scraping URL: https://www.indianodonata.org/sympetrum-vulgatum
# [ ThreadPoolExecutor-0_5   ]      Scraping URL: https://www.indianodonata.org/amphithemis-vacillans
# [ ThreadPoolExecutor-0_1   ]      Scraping URL: https://www.indianodonata.org/caconeura-ramburi
# [ ThreadPoolExecutor-0_0   ]      Scraping URL: https://www.indianodonata.org/aristocypha-immaculata
# [ ThreadPoolExecutor-0_3   ]      Scraping URL: https://www.indianodonata.org/planaeschna-intersedens
# [ ThreadPoolExecutor-0_4   ]      Scraping URL: https://www.indianodonata.org/onychogomphus-cacharicus
# [ ThreadPoolExecutor-0_2   ]      Scraping URL: https://www.indianodonata.org/ischnura-null
# [ ThreadPoolExecutor-0_7   ]      Scraping URL: https://www.indianodonata.org/orthetrum-erythronigrum
# [ ThreadPoolExecutor-0_5   ]      Scraping URL: https://www.indianodonata.org/brachydiplax-chalybea
# [ ThreadPoolExecutor-0_1   ]      Scraping URL: https://www.indianodonata.org/caconeura-risi
# [ ThreadPoolExecutor-0_6   ]      Scraping URL: https://www.indianodonata.org/tetrathemis-platyptera
# [ ThreadPoolExecutor-0_0   ]      Scraping URL: https://www.indianodonata.org/aristocypha-quadrimaculata
# [ ThreadPoolExecutor-0_4   ]      Scraping URL: https://www.indianodonata.org/nychogomphus-duaricus
# [ ThreadPoolExecutor-0_3   ]      Scraping URL: https://www.indianodonata.org/polycanthagyna-erythromelas
# [ ThreadPoolExecutor-0_2   ]      Scraping URL: https://www.indianodonata.org/ischnura-rufostigma
# [ ThreadPoolExecutor-0_7   ]      Scraping URL: https://www.indianodonata.org/ceriagrion-calamineum
# [ ThreadPoolExecutor-0_1   ]      Scraping URL: https://www.indianodonata.org/caconeura-t-coerulea
# [ ThreadPoolExecutor-0_6   ]      Scraping URL: https://www.indianodonata.org/tholymis-tillarga
# [ ThreadPoolExecutor-0_5   ]      Scraping URL: https://www.indianodonata.org/brachydiplax-farinosa
# [ ThreadPoolExecutor-0_4   ]      Scraping URL: https://www.indianodonata.org/onychogomphus-grammicus
# [ ThreadPoolExecutor-0_0   ]      Scraping URL: https://www.indianodonata.org/aristocypha-spuria
# [ ThreadPoolExecutor-0_2   ]      Scraping URL: https://www.indianodonata.org/ischnura-senegalensis
# [ ThreadPoolExecutor-0_3   ]      Scraping URL: https://www.indianodonata.org/polycanthagyna-ornithocephala
# [ ThreadPoolExecutor-0_7   ]      Scraping URL: https://www.indianodonata.org/phyllothemis-eltoni
# [ ThreadPoolExecutor-0_1   ]      Scraping URL: https://www.indianodonata.org/disparoneura-apicalis
# [ ThreadPoolExecutor-0_6   ]      Scraping URL: https://www.indianodonata.org/tramea-basilaris
# [ ThreadPoolExecutor-0_5   ]      Scraping URL: https://www.indianodonata.org/brachydiplax-sobrina
# [ ThreadPoolExecutor-0_0   ]      Scraping URL: https://www.indianodonata.org/calocypha-laidlawi
# [ ThreadPoolExecutor-0_4   ]      Scraping URL: https://www.indianodonata.org/onychogomphus-malabarensis
# [ ThreadPoolExecutor-0_3   ]      Scraping URL: https://www.indianodonata.org/tetracanthagyna-waterhousei
# [ ThreadPoolExecutor-0_1   ]      Scraping URL: https://www.indianodonata.org/disparoneura-quadrimaculata
# [ ThreadPoolExecutor-0_7   ]      Scraping URL: https://www.indianodonata.org/nannophyopsis-clara
# [ ThreadPoolExecutor-0_2   ]      Scraping URL: https://www.indianodonata.org/mortonagrion-aborense
# [ ThreadPoolExecutor-0_6   ]      Scraping URL: https://www.indianodonata.org/tramea-eurybia
# [ ThreadPoolExecutor-0_0   ]      Scraping URL: https://www.indianodonata.org/heliocypha-biforata
# [ ThreadPoolExecutor-0_5   ]      Scraping URL: https://www.indianodonata.org/brachythemis-contaminata
# [ ThreadPoolExecutor-0_4   ]      Scraping URL: https://www.indianodonata.org/onychogomphus-meghalayanus
# [ ThreadPoolExecutor-0_3   ]      Scraping URL: https://www.indianodonata.org/acrogomphus-fraseri
# [ ThreadPoolExecutor-0_7   ]      Scraping URL: https://www.indianodonata.org/zyxomma-breviventre
# [ ThreadPoolExecutor-0_2   ]      Scraping URL: https://www.indianodonata.org/mortonagrion-varralli
# [ ThreadPoolExecutor-0_1   ]      Scraping URL: https://www.indianodonata.org/elattoneura-atkinsoni
# [ ThreadPoolExecutor-0_6   ]      Scraping URL: https://www.indianodonata.org/tramea-limbata
# [ ThreadPoolExecutor-0_0   ]      Scraping URL: https://www.indianodonata.org/heliocypha-perforata
# [ ThreadPoolExecutor-0_4   ]      Scraping URL: https://www.indianodonata.org/lamelligomphus-nilgiriensis
# [ ThreadPoolExecutor-0_5   ]      Scraping URL: https://www.indianodonata.org/bradinopyga-geminata
# [ ThreadPoolExecutor-0_3   ]      Scraping URL: https://www.indianodonata.org/acrogomphus-mohani
# [ ThreadPoolExecutor-0_7   ]      Scraping URL: https://www.indianodonata.org/cephalaeschna-patrai
# [ ThreadPoolExecutor-0_2   ]      Scraping URL: https://www.indianodonata.org/paracercion-calamorum
# [ ThreadPoolExecutor-0_1   ]      Scraping URL: https://www.indianodonata.org/elattoneura-campioni
# [ ThreadPoolExecutor-0_6   ]      Scraping URL: https://www.indianodonata.org/tramea-transmarina
# [ ThreadPoolExecutor-0_0   ]      Scraping URL: https://www.indianodonata.org/indocypha-vittata
# [ ThreadPoolExecutor-0_4   ]      Scraping URL: https://www.indianodonata.org/lamelligomphus-risi
# [ ThreadPoolExecutor-0_5   ]      Scraping URL: https://www.indianodonata.org/camacinia-gigantea
# [ ThreadPoolExecutor-0_3   ]      Scraping URL: https://www.indianodonata.org/anisogomphus-bivittatus
# [ ThreadPoolExecutor-0_1   ]      Scraping URL: https://www.indianodonata.org/elattoneura-coomansi
# [ ThreadPoolExecutor-0_2   ]      Scraping URL: https://www.indianodonata.org/paracercion-melanotum
# [ ThreadPoolExecutor-0_7   ]      Scraping URL: https://www.indianodonata.org/anaciaeschna-martini
# [ ThreadPoolExecutor-0_6   ]      Scraping URL: https://www.indianodonata.org/tramea-virginia
# [ ThreadPoolExecutor-0_4   ]      Scraping URL: https://www.indianodonata.org/nychogomphus-saundersii
# [ ThreadPoolExecutor-0_0   ]      Scraping URL: https://www.indianodonata.org/libellago-andamanensis
# [ ThreadPoolExecutor-0_5   ]      Scraping URL: https://www.indianodonata.org/cratilla-lineata
# [ ThreadPoolExecutor-0_3   ]      Scraping URL: https://www.indianodonata.org/anisogomphus-caudalis
# [ ThreadPoolExecutor-0_7   ]      Scraping URL: https://www.indianodonata.org/euphaea-thosegharensis
# [ ThreadPoolExecutor-0_2   ]      Scraping URL: https://www.indianodonata.org/pseudagrion-andamanicum
# [ ThreadPoolExecutor-0_1   ]      Scraping URL: https://www.indianodonata.org/elattoneura-nigerrima
# [ ThreadPoolExecutor-0_6   ]      Scraping URL: https://www.indianodonata.org/trithemis-aurora
# [ ThreadPoolExecutor-0_4   ]      Scraping URL: https://www.indianodonata.org/scalmogomphus-schmidti
# [ ThreadPoolExecutor-0_0   ]      Scraping URL: https://www.indianodonata.org/libellago-aurantiaca
# [ ThreadPoolExecutor-0_5   ]      Scraping URL: https://www.indianodonata.org/crocothemis-erythraea
# [ ThreadPoolExecutor-0_3   ]      Scraping URL: https://www.indianodonata.org/anisogomphus-occipitalis
# [ ThreadPoolExecutor-0_1   ]      Scraping URL: https://www.indianodonata.org/elattoneura-nihari
# [ ThreadPoolExecutor-0_7   ]      Scraping URL: https://www.indianodonata.org/euphaea-pseudodispar
# [ ThreadPoolExecutor-0_2   ]      Scraping URL: https://www.indianodonata.org/pseudagrion-australasiae
# [ ThreadPoolExecutor-0_6   ]      Scraping URL: https://www.indianodonata.org/trithemis-festiva
# [ ThreadPoolExecutor-0_4   ]      Scraping URL: https://www.indianodonata.org/nychogomphus-striatus
# [ ThreadPoolExecutor-0_0   ]      Scraping URL: https://www.indianodonata.org/libellago-balus
# [ ThreadPoolExecutor-0_5   ]      Scraping URL: https://www.indianodonata.org/crocothemis-servilia
# [ ThreadPoolExecutor-0_3   ]      Scraping URL: https://www.indianodonata.org/anisogomphus-orites
# [ ThreadPoolExecutor-0_2   ]      Scraping URL: https://www.indianodonata.org/pseudagrion-bidentatum
# [ ThreadPoolExecutor-0_1   ]      Scraping URL: https://www.indianodonata.org/elattoneura-souteri
# [ ThreadPoolExecutor-0_7   ]      Scraping URL: https://www.indianodonata.org/pseudagrion-pruinosum
# [ ThreadPoolExecutor-0_6   ]      Scraping URL: https://www.indianodonata.org/trithemis-kirbyi
# [ ThreadPoolExecutor-0_0   ]      Scraping URL: https://www.indianodonata.org/libellago-blanda
# [ ThreadPoolExecutor-0_4   ]      Scraping URL: https://www.indianodonata.org/onychogomphus-thienemanni
# [ ThreadPoolExecutor-0_5   ]      Scraping URL: https://www.indianodonata.org/diplacodes-lefebvrii
# [ ThreadPoolExecutor-0_3   ]      Scraping URL: https://www.indianodonata.org/anormogomphus-heteropterus
# [ ThreadPoolExecutor-0_2   ]      Scraping URL: https://www.indianodonata.org/pseudagrion-decorum
# [ ThreadPoolExecutor-0_7   ]      Scraping URL: https://www.indianodonata.org/cephalaeschna-triadica
# [ ThreadPoolExecutor-0_6   ]      Scraping URL: https://www.indianodonata.org/trithemis-pallidinervis
# [ ThreadPoolExecutor-0_1   ]      Scraping URL: https://www.indianodonata.org/elattoneura-tetrica
# [ ThreadPoolExecutor-0_0   ]      Scraping URL: https://www.indianodonata.org/libellago-indica
# [ ThreadPoolExecutor-0_4   ]      Scraping URL: https://www.indianodonata.org/ophiogomphus-cerastis
# [ ThreadPoolExecutor-0_5   ]      Scraping URL: https://www.indianodonata.org/diplacodes-nebulosa
# [ ThreadPoolExecutor-0_7   ]      Scraping URL: https://www.indianodonata.org/orthetrum-spp
# [ ThreadPoolExecutor-0_2   ]      Scraping URL: https://www.indianodonata.org/pseudagrion-hypermelas
# [ ThreadPoolExecutor-0_3   ]      Scraping URL: https://www.indianodonata.org/anormogomphus-kiritschenkoi
# [ ThreadPoolExecutor-0_1   ]      Scraping URL: https://www.indianodonata.org/esme-cyaneovittata
# [ ThreadPoolExecutor-0_6   ]      Scraping URL: https://www.indianodonata.org/urothemis-signata
# [ ThreadPoolExecutor-0_0   ]      Scraping URL: https://www.indianodonata.org/libellago-lineata
# [ ThreadPoolExecutor-0_4   ]      Scraping URL: https://www.indianodonata.org/ophiogomphus-reductus
# [ ThreadPoolExecutor-0_5   ]      Scraping URL: https://www.indianodonata.org/diplacodes-trivialis
# [ ThreadPoolExecutor-0_2   ]      Scraping URL: https://www.indianodonata.org/pseudagrion-indicum
# [ ThreadPoolExecutor-0_1   ]      Scraping URL: https://www.indianodonata.org/esme-longistyla
# [ ThreadPoolExecutor-0_3   ]      Scraping URL: https://www.indianodonata.org/asiagomphus-nilgiricus
# [ ThreadPoolExecutor-0_7   ]      Scraping URL: https://www.indianodonata.org/echo-perornata
# [ ThreadPoolExecutor-0_0   ]      Scraping URL: https://www.indianodonata.org/aristocypha-hilaryae
# [ ThreadPoolExecutor-0_6   ]      Scraping URL: https://www.indianodonata.org/zygonyx-iris
# [ ThreadPoolExecutor-0_4   ]      Scraping URL: https://www.indianodonata.org/paragomphus-echinoccipitalis
# [ ThreadPoolExecutor-0_5   ]      Scraping URL: https://www.indianodonata.org/epithemis-mariae
# [ ThreadPoolExecutor-0_2   ]      Scraping URL: https://www.indianodonata.org/pseudagrion-laidlawi
# [ ThreadPoolExecutor-0_3   ]      Scraping URL: https://www.indianodonata.org/asiagomphus-odoneli
# [ ThreadPoolExecutor-0_1   ]      Scraping URL: https://www.indianodonata.org/esme-mudiensis
# [ ThreadPoolExecutor-0_7   ]      Scraping URL: https://www.indianodonata.org/gynacantha-millardi
# [ ThreadPoolExecutor-0_0   ]      Scraping URL: https://www.indianodonata.org/rhinocypha-ignipennis
# [ ThreadPoolExecutor-0_6   ]      Scraping URL: https://www.indianodonata.org/zygonyx-torrida
# [ ThreadPoolExecutor-0_4   ]      Scraping URL: https://www.indianodonata.org/paragomphus-lindgreni
# [ ThreadPoolExecutor-0_5   ]      Scraping URL: https://www.indianodonata.org/hydrobasileus-croceus
# [ ThreadPoolExecutor-0_3   ]      Scraping URL: https://www.indianodonata.org/asiagomphus-personatus
# [ ThreadPoolExecutor-0_2   ]      Scraping URL: https://www.indianodonata.org/pseudagrion-malabaricum
# [ ThreadPoolExecutor-0_1   ]      Scraping URL: https://www.indianodonata.org/melanoneura-bilineata
# [ ThreadPoolExecutor-0_6   ]      Scraping URL: https://www.indianodonata.org/zyxomma-obtusum
# [ ThreadPoolExecutor-0_7   ]      Scraping URL: https://www.indianodonata.org/coeliccia-spp
# [ ThreadPoolExecutor-0_0   ]      Scraping URL: https://www.indianodonata.org/rhinocypha-immaculata
# [ ThreadPoolExecutor-0_4   ]      Scraping URL: https://www.indianodonata.org/paragomphus-lineatus
# [ ThreadPoolExecutor-0_5   ]      Scraping URL: https://www.indianodonata.org/hylaeothemis-gardeneri
# [ ThreadPoolExecutor-0_3   ]      Scraping URL: https://www.indianodonata.org/burmagomphus-cauvericus
# [ ThreadPoolExecutor-0_2   ]      Scraping URL: https://www.indianodonata.org/pseudagrion-microcephalum
# [ ThreadPoolExecutor-0_1   ]      Scraping URL: https://www.indianodonata.org/phylloneura-westermanni
# [ ThreadPoolExecutor-0_0   ]      Scraping URL: https://www.indianodonata.org/aristocypha-trifasciata
# [ ThreadPoolExecutor-0_7   ]      Scraping URL: https://www.indianodonata.org/scalmogomphus-spp
# [ ThreadPoolExecutor-0_6   ]      Scraping URL: https://www.indianodonata.org/zyxomma-petiolatum
# [ ThreadPoolExecutor-0_4   ]      Scraping URL: https://www.indianodonata.org/perissogomphus-stevensi
# [ ThreadPoolExecutor-0_3   ]      Scraping URL: https://www.indianodonata.org/burmagomphus-hasimaricus
# [ ThreadPoolExecutor-0_5   ]      Scraping URL: https://www.indianodonata.org/hylaeothemis-apicalis
# [ ThreadPoolExecutor-0_1   ]      Scraping URL: https://www.indianodonata.org/prodasineura-autumnalis
# [ ThreadPoolExecutor-0_0   ]      Scraping URL: https://www.indianodonata.org/rhinocypha-trimaculata
# [ ThreadPoolExecutor-0_7   ]      Scraping URL: https://www.indianodonata.org/ceriagrion-spp
# [ ThreadPoolExecutor-0_6   ]      Scraping URL: https://www.indianodonata.org/idionyx-corona
# [ ThreadPoolExecutor-0_4   ]      Scraping URL: https://www.indianodonata.org/phaenandrogomphus-aureus
# [ ThreadPoolExecutor-0_2   ]      Scraping URL: https://www.indianodonata.org/pseudagrion-pilidorsum
# [ ThreadPoolExecutor-0_3   ]      Scraping URL: https://www.indianodonata.org/burmagomphus-laidlawi
# [ ThreadPoolExecutor-0_0   ]      Scraping URL: https://www.indianodonata.org/paracypha-unimaculata
# [ ThreadPoolExecutor-0_5   ]      Scraping URL: https://www.indianodonata.org/indothemis-carnatica
# [ ThreadPoolExecutor-0_3   ]      Scraping URL: https://www.indianodonata.org/burmagomphus-pyramidalis
# [ ThreadPoolExecutor-0_0   ]      Scraping URL: https://www.indianodonata.org/rhinocypha-vitrinella
# Thread completed with result None
# Thread completed with result None
# Thread completed with result None
# Thread completed with result None
# Thread completed with result None
# Thread completed with result None
# Thread completed with result None
# Thread completed with result None
# Thread completed with result None
# Scraping completed!

# %% [markdown]
# # Remove corrupted images & empty folders

# %%
import os
from PIL import Image
from pathlib import Path

def check_image(file_path):
    try:
        with Image.open(file_path) as img:
            img.verify()
        return True
    except (IOError, SyntaxError):
        return False

for species_dir in Path(f"{dataset_dir}").iterdir():
    if species_dir.is_dir() and os.listdir(species_dir):
        for file in Path(f"{species_dir}").iterdir():
            if file.is_file() and not check_image(file):
                os.remove(file)
                print(f"Corrupted file {file} removed")
            elif re.search(ignore_image_regex, file.name):
                os.remove(file)
                print(f"Unwanted file {file} removed")
    # if species_dir.is_dir() and not os.listdir(species_dir):
    #     os.rmdir(species_dir)
    #     print(f"Empty folder {species_dir} removed")
# Out:
# Corrupted file insect-dataset\src\indianodonata.org\protosticta-mortoni\Protosticta%20mortoni_1655551867_237852.jpg removed
# Corrupted file insect-dataset\src\indianodonata.org\protosticta-mortoni\Protosticta%20mortoni_1655551867_237853.jpg removed

# %% [markdown]
# # Fetch species names

# %%
classes = { class_dir: len([ img for img in os.listdir(f"{dataset_dir}/{class_dir}") ]) for class_dir in os.listdir(f"{dataset_dir}") }

# %%
class_details = {}

# %%
import json

# read json
with open(class_details_json_path, "r", encoding="utf-8") as file:
    class_details = json.load(file)

# %%
for class_name in [ c for c in classes.keys() if not c.endswith("-early") ]:
    try:
        if class_name in class_details and "name" in class_details[class_name]:
            continue
        print()
        print(f"class_name: {class_name}")
        url = f"{website_url}/{class_name}"
        response = requests.get(url, timeout=page_timeout)
        soup = BeautifulSoup(response.text, 'html.parser')
        title = soup.find(lambda tag: tag.find("span", class_="spices-title") is not None, class_="field field--name-title field--type-string field--label-hidden").get_text(strip=True)
        print(f"title: {title}")
        species_name = re.split(r"\s+-\s+", title)
        if len(species_name) > 1:
            species_name = species_name[-1]
        else:
            print(f"species_name: NOT FOUND")
            continue
        print(f"species_name: {species_name}")
        class_details[class_name] = {"name": species_name}
    except Exception:
        print("ERROR")
# Out:
# class_name: aciagrion-azureum
# title: Aciagrion azureumFraser, 1922  -
# species_name: NOT FOUND
#
# class_name: aciagrion-hisopa
# title: Aciagrion hisopaSelys, 1876  - Violet-striped Slender Dartlet
# species_name: Violet-striped Slender Dartlet
#
# class_name: aciagrion-olympicum
# title: Aciagrion olympicumLaidlaw, 1919  -
# species_name: NOT FOUND
#
# class_name: aciagrion-spp
# title: Aciagrion spp- Slims
# species_name: NOT FOUND
#
# class_name: aciagrion-tillyardi
# title: Aciagrion tillyardiLaidlaw, 1919  -
# species_name: NOT FOUND
#
# class_name: acrogomphus-fraseri
# title: Acrogomphus fraseriLaidlaw, 1925  -
# species_name: NOT FOUND
#
# class_name: acrogomphus-mohani
# title: Acrogomphus mohaniSahani, 1964  -
# species_name: NOT FOUND
#
# class_name: aeshna-donaldi
# title: Aeshna donaldiFraser, 1922b  - Darner
# species_name: Darner
#
# class_name: aeshna-spp
# title: Aeshna spp- Hawker
# species_name: NOT FOUND
#
# class_name: agriocnemis-clauseni
# title: Agriocnemis clauseniFraser, 1922  -
# species_name: NOT FOUND
#
# class_name: agriocnemis-corbeti
# title: Agriocnemis corbetiKumar & Prasad, 1978  -
# species_name: NOT FOUND
#
# class_name: agriocnemis-dabreui
# title: Agriocnemis dabreuiFraser, 1919  -
# species_name: NOT FOUND
#
# class_name: agriocnemis-nana
# title: Agriocnemis nanaLaidlaw, 1914  -
# species_name: NOT FOUND
#
# class_name: agriocnemis-spp
# title: Agriocnemis spp- Wisps
# species_name: NOT FOUND
#
# class_name: agrionoptera-dorothea
# title: Agrionoptera dorotheaFraser, 1927  -
# species_name: NOT FOUND
#
# class_name: amphithemis-curvistyla
# title: Amphithemis curvistylaSelys, 1891  -
# species_name: NOT FOUND
#
# class_name: amphithemis-vacillans
# title: Amphithemis vacillansSelys, 1891  -
# species_name: NOT FOUND
#
# class_name: anax-imperator
# title: Anax imperatorLeach, 1815  - Blue Emperor
# species_name: Blue Emperor
#
# class_name: anax-panybeus
# title: Anax panybeusHagen, 1867  -
# species_name: NOT FOUND
#
# class_name: anisogomphus-bivittatus
# title: Anisogomphus bivittatusSelys, 1854  -
# species_name: NOT FOUND
#
# class_name: anisogomphus-caudalis
# title: Anisogomphus caudalisFraser, 1926  -
# species_name: NOT FOUND
#
# class_name: anisogomphus-orites
# title: Anisogomphus oritesLaidlaw, 1922  -
# species_name: NOT FOUND
#
# class_name: anisopleura-comes
# title: Anisopleura comesHagen,1880  -
# species_name: NOT FOUND
#
# class_name: anisopleura-lestoides
# title: Anisopleura lestoidesSelys,1853  -
# species_name: NOT FOUND
#
# class_name: anisopleura-subplatystyla
# title: Anisopleura subplatystylaFraser, 1927  -
# species_name: NOT FOUND
#
# class_name: anisopleura-vallei
# title: Anisopleura valleiSt.Quentin,1937  -
# species_name: NOT FOUND
#
# class_name: anormogomphus-heteropterus
# title: Anormogomphus heteropterusSelys, 1854  -
# species_name: NOT FOUND
#
# class_name: anormogomphus-kiritschenkoi
# title: Anormogomphus kiritschenkoiBartenef, 1913  -
# species_name: NOT FOUND
#
# class_name: anotogaster-basalis
# title: Anotogaster basalisSelys, 1854  -
# species_name: NOT FOUND
#
# class_name: anotogaster-nipalensis
# title: Anotogaster nipalensisSelys, 1854  -
# species_name: NOT FOUND
#
# class_name: aristocypha-cuneata
# title: Aristocypha cuneataSelys, 1853  -
# species_name: NOT FOUND
#
# class_name: aristocypha-fenestrella
# title: Aristocypha fenestrellaRambur, 1842  -
# species_name: NOT FOUND
#
# class_name: aristocypha-hilaryae
# title: Aristocypha hilaryaeFraser, 1927  -
# species_name: NOT FOUND
#
# class_name: aristocypha-immaculata
# title: Aristocypha immaculataSelys, 1879  -
# species_name: NOT FOUND
#
# class_name: aristocypha-quadrimaculata
# title: Aristocypha quadrimaculataSelys, 1853  -
# species_name: NOT FOUND
#
# class_name: aristocypha-spp
# title: Aristocypha spp- Jewels
# species_name: NOT FOUND
#
# class_name: aristocypha-spuria
# title: Aristocypha spuriaSelys, 1879  -
# species_name: NOT FOUND
#
# class_name: asiagomphus-nilgiricus
# title: Asiagomphus nilgiricusLaidlaw, 1922  -
# species_name: NOT FOUND
#
# class_name: asiagomphus-odoneli
# title: Asiagomphus odoneliFraser, 1922  -
# species_name: NOT FOUND
#
# class_name: asiagomphus-personatus
# title: Asiagomphus personatusSelys, 1873  -
# species_name: NOT FOUND
#
# class_name: bayadera-hyalina
# title: Bayadera hyalinaSelys, 1879  -
# species_name: NOT FOUND
#
# class_name: bayadera-indica
# title: Bayadera indicaSelys, 1853  -
# species_name: NOT FOUND
#
# class_name: bayadera-kali
# title: Bayadera kaliCowley, 1936  -
# species_name: NOT FOUND
#
# class_name: bayadera-longicauda
# title: Bayadera longicaudaFraser, 1928  -
# species_name: NOT FOUND
#
# class_name: bayadera-spp
# title: Bayadera spp-
# species_name: NOT FOUND
#
# class_name: burmagomphus-divaricatus
# title: Burmagomphus divaricatusLieftinck, 1964  -
# species_name: NOT FOUND
#
# class_name: burmagomphus-hasimaricus
# title: Burmagomphus hasimaricusFraser, 1926  -
# species_name: NOT FOUND
#
# class_name: burmagomphus-laidlawi
# title: Burmagomphus laidlawiFraser, 1924  -
# species_name: NOT FOUND
#
# class_name: burmagomphus-sivalikensis
# title: Burmagomphus sivalikensisLaidlaw, 1922  -
# species_name: NOT FOUND
#
# class_name: burmargiolestes-laidlawi
# title: Burmargiolestes laidlawiLieftinck, 1960  -
# species_name: NOT FOUND
#
# class_name: caconeura-gomphoides
# title: Caconeura gomphoidesRambur, 1842  -
# species_name: NOT FOUND
#
# class_name: caconeura-obscura
# title: Caconeura obscuraFraser, 1933  -
# species_name: NOT FOUND
#
# class_name: caconeura-risi
# title: Caconeura risiFraser, 1931  -
# species_name: NOT FOUND
#
# class_name: caconeura-spp
# title: Caconeura sppKirby, 1890  -
# species_name: NOT FOUND
#
# class_name: caconeura-t-coerulea
# title: Caconeura t-coeruleaFraser, 1933  -
# species_name: NOT FOUND
#
# class_name: calicnemia-carminea
# title: Calicnemia carmineaLieftinck, 1984  -
# species_name: NOT FOUND
#
# class_name: calicnemia-doonensis
# title: Calicnemia doonensisSangal & Tyagi, 1984  -
# species_name: NOT FOUND
#
# class_name: calicnemia-erythromelas
# title: Calicnemia erythromelasSelys, 1891  -
# species_name: NOT FOUND
#
# class_name: calicnemia-eximia
# title: Calicnemia eximiaSelys, 1863  -
# species_name: NOT FOUND
#
# class_name: calicnemia-imitans
# title: Calicnemia imitansLieftinck, 1948  -
# species_name: NOT FOUND
#
# class_name: calicnemia-miles
# title: Calicnemia milesLaidlaw, 1917  -
# species_name: NOT FOUND
#
# class_name: calicnemia-miniata
# title: Calicnemia miniataSelys, 1886  -
# species_name: NOT FOUND
#
# class_name: calicnemia-mortoni
# title: Calicnemia mortoniLaidlaw, 1917  -
# species_name: NOT FOUND
#
# class_name: calicnemia-mukherjeei
# title: Calicnemia mukherjeeiLahiri, 1976  -
# species_name: NOT FOUND
#
# class_name: calicnemia-nipalica
# title: Calicnemia nipalicaKimmins, 1958  -
# species_name: NOT FOUND
#
# class_name: calicnemia-pulverulans
# title: Calicnemia pulverulansSelys, 1886  -
# species_name: NOT FOUND
#
# class_name: calicnemia-pyrrhosoma
# title: Calicnemia pyrrhosomaLieftinck, 1984  -
# species_name: NOT FOUND
#
# class_name: calicnemia-spp
# title: Calicnemia sppStrand, 1928  -
# species_name: NOT FOUND
#
# class_name: calicnemia-sudhaae
# title: Calicnemia sudhaaeMitra, 1994  -
# species_name: NOT FOUND
#
# class_name: caliphaea-confusa
# title: Caliphaea confusaHagen in Selys, 1859  -
# species_name: NOT FOUND
#
# class_name: camacinia-harterti
# title: Camacinia hartertiKarsch, 1890  -
# species_name: NOT FOUND
#
# class_name: cephalaeschna-acanthifrons
# title: Cephalaeschna acanthifronsJoshi & Kunte 2017  -
# species_name: NOT FOUND
#
# class_name: cephalaeschna-acutifrons
# title: Cephalaeschna acutifronsMartin, 1909  -
# species_name: NOT FOUND
#
# class_name: cephalaeschna-klapperichi
# title: Cephalaeschna klapperichiSchmidt, 1961  -
# species_name: NOT FOUND
#
# class_name: cephalaeschna-masoni
# title: Cephalaeschna masoniMartin, 1909  -
# species_name: NOT FOUND
#
# class_name: cephalaeschna-orbifrons
# title: Cephalaeschna orbifronsSelys, 1883  -
# species_name: NOT FOUND
#
# class_name: cephalaeschna-triadica
# title: Cephalaeschna triadicaLieftinck, 1977   -
# species_name: NOT FOUND
#
# class_name: cephalaeschna-viridifrons
# title: Cephalaeschna viridifronsFraser, 1922  -
# species_name: NOT FOUND
#
# class_name: ceriagrion-auranticum
# title: Ceriagrion auranticumFraser, 1922  -
# species_name: NOT FOUND
#
# class_name: ceriagrion-calamineum
# title: Ceriagrion calamineumLieftinck, 1951  -
# species_name: NOT FOUND
#
# class_name: ceriagrion-coeruleum
# title: Ceriagrion coeruleumLaidlaw, 1919  -
# species_name: NOT FOUND
#
# class_name: chlorogomphus-brevistigma
# title: Chlorogomphus brevistigmaOguma, 1926  -
# species_name: NOT FOUND
#
# class_name: chlorogomphus-fraseri
# title: Chlorogomphus fraseriSt.Quentin, 1936  -
# species_name: NOT FOUND
#
# class_name: chlorogomphus-mortoni
# title: Chlorogomphus mortoniFraser, 1936  -
# species_name: NOT FOUND
#
# class_name: chlorogomphus-preciosus
# title: Chlorogomphus preciosusFraser, 1924  -
# species_name: NOT FOUND
#
# class_name: chlorogomphus-schmidti
# title: Chlorogomphus schmidtiAsahina, 1986  -
# species_name: NOT FOUND
#
# class_name: chlorogomphus-xanthoptera
# title: Chlorogomphus xanthopteraFraser, 1919  -
# species_name: NOT FOUND
#
# class_name: chloropetalia-olympicus
# title: Chloropetalia olympicusFraser, 1933  -
# species_name: NOT FOUND
#
# class_name: chloropetalia-selysi
# title: Chloropetalia selysiFraser, 1929  -
# species_name: NOT FOUND
#
# class_name: coeliccia-bimaculata
# title: Coeliccia bimaculataLaidlaw, 1914  -
# species_name: NOT FOUND
#
# class_name: coeliccia-dorothea
# title: Coeliccia dorotheaFraser, 1933  -
# species_name: NOT FOUND
#
# class_name: coeliccia-fraseri
# title: Coeliccia fraseriLaidlaw, 1932  -
# species_name: NOT FOUND
#
# class_name: coeliccia-prakritiae
# title: Coeliccia prakritiaeLahiri, 1985  -
# species_name: NOT FOUND
#
# class_name: coeliccia-renifera
# title: Coeliccia reniferaSelys, 1886  -
# species_name: NOT FOUND
#
# class_name: coeliccia-rossi
# title: Coeliccia rossiAsahina, 1984  -
# species_name: NOT FOUND
#
# class_name: coeliccia-sarbottama
# title: Coeliccia sarbottamaLahiri, 1987  -
# species_name: NOT FOUND
#
# class_name: coeliccia-schmidti
# title: Coeliccia schmidtiAsahina, 1984  -
# species_name: NOT FOUND
#
# class_name: coeliccia-svihleri
# title: Coeliccia svihleriAsahina, 1970  -
# species_name: NOT FOUND
#
# class_name: coeliccia-vacca
# title: Coeliccia vaccaLaidlaw, 1932  -
# species_name: NOT FOUND
#
# class_name: cordulegaster-brevistigma
# title: Cordulegaster brevistigmaSelys, 1854  -
# species_name: NOT FOUND
#
# class_name: cordulegaster-parvistigma
# title: Cordulegaster parvistigmaSelys, 1873  -
# species_name: NOT FOUND
#
# class_name: crocothemis-spp
# title: Crocothemis spp- Skimmers
# species_name: NOT FOUND
#
# class_name: cyclogomphus-flavoannulatus
# title: Cyclogomphus flavoannulatusRangnekar, Dharwadkar, Sadasivan & Subramanian, 2019  -
# species_name: NOT FOUND
#
# class_name: cyclogomphus-heterostylus
# title: Cyclogomphus heterostylusSelys, 1854  -
# species_name: NOT FOUND
#
# class_name: cyclogomphus-spp
# title: Cyclogomphus sppNA  -
# species_name: NOT FOUND
#
# class_name: cyclogomphus-vesiculosus
# title: Cyclogomphus vesiculosusSelys, 1873  -
# species_name: NOT FOUND
#
# class_name: cyclogomphus-wilkinsi
# title: Cyclogomphus wilkinsiFraser, 1926  -
# species_name: NOT FOUND
#
# class_name: cyclogomphus-ypsilon
# title: Cyclogomphus ypsilonSelys, 1854  -
# species_name: NOT FOUND
#
# class_name: davidioides-martini
# title: Davidioides martiniFraser, 1924  -
# species_name: NOT FOUND
#
# class_name: davidius-aberrans
# title: Davidius aberransSelys, 1873  -
# species_name: NOT FOUND
#
# class_name: davidius-davidi
# title: Davidius davidi-
# species_name: NOT FOUND
#
# class_name: davidius-davidii
# title: Davidius davidiiSelys, 1878  -
# species_name: NOT FOUND
#
# class_name: davidius-kumaonensis
# title: Davidius kumaonensisFraser, 1926  -
# species_name: NOT FOUND
#
# class_name: davidius-malloryi
# title: Davidius malloryiFraser, 1926  -
# species_name: NOT FOUND
#
# class_name: davidius-zallorensis
# title: Davidius zallorensisHagen in Selys, 1878  -
# species_name: NOT FOUND
#
# class_name: drepanosticta-annandalei
# title: Drepanosticta annandaleiFraser, 1924  -
# species_name: NOT FOUND
#
# class_name: drepanosticta-polychromatica
# title: Drepanosticta polychromaticaFraser, 1931  -
# species_name: NOT FOUND
#
# class_name: dubitogomphus-bidentatus
# title: Dubitogomphus bidentatusFraser, 1930  -
# species_name: NOT FOUND
#
# class_name: dysphaea-gloriosa
# title: Dysphaea gloriosaFraser, 1938  -
# species_name: NOT FOUND
#
# class_name: elattoneura-campioni
# title: Elattoneura campioniFraser, 1922  -
# species_name: NOT FOUND
#
# class_name: elattoneura-coomansi
# title: Elattoneura coomansiLieftinck, 1937  -
# species_name: NOT FOUND
#
# class_name: elattoneura-nihari
# title: Elattoneura nihariMitra, 1995  -
# species_name: NOT FOUND
#
# class_name: elattoneura-souteri
# title: Elattoneura souteriFraser, 1924  -
# species_name: NOT FOUND
#
# class_name: elattoneura-tetrica
# title: Elattoneura tetricaLaidlaw, 1917  -
# species_name: NOT FOUND
#
# class_name: enallagma-immsi
# title: Enallagma immsiLaidlaw, 1913  -
# species_name: NOT FOUND
#
# class_name: enallagma-insula
# title: Enallagma insulaFraser, 1920  -
# species_name: NOT FOUND
#
# class_name: enallagma-risi
# title: Enallagma risiSchmidt, 1961  -
# species_name: NOT FOUND
#
# class_name: epallage-fatime
# title: Epallage fatimeCharpentier, 1840  -
# species_name: NOT FOUND
#
# class_name: epiophlebia-laidlawi
# title: Epiophlebia laidlawiTillyard, 1921  -
# species_name: NOT FOUND
#
# class_name: epophthalmia-frontalis
# title: Epophthalmia frontalisSelys, 1871  -
# species_name: NOT FOUND
#
# class_name: epophthalmia-vittigera
# title: Epophthalmia vittigeraRambur, 1842  -
# species_name: NOT FOUND
#
# class_name: esme-cyaneovittata
# title: Esme cyaneovittataFraser, 1922  -
# species_name: NOT FOUND
#
# class_name: esme-longistyla
# title: Esme longistylaFraser, 1931  -
# species_name: NOT FOUND
#
# class_name: euphaea-masoni
# title: Euphaea masoniSelys, 1879  -
# species_name: NOT FOUND
#
# class_name: euphaea-ochracea
# title: Euphaea ochraceaSelys, 1859  -
# species_name: NOT FOUND
#
# class_name: euthygomphus-martini
# title: Euthygomphus martiniFraser, 1922  -
# species_name: NOT FOUND
#
# class_name: gomphidia-podhigai
# title: Gomphidia podhigaiBabu & Subramanian, 2019  -
# species_name: NOT FOUND
#
# class_name: gomphidia-t-nigrum
# title: Gomphidia t-nigrumSelys, 1854  -
# species_name: NOT FOUND
#
# class_name: gynacantha-albistyla
# title: Gynacantha albistylaFraser, 1927  -
# species_name: NOT FOUND
#
# class_name: gynacantha-anandmati
# title: Gynacantha anandmatiSawant & Kambli, 2023  -
# species_name: NOT FOUND
#
# class_name: gynacantha-andamanae
# title: Gynacantha andamanaeYeh & Veenakumari, 2000  -
# species_name: NOT FOUND
#
# class_name: gynacantha-apicalis
# title: Gynacantha apicalisFraser, 1927  -
# species_name: NOT FOUND
#
# class_name: gynacantha-arnaudi
# title: Gynacantha arnaudiAsahina, 1984  -
# species_name: NOT FOUND
#
# class_name: gynacantha-bainbriggei
# title: Gynacantha bainbriggeiFraser, 1922  -
# species_name: NOT FOUND
#
# class_name: gynacantha-biharica
# title: Gynacantha biharicaFraser, 1927  -
# species_name: NOT FOUND
#
# class_name: gynacantha-odoneli
# title: Gynacantha odoneliFraser, 1922  -
# species_name: NOT FOUND
#
# class_name: gynacantha-pallampurica
# title: Gynacantha pallampuricaLahiri, Sandhu & Walia, 2007  -
# species_name: NOT FOUND
#
# class_name: gynacantha-rammohani
# title: Gynacantha rammohaniMitra & Lahiri, 1975  -
# species_name: NOT FOUND
#
# class_name: gynacantha-rotundata
# title: Gynacantha rotundataNavas, 1930  -
# species_name: NOT FOUND
#
# class_name: gynacanthaeschna-sikkima
# title: Gynacanthaeschna sikkima(Karsch, 1891)  -
# species_name: NOT FOUND
#
# class_name: heliocypha-biforata
# title: Heliocypha biforataSelys, 1859  -
# species_name: NOT FOUND
#
# class_name: heliogomphus-kalarensis
# title: Heliogomphus kalarensisFraser, 1934  -
# species_name: NOT FOUND
#
# class_name: heliogomphus-selysi
# title: Heliogomphus selysiFraser, 1925  -
# species_name: NOT FOUND
#
# class_name: heliogomphus-spirillus
# title: Heliogomphus spirillusFraser, 1922  -
# species_name: NOT FOUND
#
# class_name: himalagrion-exclamatione
# title: Himalagrion exclamationeFraser, 1919  -
# species_name: NOT FOUND
#
# class_name: hylaeothemis-gardeneri
# title: Hylaeothemis gardeneriFraser, 1927  -
# species_name: NOT FOUND
#
# class_name: ictinogomphus-angulosus
# title: Ictinogomphus angulosusSelys, 1854  -
# species_name: NOT FOUND
#
# class_name: ictinogomphus-atrox
# title: Ictinogomphus atroxSelys, 1854  -
# species_name: NOT FOUND
#
# class_name: ictinogomphus-distinctus
# title: Ictinogomphus distinctusRam, 1985  -
# species_name: NOT FOUND
#
# class_name: ictinogomphus-kishori
# title: Ictinogomphus kishoriRam, 1985  -
# species_name: NOT FOUND
#
# class_name: ictinogomphus-pertinax
# title: Ictinogomphus pertinaxSelys, 1854  -
# species_name: NOT FOUND
#
# class_name: ictinogomphus-spp
# title: Ictinogomphus spp- Clubtails
# species_name: NOT FOUND
#
# class_name: idionyx-corona
# title: Idionyx coronaFraser, 1921  -
# species_name: NOT FOUND
#
# class_name: idionyx-galeata
# title: Idionyx galeataFraser, 1924  -
# species_name: NOT FOUND
#
# class_name: idionyx-imbricata
# title: Idionyx imbricataFraser, 1926  -
# species_name: NOT FOUND
#
# class_name: idionyx-intricata
# title: Idionyx intricataFraser, 1926  -
# species_name: NOT FOUND
#
# class_name: idionyx-minima
# title: Idionyx minimaFraser, 1931  -
# species_name: NOT FOUND
#
# class_name: idionyx-nadganiensis
# title: Idionyx nadganiensisFraser, 1924  -
# species_name: NOT FOUND
#
# class_name: idionyx-nilgiriensis
# title: Idionyx nilgiriensisFraser, 1918  -
# species_name: NOT FOUND
#
# class_name: idionyx-optata
# title: Idionyx optataSelys, 1878  -
# species_name: NOT FOUND
#
# class_name: idionyx-periyashola
# title: Idionyx periyasholaFraser, 1939  -
# species_name: NOT FOUND
#
# class_name: idionyx-rhinoceroides
# title: Idionyx rhinoceroidesFraser, 1934  -
# species_name: NOT FOUND
#
# class_name: idionyx-saffronata
# title: Idionyx saffronataFraser, 1924  -
# species_name: NOT FOUND
#
# class_name: idionyx-stevensi
# title: Idionyx stevensiFraser, 1924  -
# species_name: NOT FOUND
#
# class_name: idionyx-travancorensis
# title: Idionyx travancorensisFraser, 1931  -
# species_name: NOT FOUND
#
# class_name: indocnemis-orang
# title: Indocnemis orangFörster in Laidlaw, 1907  -
# species_name: NOT FOUND
#
# class_name: indocypha-vittata
# title: Indocypha vittataSelys, 1891  -
# species_name: NOT FOUND
#
# class_name: ischnura-elegans
# title: Ischnura elegansVander Linden, 1823  -
# species_name: NOT FOUND
#
# class_name: ischnura-inarmata
# title: Ischnura inarmataCalvert, 1898  -
# species_name: NOT FOUND
#
# class_name: ischnura-mildredae
# title: Ischnura mildredaeFraser, 1927  -
# species_name: NOT FOUND
#
# class_name: ischnura-null
# title: Ischnura null-
# species_name: NOT FOUND
#
# class_name: ischnura-rufostigma
# title: Ischnura rufostigmaSelys, 1876  -
# species_name: NOT FOUND
#
# class_name: ischnura-spp
# title: Ischnura spp- Bluetails
# species_name: NOT FOUND
#
# class_name: lamelligomphus-biforceps
# title: Lamelligomphus biforcepsSelys, 1878  -
# species_name: NOT FOUND
#
# class_name: lamelligomphus-risi
# title: Lamelligomphus risiFraser, 1922  -
# species_name: NOT FOUND
#
# class_name: lestes-patricia
# title: Lestes patriciaFraser, 1924  -
# species_name: NOT FOUND
#
# class_name: lestes-spp
# title: Lestes sppLeach, 1815  -
# species_name: NOT FOUND
#
# class_name: lestes-thoracicus
# title: Lestes thoracicusLaidlaw, 1920  -
# species_name: NOT FOUND
#
# class_name: libellago-aurantiaca
# title: Libellago aurantiacaSelys,1959  -
# species_name: NOT FOUND
#
# class_name: libellago-balus
# title: Libellago balusHämäläinen, 2002  -
# species_name: NOT FOUND
#
# class_name: libellago-blanda
# title: Libellago blandaHagen in Selys, 1853  -
# species_name: NOT FOUND
#
# class_name: lyriothemis-acigastra
# title: Lyriothemis acigastraSelys, 1878  -
# species_name: NOT FOUND
#
# class_name: lyriothemis-bivittata
# title: Lyriothemis bivittataRambur, 1842  -
# species_name: NOT FOUND
#
# class_name: lyriothemis-cleis
# title: Lyriothemis cleisBrauer, 1868  -
# species_name: NOT FOUND
#
# class_name: lyriothemis-mortoni
# title: Lyriothemis mortoniRis, 1919  -
# species_name: NOT FOUND
#
# class_name: lyriothemis-spp
# title: Lyriothemis sppBrauer, 1868  -
# species_name: NOT FOUND
#
# class_name: lyriothemis-tricolor
# title: Lyriothemis tricolorRis, 1919  -
# species_name: NOT FOUND
#
# class_name: macrogomphus-annulatus
# title: Macrogomphus annulatusSelys, 1854  -
# species_name: NOT FOUND
#
# class_name: macrogomphus-montanus
# title: Macrogomphus montanusSelys, 1869  -
# species_name: NOT FOUND
#
# class_name: macrogomphus-seductus
# title: Macrogomphus seductusFraser, 1926  -
# species_name: NOT FOUND
#
# class_name: macrogomphus-spp
# title: Macrogomphus spp-
# species_name: NOT FOUND
#
# class_name: macromia-annaimalaiensis
# title: Macromia annaimalaiensisFraser, 1931  -
# species_name: NOT FOUND
#
# class_name: macromia-bellicosa
# title: Macromia bellicosaFraser, 1924  -
# species_name: NOT FOUND
#
# class_name: macromia-cingulata
# title: Macromia cingulataRambur, 1842  -
# species_name: NOT FOUND
#
# class_name: macromia-cupricincta
# title: Macromia cupricinctaFraser, 1924  -
# species_name: NOT FOUND
#
# class_name: macromia-ellisoni
# title: Macromia ellisoniFraser, 1924  -
# species_name: NOT FOUND
#
# class_name: macromia-flavicincta
# title: Macromia flavicinctaSelys, 1874  -
# species_name: NOT FOUND
#
# class_name: macromia-flavocolorata
# title: Macromia flavocolorataFraser, 1922  -
# species_name: NOT FOUND
#
# class_name: macromia-flavovittata
# title: Macromia flavovittataFraser, 1935  -
# species_name: NOT FOUND
#
# class_name: macromia-ida
# title: Macromia idaFraser, 1924  -
# species_name: NOT FOUND
#
# class_name: macromia-indica
# title: Macromia indicaFraser, 1924  -
# species_name: NOT FOUND
#
# class_name: macromia-irata
# title: Macromia irataFraser, 1924  -
# species_name: NOT FOUND
#
# class_name: macromia-moorei
# title: Macromia mooreiSelys, 1874  -
# species_name: NOT FOUND
#
# class_name: macromia-pallida
# title: Macromia pallidaFraser, 1924  -
# species_name: NOT FOUND
#
# class_name: macromia-whitei
# title: Macromia whiteiSelys, 1871  -
# species_name: NOT FOUND
#
# class_name: macromidia-donaldi
# title: Macromidia donaldiFraser, 1924  -
# species_name: NOT FOUND
#
# class_name: macromidia-spp
# title: Macromidia spp-
# species_name: NOT FOUND
#
# class_name: matrona-basilaris
# title: Matrona basilarisSelys, 1853  -
# species_name: NOT FOUND
#
# class_name: matrona-nigripectus
# title: Matrona nigripectusSelys, 1879  -
# species_name: NOT FOUND
#
# class_name: megalestes-gyalsey
# title: Megalestes gyalseyGyeltshen, Kalkman & Orr, 2017  -
# species_name: NOT FOUND
#
# class_name: megalestes-irma
# title: Megalestes irmaFraser, 1926  -
# species_name: NOT FOUND
#
# class_name: megalestes-micans
# title: Megalestes micansNeedham, 1930  -
# species_name: NOT FOUND
#
# class_name: megalogomphus-bicornutus
# title: Megalogomphus bicornutusFraser, 1922  -
# species_name: NOT FOUND
#
# class_name: megalogomphus-flavicolor
# title: Megalogomphus flavicolorFraser, 1923  -
# species_name: NOT FOUND
#
# class_name: megalogomphus-hannyngtoni
# title: Megalogomphus hannyngtoniFraser, 1923  -
# species_name: NOT FOUND
#
# class_name: megalogomphus-smithii
# title: Megalogomphus smithiiSelys, 1854  -
# species_name: NOT FOUND
#
# class_name: megalogomphus-superbus
# title: Megalogomphus superbusFraser, 1931  -
# species_name: NOT FOUND
#
# class_name: melanoneura-bilineata
# title: Melanoneura bilineataFraser, 1922  -
# species_name: NOT FOUND
#
# class_name: melligomphus-acinaces
# title: Melligomphus acinacesLaidlaw, 1922  -
# species_name: NOT FOUND
#
# class_name: merogomphus-longistigma
# title: Merogomphus longistigmaFraser, 1922  -
# species_name: NOT FOUND
#
# class_name: merogomphus-tamaracherriensis
# title: Merogomphus tamaracherriensisLaidlaw, 1931  -
# species_name: NOT FOUND
#
# class_name: microgomphus-chelifer
# title: Microgomphus cheliferSelys,1858  -
# species_name: NOT FOUND
#
# class_name: microgomphus-souteri
# title: Microgomphus souteriFraser, 1924  -
# species_name: NOT FOUND
#
# class_name: microgomphus-torquatus
# title: Microgomphus torquatusSelys, 1854  -
# species_name: NOT FOUND
#
# class_name: microgomphus-verticalis
# title: Microgomphus verticalisSelys, 1873  -
# species_name: NOT FOUND
#
# class_name: mortonagrion-aborense
# title: Mortonagrion aborenseLaidlaw, 1914  -
# species_name: NOT FOUND
#
# class_name: mortonagrion-varralli
# title: Mortonagrion varralliFraser, 1920  -
# species_name: NOT FOUND
#
# class_name: neallogaster-annandalei
# title: Neallogaster annandaleiFraser, 1923  -
# species_name: NOT FOUND
#
# class_name: neallogaster-hermionae
# title: Neallogaster hermionaeFraser, 1927  -
# species_name: NOT FOUND
#
# class_name: neallogaster-latifrons
# title: Neallogaster latifronsSelys, 1878  -
# species_name: NOT FOUND
#
# class_name: neallogaster-ornata
# title: Neallogaster ornataAsahina, 1982  -
# species_name: NOT FOUND
#
# class_name: neallogaster-schmidti
# title: Neallogaster schmidtiAsahina, 1982  -
# species_name: NOT FOUND
#
# class_name: nepogomphus-modestus
# title: Nepogomphus modestusSelys, 1878  -
# species_name: NOT FOUND
#
# class_name: nepogomphus-walli
# title: Nepogomphus walliFraser, 1924  -
# species_name: NOT FOUND
#
# class_name: nesoxenia-lineata
# title: Nesoxenia lineataSelys, 1879  - Striped Grenadier
# species_name: Striped Grenadier
#
# class_name: neurothemis-intermedia
# title: Neurothemis intermediaRambur, 1842  -
# species_name: NOT FOUND
#
# class_name: neurothemis-ramburi
# title: Neurothemis ramburi(Braur, 1866)  -
# species_name: NOT FOUND
#
# class_name: nychogomphus-duaricus
# title: Nychogomphus duaricusFraser, 1924  -
# species_name: NOT FOUND
#
# class_name: nychogomphus-saundersii
# title: Nychogomphus saundersiiSelys, 1854  -
# species_name: NOT FOUND
#
# class_name: nychogomphus-striatus
# title: Nychogomphus striatusFraser, 1924  -
# species_name: NOT FOUND
#
# class_name: oligoaeschna-andamani
# title: Oligoaeschna andamaniChhotani, Lahiri & Mitra, 1983  -
# species_name: NOT FOUND
#
# class_name: onychargia-indica
# title: Onychargia indicaSahni, 1964  -
# species_name: NOT FOUND
#
# class_name: onychogomphus-cacharicus
# title: Onychogomphus cacharicusFraser, 1924  -
# species_name: NOT FOUND
#
# class_name: onychogomphus-grammicus
# title: Onychogomphus grammicusRambur, 1842  -
# species_name: NOT FOUND
#
# class_name: onychogomphus-malabarensis
# title: Onychogomphus malabarensisFraser, 1924  -
# species_name: NOT FOUND
#
# class_name: onychogomphus-meghalayanus
# title: Onychogomphus meghalayanusLahiri, 1987  -
# species_name: NOT FOUND
#
# class_name: onychogomphus-thienemanni
# title: Onychogomphus thienemanniSchmidt, 1934  -
# species_name: NOT FOUND
#
# class_name: ophiogomphus-cerastis
# title: Ophiogomphus cerastisSelys, 1854  -
# species_name: NOT FOUND
#
# class_name: ophiogomphus-reductus
# title: Ophiogomphus reductusCalvert, 1898  -
# species_name: NOT FOUND
#
# class_name: orientogomphus-indicus
# title: Orientogomphus indicusLahiri, 1987  -
# species_name: NOT FOUND
#
# class_name: orthetrum-anceps
# title: Orthetrum ancepsSchneider, 1845  -
# species_name: NOT FOUND
#
# class_name: orthetrum-brunneum
# title: Orthetrum brunneumFonscolombe, 1837  - Southern Skimmer
# species_name: Southern Skimmer
#
# class_name: orthetrum-cancellatum
# title: Orthetrum cancellatumLinnaeus, 1758  - Black-Tailed Skimmer
# species_name: Black-Tailed Skimmer
#
# class_name: orthetrum-internum
# title: Orthetrum internumMcLachlan, 1894  -
# species_name: NOT FOUND
#
# class_name: orthetrum-martensi
# title: Orthetrum martensiAsahina, 1978a  -
# species_name: NOT FOUND
#
# class_name: orthetrum-testaceaum
# title: Orthetrum testaceaumBurmeister, 1839  -
# species_name: NOT FOUND
#
# class_name: paragomphus-echinoccipitalis
# title: Paragomphus echinoccipitalisFraser, 1922  -
# species_name: NOT FOUND
#
# class_name: paragomphus-lindgreni
# title: Paragomphus lindgreniFraser, 1923  -
# species_name: NOT FOUND
#
# class_name: periaeschna-flinti
# title: Periaeschna flintiAsahina, 1978  -
# species_name: NOT FOUND
#
# class_name: periaeschna-lebasi
# title: Periaeschna lebasiNavas, 1930  -
# species_name: NOT FOUND
#
# class_name: periaeschna-magdalena
# title: Periaeschna magdalenaMartin, 1909  -
# species_name: NOT FOUND
#
# class_name: periaeschna-nocturnalis
# title: Periaeschna nocturnalisFraser, 1927  -
# species_name: NOT FOUND
#
# class_name: periaeschna-unifasciata
# title: Periaeschna unifasciataFraser, 1935  -
# species_name: NOT FOUND
#
# class_name: perissogomphus-stevensi
# title: Perissogomphus stevensiLaidlaw, 1922  -
# species_name: NOT FOUND
#
# class_name: petaliaeschna-fletcheri
# title: Petaliaeschna fletcheriFraser, 1927  -
# species_name: NOT FOUND
#
# class_name: phaenandrogomphus-aureus
# title: Phaenandrogomphus aureusLaidlaw, 1922  -
# species_name: NOT FOUND
#
# class_name: philoganga-montana
# title: Philoganga montanaHagen in Selys, 1859  -
# species_name: NOT FOUND
#
# class_name: phyllothemis-eltoni
# title: Phyllothemis eltoniFraser, 1935  -
# species_name: NOT FOUND
#
# class_name: planaeschna-intersedens
# title: Planaeschna intersedensMartin, 1909  -
# species_name: NOT FOUND
#
# class_name: planaeschna-poumai
# title: Planaeschna poumaiJoshi & Kunte 2017  -
# species_name: NOT FOUND
#
# class_name: planaeschna-spp
# title: Planaeschna spp-
# species_name: NOT FOUND
#
# class_name: platycnemis-dealbata
# title: Platycnemis dealbataSelys, 1863  -
# species_name: NOT FOUND
#
# class_name: platygomphus-dolabratus
# title: Platygomphus dolabratusSelys, 1854  -
# species_name: NOT FOUND
#
# class_name: platylestes-platystylus
# title: Platylestes platystylusRambur, 1842  -
# species_name: NOT FOUND
#
# class_name: polycanthagyna-erythromelas
# title: Polycanthagyna erythromelasMcLachlan, 1896  -
# species_name: NOT FOUND
#
# class_name: polycanthagyna-ornithocephala
# title: Polycanthagyna ornithocephalaMcLachlan, 1896  -
# species_name: NOT FOUND
#
# class_name: prodasineura-odoneli
# title: Prodasineura odoneliFraser, 1922  -
# species_name: NOT FOUND
#
# class_name: protosticta-fraseri
# title: Protosticta fraseriKennedy, 1936  -
# species_name: NOT FOUND
#
# class_name: protosticta-hearseyi
# title: Protosticta hearseyiFraser, 1922  -
# species_name: NOT FOUND
#
# class_name: protosticta-himalaica
# title: Protosticta himalaicaLaidlaw, 1917  -
# species_name: NOT FOUND
#
# class_name: protosticta-mortoni
# title: Protosticta mortoniFraser, 1924  -
# species_name: NOT FOUND
#
# class_name: protosticta-rufostigma
# title: Protosticta rufostigmaKimmins, 1958  -
# species_name: NOT FOUND
#
# class_name: protosticta-spp
# title: Protosticta spp-
# species_name: NOT FOUND
#
# class_name: pseudagrion-andamanicum
# title: Pseudagrion andamanicumFraser, 1924  - Andaman Sprite
# species_name: Andaman Sprite
#
# class_name: pseudagrion-bidentatum
# title: Pseudagrion bidentatumMorton, 1907  -
# species_name: NOT FOUND
#
# class_name: pseudagrion-laidlawi
# title: Pseudagrion laidlawiFraser, 1922  -
# species_name: NOT FOUND
#
# class_name: pseudagrion-pilidorsum
# title: Pseudagrion pilidorsumBrauer, 1868  -
# species_name: NOT FOUND
#
# class_name: pseudagrion-pruinosum
# title: Pseudagrion pruinosum(Burmeister, 1839)  - Grey Sprite
# species_name: Grey Sprite
#
# class_name: pseudocopera-superplatypes
# title: Pseudocopera superplatypesFraser, 1927  -
# species_name: NOT FOUND
#
# class_name: pseudotramea-prateri
# title: Pseudotramea prateriFraser, 1920  -
# species_name: NOT FOUND
#
# class_name: rhinocypha-ignipennis
# title: Rhinocypha ignipennisSelys,1879  -
# species_name: NOT FOUND
#
# class_name: rhinocypha-immaculata
# title: Rhinocypha immaculataSelys,1879  -
# species_name: NOT FOUND
#
# class_name: rhinocypha-trimaculata
# title: Rhinocypha trimaculataSelys,1853  -
# species_name: NOT FOUND
#
# class_name: rhinocypha-vitrinella
# title: Rhinocypha vitrinellaFraser,1935  -
# species_name: NOT FOUND
#
# class_name: rhyothemis-obsolescens
# title: Rhyothemis obsolescensKirby, 1889  -
# species_name: NOT FOUND
#
# class_name: sarasaeschna-khasiana
# title: Sarasaeschna khasianaLieftinck, 1968  -
# species_name: NOT FOUND
#
# class_name: sarasaeschna-martini
# title: Sarasaeschna martiniLaidlaw, 1921  -
# species_name: NOT FOUND
#
# class_name: sarasaeschna-speciosa
# title: Sarasaeschna speciosaKarube, 1998  -
# species_name: NOT FOUND
#
# class_name: scalmogomphus-bistrigatus
# title: Scalmogomphus bistrigatusHagen in Selys, 1854  -
# species_name: NOT FOUND
#
# class_name: scalmogomphus-schmidti
# title: Scalmogomphus schmidtiFraser, 1937  -
# species_name: NOT FOUND
#
# class_name: scalmogomphus-spp
# title: Scalmogomphus sppChao, 1990  -
# species_name: NOT FOUND
#
# class_name: schmidtiphaea-chittaranjani
# title: Schmidtiphaea chittaranjaniLahiri, 2003  -
# species_name: NOT FOUND
#
# class_name: schmidtiphaea-schmidi
# title: Schmidtiphaea schmidiAsahina, 1978  -
# species_name: NOT FOUND
#
# class_name: selysiothemis-nigra
# title: Selysiothemis nigraVander Linden, 1825  - Black Pennant
# species_name: Black Pennant
#
# class_name: somatochlora-daviesi
# title: Somatochlora daviesiLieftinck, 1977  -
# species_name: NOT FOUND
#
# class_name: stylogomphus-inglisi
# title: Stylogomphus inglisiFraser, 1922  -
# species_name: NOT FOUND
#
# class_name: sympetrum-durum
# title: Sympetrum durumBartenef, 1916  -
# species_name: NOT FOUND
#
# class_name: sympetrum-himalayanum
# title: Sympetrum himalayanumNavas, 1934  -
# species_name: NOT FOUND
#
# class_name: sympetrum-hypomelas
# title: Sympetrum hypomelasSelys, 1884  -
# species_name: NOT FOUND
#
# class_name: sympetrum-meridionale
# title: Sympetrum meridionaleSelys, 1841  - Southern Darter
# species_name: Southern Darter
#
# class_name: sympetrum-orientale
# title: Sympetrum orientaleSelys, 1883  -
# species_name: NOT FOUND
#
# class_name: sympetrum-speciosum
# title: Sympetrum speciosumOguma, 1915  -
# species_name: NOT FOUND
#
# class_name: sympetrum-spp
# title: Sympetrum sppNewman, 1833  -
# species_name: NOT FOUND
#
# class_name: sympetrum-vulgatum
# title: Sympetrum vulgatumLinnaeus, 1758  - Vagrant Darter
# species_name: Vagrant Darter
#
# class_name: tetracanthagyna-waterhousei
# title: Tetracanthagyna waterhouseiMcLachlan, 1898  -
# species_name: NOT FOUND
#
# class_name: tramea-eurybia
# title: Tramea eurybiaSelys, 1878  -
# species_name: NOT FOUND
#
# class_name: tramea-transmarina
# title: Tramea transmarinaSelys, 1878  -
# species_name: NOT FOUND
#
# class_name: tramea-virginia
# title: Tramea virginiaRambur, 1842  -
# species_name: NOT FOUND
#
# class_name: vestalaria-smaragdina
# title: Vestalaria smaragdinaSelys, 1879  -
# species_name: NOT FOUND
#
# class_name: vestalis-submontana
# title: Vestalis submontanaFraser, 1934  -
# species_name: NOT FOUND
#
# class_name: watanabeopetalia-atkinsoni
# title: Watanabeopetalia atkinsoniSelys, 1878c  -
# species_name: NOT FOUND
#
# class_name: zygonyx-torrida
# title: Zygonyx torridaKirby, 1889  - Ringed Cascader
# species_name: Ringed Cascader
#
# class_name: zyxomma-breviventre
# title: Zyxomma breviventre(Martin, 1921)  -
# species_name: NOT FOUND
#
# class_name: zyxomma-obtusum
# title: Zyxomma obtusumAlbarda, 1881  - White Duskdarter
# species_name: White Duskdarter

# %%
# replace unicodes 

import json

for class_name, details in class_details.items():
    if 'name' in details:
        # details['name'] = re.sub("\\u2019", "'", details['name'])
        for unicode in range(0, 9999):
            details['name'] = re.sub(f"\\u{unicode:04}", f"\\u{unicode:04}".encode().decode("unicode_escape"), details['name'])

# %%
import json

# dump json
with open(class_details_json_path, "w", encoding="utf-8") as file:
        json.dump(class_details, file, indent=4)

# %% [markdown]
# # Fetch image urls

# %%
import json

# read json
with open(class_details_json_path, "r", encoding="utf-8") as file:
    class_details = json.load(file)

# %%
for class_name, _ in classes.items():
    if class_name not in class_details and not class_name.endswith(early_stage_suffix):
        class_details[class_name] = {}

# %%
max_images = 10

for class_name, data in class_details.items():
    try:
        if 'images' in class_details[class_name]:
            continue
        print(f"processing {class_name}")
        early_class_name = class_name + early_stage_suffix
        url = f"{website_url}/{class_name}"
        response = requests.get(url, timeout=page_timeout)
        soup = BeautifulSoup(response.text, 'html.parser')
        img_tags = soup.find_all('img')
        for img in img_tags:
            if 'images' in class_details[class_name] and len(class_details[class_name]['images']) >= max_images:
                break
            if early_class_name in class_details:
                if 'images' in class_details[early_class_name] and len(class_details[early_class_name]['images']) >= max_images:
                    break
            img_url = img.get('src')
            if has_parent_with_prop(img, 'id', 'laraval', 5):
                continue
            if img_url:
                img_url = urljoin(url, img_url)
                img_name = img_url.split("/")[-1]
                if re.search(ignore_image_regex, img_name):
                    continue
                if has_parent_with_prop(img, 'id', 'early', 6):
                    if 'images' not in class_details[early_class_name]:
                        class_details[early_class_name]['images'] = []
                    if len(class_details[early_class_name]['images']) < max_images:
                        class_details[early_class_name]['images'] += [img_url]
                else:
                    if 'images' not in class_details[class_name]:
                        class_details[class_name]['images'] = []
                    if len(class_details[class_name]['images']) < max_images:
                        class_details[class_name]['images'] += [img_url]
        with open(class_details_json_path, "w", encoding="utf-8") as file:
            json.dump(class_details, file, indent=4)
    except Exception:
        print("ERROR")
# Out:
# processing aciagrion-hisopa
# processing aeshna-donaldi
# processing anax-imperator
# processing nesoxenia-lineata
# processing orthetrum-brunneum
# processing orthetrum-cancellatum
# processing pseudagrion-andamanicum
# processing pseudagrion-pruinosum
# processing selysiothemis-nigra
# processing sympetrum-meridionale
# processing sympetrum-vulgatum
# processing zygonyx-torrida
# processing zyxomma-obtusum
# processing aciagrion-azureum
# processing aciagrion-olympicum
# processing aciagrion-tillyardi
# processing acrogomphus-mohani
# processing agriocnemis-corbeti
# processing agriocnemis-dabreui
# processing agriocnemis-nana
# processing agrionoptera-dorothea
# processing amphithemis-curvistyla
# processing anax-panybeus
# processing anisogomphus-orites
# processing anormogomphus-heteropterus
# processing anormogomphus-kiritschenkoi
# processing aristocypha-immaculata
# processing asiagomphus-personatus
# processing bayadera-kali
# processing bayadera-longicauda
# processing burmargiolestes-laidlawi
# processing caconeura-gomphoides
# processing caconeura-obscura
# processing calicnemia-doonensis
# processing calicnemia-mukherjeei
# processing calicnemia-pyrrhosoma
# processing calicnemia-sudhaae
# processing cephalaeschna-acutifrons
# processing cephalaeschna-klapperichi
# processing cephalaeschna-masoni
# processing cephalaeschna-orbifrons
# processing ceriagrion-auranticum
# processing ceriagrion-coeruleum
# processing chlorogomphus-brevistigma
# processing chlorogomphus-schmidti
# processing chloropetalia-olympicus
# processing chloropetalia-selysi
# processing coeliccia-dorothea
# processing coeliccia-fraseri
# processing coeliccia-prakritiae
# processing coeliccia-rossi
# processing coeliccia-sarbottama
# processing coeliccia-vacca
# processing cordulegaster-parvistigma
# processing cyclogomphus-vesiculosus
# processing davidius-kumaonensis
# processing davidius-malloryi
# processing davidius-zallorensis
# processing drepanosticta-annandalei
# processing drepanosticta-polychromatica
# processing elattoneura-nihari
# processing elattoneura-souteri
# processing enallagma-immsi
# processing enallagma-insula
# processing enallagma-risi
# processing epallage-fatime
# processing epiophlebia-laidlawi
# processing epophthalmia-vittigera
# processing gynacantha-albistyla
# processing gynacantha-anandmati
# processing gynacantha-andamanae
# processing gynacantha-apicalis
# processing gynacantha-arnaudi
# processing gynacantha-bainbriggei
# processing gynacantha-biharica
# processing gynacantha-odoneli
# processing gynacantha-pallampurica
# processing gynacantha-rammohani
# processing gynacantha-rotundata
# processing heliogomphus-kalarensis
# processing heliogomphus-selysi
# processing himalagrion-exclamatione
# processing ictinogomphus-atrox
# processing ictinogomphus-kishori
# processing ictinogomphus-pertinax
# processing idionyx-galeata
# processing idionyx-imbricata
# processing idionyx-intricata
# processing idionyx-minima
# processing idionyx-nadganiensis
# processing idionyx-nilgiriensis
# processing idionyx-optata
# processing idionyx-periyashola
# processing idionyx-rhinoceroides
# processing indocypha-vittata
# processing ischnura-elegans
# processing ischnura-null
# processing libellago-aurantiaca
# processing lyriothemis-cleis
# processing macrogomphus-spp
# ERROR
# processing macromia-annaimalaiensis
# processing macromia-cupricincta
# processing macromia-flavovittata
# processing macromia-ida
# processing macromia-pallida
# processing macromia-whitei
# processing macromidia-spp
# ERROR
# processing megalogomphus-bicornutus
# processing microgomphus-chelifer
# processing microgomphus-verticalis
# processing neallogaster-annandalei
# processing neallogaster-latifrons
# processing neallogaster-ornata
# processing neallogaster-schmidti
# processing neurothemis-ramburi
# processing nychogomphus-saundersii
# processing nychogomphus-striatus
# processing oligoaeschna-andamani
# processing onychargia-indica
# processing onychogomphus-cacharicus
# processing onychogomphus-grammicus
# processing onychogomphus-malabarensis
# processing onychogomphus-meghalayanus
# processing onychogomphus-thienemanni
# processing ophiogomphus-cerastis
# processing orthetrum-anceps
# processing orthetrum-martensi
# processing orthetrum-testaceaum
# processing paragomphus-lindgreni
# processing periaeschna-flinti
# processing periaeschna-lebasi
# processing periaeschna-magdalena
# processing periaeschna-nocturnalis
# processing petaliaeschna-fletcheri
# processing planaeschna-intersedens
# processing platycnemis-dealbata
# processing polycanthagyna-ornithocephala
# processing prodasineura-odoneli
# processing protosticta-rufostigma
# processing pseudagrion-bidentatum
# processing pseudagrion-laidlawi
# ERROR
# processing pseudocopera-superplatypes
# processing pseudotramea-prateri
# processing rhinocypha-ignipennis
# processing rhinocypha-immaculata
# processing rhinocypha-trimaculata
# processing rhinocypha-vitrinella
# processing rhyothemis-obsolescens
# processing sarasaeschna-martini
# processing sarasaeschna-speciosa
# processing schmidtiphaea-schmidi
# processing sympetrum-durum
# processing sympetrum-himalayanum
# processing sympetrum-hypomelas
# processing tramea-eurybia
# processing vestalis-submontana
# processing watanabeopetalia-atkinsoni

# %%
import json
# read json
with open(class_details_json_path, "r", encoding="utf-8") as file:
    class_details = json.load(file)
# remove duplicates
for class_name, data in class_details.items():
    if 'images' in data:
        data['images'] = list(set(data['images']))
# dump json
with open(class_details_json_path, "w", encoding="utf-8") as file:
    json.dump(class_details, file, indent=4)

# %%
import json
# read json
with open(class_details_json_path, "r", encoding="utf-8") as file:
    class_details = json.load(file)
# remove bad images
bad_image_regex = r"(?i).*(butterfliy_5\.jpg).*"
for class_name, data in class_details.items():
    if 'images' in data:
        data['images'] = [ image for image in data['images'] if not re.match(bad_image_regex, image) ]
# dump json
with open(class_details_json_path, "w", encoding="utf-8") as file:
    json.dump(class_details, file, indent=4)

# %% [markdown]
# # Count

# %%
early_regex = r"^.*-(early)$"
unidentified_regex = r"^.*-(spp|genera|genera-spp)$"
early_or_unidentified_regex = r"^.*-(early|spp|genera|genera-spp)$"
classes = { class_dir: len([ img for img in os.listdir(f"{dataset_dir}/{class_dir}") ]) for class_dir in os.listdir(f"{dataset_dir}") }
early_classes = { class_name: count for class_name, count in classes.items() if re.match(early_regex, class_name) }
unidentified_classes = { class_name: count for class_name, count in classes.items() if re.match(unidentified_regex, class_name) }
print(f"Total Class count : {len(classes):6} ( Unidentified: {len(unidentified_classes):6} / Early-stage: {len(early_classes):6} / Identified-adult: {len(classes) - len(unidentified_classes) - len(early_classes):6} )")
print(f"Total  Data count : {sum(classes.values()):6} ( Unidentified: {sum(unidentified_classes.values()):6} / Early-stage: {sum(early_classes.values()):6} / Identified-adult: {sum(classes.values()) - sum(unidentified_classes.values()) - sum(early_classes.values()):6} )")
# Out:
# Total Class count :    737 ( Unidentified:     27 / Early-stage:    200 / Identified-adult:    510 )
# Total  Data count :  13172 ( Unidentified:    286 / Early-stage:   1498 / Identified-adult:  11388 )

# %%
empty_classes = [ class_dir for class_dir in os.listdir(f"{dataset_dir}") if not os.listdir(f"{dataset_dir}/{class_dir}") ]
print (f"Empty classes: {len(empty_classes)}")
# Out:
# Empty classes: 157
